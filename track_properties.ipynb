# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from client_info import SPOTIFY_CID as cid, SPOTIFY_CS as secret
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
def get_all_tracks(user_id,playlist_id):
    results = sp.user_playlist_tracks(user_id, playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
#>=500 million plays 
#https://open.spotify.com/playlist/2YRe7HRKNRvXdJBp9nXFza?si=\198755290d2c4102
#user
#https://open.spotify.com/user/1221028518?si=2aa6f2f72ab44757

mil_playlist_url = 'https://open.spotify.com/playlist/2YRe7HRKNRvXdJBp9nXFza?si=\198755290d2c4102'
track_list = get_all_tracks('2aa6f2f72ab44757', mil_playlist_url)
#sp.playlist(mil_playlist_url)['tracks']['items']
len(track_list)
# Out:
# 682

# %%
#create list to create dataframe with. contains all features+song name and artist
track_info = []
bad_info = ['type', 'id', 'uri', 'track_href', 'analysis_url']
total_genres = set()
for track in track_list:
    track_uri=track['track']['uri']
    usable_track=sp.track(track_uri)
    track_id=usable_track['id']

    track_features = sp.audio_features(track_id)[0]
    track_features['name'] = usable_track['name']
    track_features['artist(s)'] = [usable_track['artists'][i]['name'] 
        for i in range(len(usable_track['artists']))]

    artist_ids = [usable_track['artists'][i]['uri'] 
        for i in range(len(usable_track['artists']))]
    genres = [sp.artist(artist)['genres'] for artist in artist_ids]
    track_features['genres'] = genres
    [total_genres.update(genre) for genre in genres]

    for info in bad_info:
        track_features.pop(info)

    track_info.append(track_features)

# %%
track_info
# Out:
# [{'danceability': 0.514,
#   'energy': 0.73,
#   'key': 1,
#   'loudness': -5.934,
#   'mode': 1,
#   'speechiness': 0.0598,
#   'acousticness': 0.00146,
#   'instrumentalness': 9.54e-05,
#   'liveness': 0.0897,
#   'valence': 0.334,
#   'tempo': 171.005,
#   'duration_ms': 200040,
#   'time_signature': 4,
#   'name': 'Blinding Lights',
#   'artist(s)': ['The Weeknd'],
#   'genres': [['canadian contemporary r&b', 'canadian pop', 'pop']]},
#  {'danceability': 0.825,
#   'energy': 0.652,
#   'key': 1,
#   'loudness': -3.183,
#   'mode': 0,
#   'speechiness': 0.0802,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0931,
#   'valence': 0.931,
#   'tempo': 95.977,
#   'duration_ms': 233713,
#   'time_signature': 4,
#   'name': 'Shape of You',
#   'artist(s)': ['Ed Sheeran'],
#   'genres': [['pop', 'uk pop']]},
#  {'danceability': 0.824,
#   'energy': 0.587,
#   'key': 6,
#   'loudness': -6.401,
#   'mode': 0,
#   'speechiness': 0.0937,
#   'acousticness': 0.69,
#   'instrumentalness': 0.000105,
#   'liveness': 0.149,
#   'valence': 0.514,
#   'tempo': 98.029,
#   'duration_ms': 209438,
#   'time_signature': 4,
#   'name': 'Dance Monkey',
#   'artist(s)': ['Tones And I'],
#   'genres': [['australian pop', 'pop']]},
#  {'danceability': 0.501,
#   'energy': 0.405,
#   'key': 1,
#   'loudness': -5.679,
#   'mode': 1,
#   'speechiness': 0.0319,
#   'acousticness': 0.751,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.446,
#   'tempo': 109.891,
#   'duration_ms': 182161,
#   'time_signature': 4,
#   'name': 'Someone You Loved',
#   'artist(s)': ['Lewis Capaldi'],
#   'genres': [['pop', 'uk pop']]},
#  {'danceability': 0.585,
#   'energy': 0.52,
#   'key': 5,
#   'loudness': -6.136,
#   'mode': 0,
#   'speechiness': 0.0712,
#   'acousticness': 0.124,
#   'instrumentalness': 7.01e-05,
#   'liveness': 0.131,
#   'valence': 0.129,
#   'tempo': 159.801,
#   'duration_ms': 218147,
#   'time_signature': 4,
#   'name': 'rockstar (feat. 21 Savage)',
#   'artist(s)': ['Post Malone', '21 Savage'],
#   'genres': [['dfw rap', 'melodic rap', 'rap'], ['atl hip hop', 'rap']]},
#  {'danceability': 0.76,
#   'energy': 0.479,
#   'key': 2,
#   'loudness': -5.574,
#   'mode': 1,
#   'speechiness': 0.0466,
#   'acousticness': 0.556,
#   'instrumentalness': 0,
#   'liveness': 0.0703,
#   'valence': 0.913,
#   'tempo': 89.911,
#   'duration_ms': 158040,
#   'time_signature': 4,
#   'name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#   'artist(s)': ['Post Malone', 'Swae Lee'],
#   'genres': [['dfw rap', 'melodic rap', 'rap'], ['melodic rap', 'trap']]},
#  {'danceability': 0.792,
#   'energy': 0.625,
#   'key': 1,
#   'loudness': -5.609,
#   'mode': 1,
#   'speechiness': 0.0536,
#   'acousticness': 0.00776,
#   'instrumentalness': 0.00188,
#   'liveness': 0.329,
#   'valence': 0.37,
#   'tempo': 103.967,
#   'duration_ms': 173987,
#   'time_signature': 4,
#   'name': 'One Dance',
#   'artist(s)': ['Drake', 'Wizkid', 'Kyla'],
#   'genres': [['canadian hip hop',
#     'canadian pop',
#     'hip hop',
#     'rap',
#     'toronto rap'],
#    ['afro dancehall', 'afropop', 'azonto', 'nigerian hip hop', 'nigerian pop'],
#    ['uk funky']]},
#  {'danceability': 0.738,
#   'energy': 0.541,
#   'key': 8,
#   'loudness': -5.597,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.415,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.657,
#   'tempo': 94.949,
#   'duration_ms': 245507,
#   'time_signature': 4,
#   'name': 'Closer',
#   'artist(s)': ['The Chainsmokers', 'Halsey'],
#   'genres': [['dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop']]},
#  {'danceability': 0.772,
#   'energy': 0.78,
#   'key': 10,
#   'loudness': -4.288,
#   'mode': 0,
#   'speechiness': 0.108,
#   'acousticness': 0.0512,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.719,
#   'tempo': 124.988,
#   'duration_ms': 204347,
#   'time_signature': 4,
#   'name': 'Believer',
#   'artist(s)': ['Imagine Dragons'],
#   'genres': [['modern rock', 'rock']]},
#  {'danceability': 0.591,
#   'energy': 0.764,
#   'key': 1,
#   'loudness': -5.484,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.0383,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.478,
#   'tempo': 169.928,
#   'duration_ms': 141806,
#   'time_signature': 4,
#   'name': 'STAY (with Justin Bieber)',
#   'artist(s)': ['The Kid LAROI', 'Justin Bieber'],
#   'genres': [['australian hip hop', 'pop', 'rap'], ['canadian pop', 'pop']]},
#  {'danceability': 0.759,
#   'energy': 0.548,
#   'key': 9,
#   'loudness': -6.049,
#   'mode': 0,
#   'speechiness': 0.029,
#   'acousticness': 0.0392,
#   'instrumentalness': 0,
#   'liveness': 0.0828,
#   'valence': 0.749,
#   'tempo': 116.967,
#   'duration_ms': 190800,
#   'time_signature': 4,
#   'name': 'Señorita',
#   'artist(s)': ['Shawn Mendes', 'Camila Cabello'],
#   'genres': [['canadian pop', 'dance pop', 'pop', 'viral pop'],
#    ['dance pop', 'pop', 'post-teen pop']]},
#  {'danceability': 0.599,
#   'energy': 0.448,
#   'key': 8,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0232,
#   'acousticness': 0.163,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.168,
#   'tempo': 95.05,
#   'duration_ms': 263400,
#   'time_signature': 3,
#   'name': 'Perfect',
#   'artist(s)': ['Ed Sheeran'],
#   'genres': [['pop', 'uk pop']]},
#  {'danceability': 0.761,
#   'energy': 0.525,
#   'key': 11,
#   'loudness': -6.9,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.44,
#   'instrumentalness': 6.7e-06,
#   'liveness': 0.0921,
#   'valence': 0.531,
#   'tempo': 80.87,
#   'duration_ms': 238805,
#   'time_signature': 4,
#   'name': 'Heat Waves',
#   'artist(s)': ['Glass Animals'],
#   'genres': [['gauze pop', 'indietronica', 'shiver pop']]},
#  {'danceability': 0.358,
#   'energy': 0.557,
#   'key': 10,
#   'loudness': -7.398,
#   'mode': 1,
#   'speechiness': 0.059,
#   'acousticness': 0.695,
#   'instrumentalness': 0,
#   'liveness': 0.0902,
#   'valence': 0.494,
#   'tempo': 85.043,
#   'duration_ms': 211467,
#   'time_signature': 4,
#   'name': "Say You Won't Let Go",
#   'artist(s)': ['James Arthur'],
#   'genres': [['pop', 'talent show', 'uk pop']]},
#  {'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'duration_ms': 194088,
#   'time_signature': 4,
#   'name': 'bad guy',
#   'artist(s)': ['Billie Eilish'],
#   'genres': [['art pop', 'electropop', 'pop']]},
#  {'danceability': 0.781,
#   'energy': 0.445,
#   'key': 2,
#   'loudness': -6.061,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.474,
#   'instrumentalness': 0,
#   'liveness': 0.184,
#   'valence': 0.591,
#   'tempo': 78.998,
#   'duration_ms': 281560,
#   'time_signature': 4,
#   'name': 'Thinking out Loud',
#   'artist(s)': ['Ed Sheeran'],
#   'genres': [['pop', 'uk pop']]},
#  {'danceability': 0.511,
#   'energy': 0.566,
#   'key': 6,
#   'loudness': -7.23,
#   'mode': 0,
#   'speechiness': 0.2,
#   'acousticness': 0.349,
#   'instrumentalness': 0,
#   'liveness': 0.34,
#   'valence': 0.218,
#   'tempo': 83.903,
#   'duration_ms': 239836,
#   'time_signature': 4,
#   'name': 'Lucid Dreams',
#   'artist(s)': ['Juice WRLD'],
#   'genres': [['chicago rap', 'melodic rap']]},
#  {'danceability': 0.679,
#   'energy': 0.587,
#   'key': 7,
#   'loudness': -7.015,
#   'mode': 1,
#   'speechiness': 0.276,
#   'acousticness': 0.141,
#   'instrumentalness': 6.35e-06,
#   'liveness': 0.137,
#   'valence': 0.486,
#   'tempo': 186.003,
#   'duration_ms': 230453,
#   'time_signature': 4,
#   'name': 'Starboy',
#   'artist(s)': ['The Weeknd', 'Daft Punk'],
#   'genres': [['canadian contemporary r&b', 'canadian pop', 'pop'],
#    ['electro', 'filter house']]},
#  {'danceability': 0.793,
#   'energy': 0.793,
#   'key': 11,
#   'loudness': -4.521,
#   'mode': 0,
#   'speechiness': 0.083,
#   'acousticness': 0.0123,
#   'instrumentalness': 0,
#   'liveness': 0.0951,
#   'valence': 0.679,
#   'tempo': 123.95,
#   'duration_ms': 183290,
#   'time_signature': 4,
#   'name': "Don't Start Now",
#   'artist(s)': ['Dua Lipa'],
#   'genres': [['dance pop', 'pop', 'uk pop']]},
#  {'danceability': 0.754,
#   'energy': 0.449,
#   'key': 7,
#   'loudness': -9.211,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.0332,
#   'instrumentalness': 8.29e-05,
#   'liveness': 0.552,
#   'valence': 0.357,
#   'tempo': 77.169,
#   'duration_ms': 198973,
#   'time_signature': 4,
#   'name': "God's Plan",
#   'artist(s)': ['Drake'],
#   'genres': [['canadian hip hop',
#     'canadian pop',
#     'hip hop',
#     'rap',
#     'toronto rap']]},
#  {'danceability': 0.351,
#   'energy': 0.296,
#   'key': 4,
#   'loudness': -10.109,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.934,
#   'instrumentalness': 0,
#   'liveness': 0.095,
#   'valence': 0.12,
#   'tempo': 115.284,
#   'duration_ms': 200186,
#   'time_signature': 4,
#   'name': 'lovely (with Khalid)',
#   'artist(s)': ['Billie Eilish', 'Khalid'],
#   'genres': [['art pop', 'electropop', 'pop'], ['pop', 'pop r&b']]},
#  {'danceability': 0.548,
#   'energy': 0.816,
#   'key': 0,
#   'loudness': -4.209,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.122,
#   'instrumentalness': 0,
#   'liveness': 0.335,
#   'valence': 0.557,
#   'tempo': 95.39,
#   'duration_ms': 174000,
#   'time_signature': 4,
#   'name': 'Watermelon Sugar',
#   'artist(s)': ['Harry Styles'],
#   'genres': [['pop']]},
#  {'danceability': 0.614,
#   'energy': 0.379,
#   'key': 4,
#   'loudness': -10.48,
#   'mode': 1,
#   'speechiness': 0.0476,
#   'acousticness': 0.607,
#   'instrumentalness': 0.000464,
#   'liveness': 0.0986,
#   'valence': 0.201,
#   'tempo': 107.989,
#   'duration_ms': 258987,
#   'time_signature': 4,
#   'name': 'Photograph',
#   'artist(s)': ['Ed Sheeran'],
#   'genres': [['pop', 'uk pop']]},
#  {'danceability': 0.392,
#   'energy': 0.402,
#   'key': 0,
#   'loudness': -9.961,
#   'mode': 0,
#   'speechiness': 0.0536,
#   'acousticness': 0.288,
#   'instrumentalness': 0,
#   'liveness': 0.243,
#   'valence': 0.228,
#   'tempo': 143.883,
#   'duration_ms': 354320,
#   'time_signature': 4,
#   'name': 'Bohemian Rhapsody - Remastered 2011',
#   'artist(s)': ['Queen'],
#   'genres': [['classic rock', 'glam rock', 'rock']]},
#  {'danceability': 0.617,
#   'energy': 0.635,
#   'key': 11,
#   'loudness': -6.769,
#   'mode': 0,
#   'speechiness': 0.0317,
#   'acousticness': 0.0498,
#   'instrumentalness': 1.44e-05,
#   'liveness': 0.164,
#   'valence': 0.446,
#   'tempo': 103.019,
#   'duration_ms': 247160,
#   'time_signature': 4,
#   'name': 'Something Just Like This',
#   'artist(s)': ['The Chainsmokers', 'Coldplay'],
#   'genres': [['dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    ['permanent wave', 'pop']]},
#  {'danceability': 0.572,
#   'energy': 0.385,
#   'key': 7,
#   'loudness': -6.362,
#   'mode': 1,
#   'speechiness': 0.0308,
#   'acousticness': 0.371,
#   'instrumentalness': 0,
#   'liveness': 0.231,
#   'valence': 0.323,
#   'tempo': 95.799,
#   'duration_ms': 215733,
#   'time_signature': 4,
#   'name': 'Shallow',
#   'artist(s)': ['Lady Gaga', 'Bradley Cooper'],
#   'genres': [['art pop', 'dance pop', 'pop'], ['hollywood']]},
#  {'danceability': 0.609,
#   'energy': 0.378,
#   'key': 4,
#   'loudness': -9.828,
#   'mode': 1,
#   'speechiness': 0.438,
#   'acousticness': 0.835,
#   'instrumentalness': 0,
#   'liveness': 0.28,
#   'valence': 0.515,
#   'tempo': 100.418,
#   'duration_ms': 233720,
#   'time_signature': 4,
#   'name': 'Love Yourself',
#   'artist(s)': ['Justin Bieber'],
#   'genres': [['canadian pop', 'pop']]},
#  {'danceability': 0.74,
#   'energy': 0.613,
#   'key': 8,
#   'loudness': -4.88,
#   'mode': 1,
#   'speechiness': 0.145,
#   'acousticness': 0.258,
#   'instrumentalness': 0.00372,
#   'liveness': 0.123,
#   'valence': 0.473,
#   'tempo': 75.023,
#   'duration_ms': 166606,
#   'time_signature': 4,
#   'name': 'SAD!',
#   'artist(s)': ['XXXTENTACION'],
#   'genres': [['emo rap', 'miami hip hop']]},
#  {'danceability': 0.695,
#   'energy': 0.762,
#   'key': 0,
#   'loudness': -3.497,
#   'mode': 1,
#   'speechiness': 0.0395,
#   'acousticness': 0.192,
#   'instrumentalness': 0.00244,
#   'liveness': 0.0863,
#   'valence': 0.553,
#   'tempo': 120.042,
#   'duration_ms': 215280,
#   'time_signature': 4,
#   'name': 'Circles',
#   'artist(s)': ['Post Malone'],
#   'genres': [['dfw rap', 'melodic rap', 'rap']]},
#  {'danceability': 0.575,
#   'energy': 0.664,
#   'key': 4,
#   'loudness': -5.303,
#   'mode': 0,
#   'speechiness': 0.0481,
#   'acousticness': 0.637,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.437,
#   'tempo': 129.07,
#   'duration_ms': 241693,
#   'time_signature': 4,
#   'name': 'Take Me to Church',
#   'artist(s)': ['Hozier'],
#   'genres': [['irish singer-songwriter', 'pop']]},
#  {'danceability': 0.422,
#   'energy': 0.264,
#   'key': 8,
#   'loudness': -7.064,
#   'mode': 1,
#   'speechiness': 0.0322,
#   'acousticness': 0.922,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.331,
#   'tempo': 119.93,
#   'duration_ms': 269560,
#   'time_signature': 4,
#   'name': 'All of Me',
#   'artist(s)': ['John Legend'],
#   'genres': [['neo soul', 'pop', 'pop soul', 'r&b', 'urban contemporary']]},
#  {'danceability': 0.612,
#   'energy': 0.807,
#   'key': 10,
#   'loudness': -2.81,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.0495,
#   'instrumentalness': 0.0177,
#   'liveness': 0.101,
#   'valence': 0.398,
#   'tempo': 124.053,
#   'duration_ms': 240400,
#   'time_signature': 4,
#   'name': 'Sweater Weather',
#   'artist(s)': ['The Neighbourhood'],
#   'genres': [['modern alternative rock',
#     'modern rock',
#     'pop',
#     'shimmer pop']]},
#  {'danceability': 0.604,
#   'energy': 0.826,
#   'key': 0,
#   'loudness': -4.804,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.00782,
#   'instrumentalness': 0.15,
#   'liveness': 0.154,
#   'valence': 0.241,
#   'tempo': 167.985,
#   'duration_ms': 187147,
#   'time_signature': 4,
#   'name': 'Thunder',
#   'artist(s)': ['Imagine Dragons'],
#   'genres': [['modern rock', 'rock']]},
#  {'danceability': 0.778,
#   'energy': 0.317,
#   'key': 1,
#   'loudness': -10.732,
#   'mode': 0,
#   'speechiness': 0.334,
#   'acousticness': 0.592,
#   'instrumentalness': 0,
#   'liveness': 0.0881,
#   'valence': 0.327,
#   'tempo': 140.048,
#   'duration_ms': 178627,
#   'time_signature': 4,
#   'name': '7 rings',
#   'artist(s)': ['Ariana Grande'],
#   'genres': [['dance pop', 'pop']]},
#  {'danceability': 0.841,
#   'energy': 0.728,
#   'key': 7,
#   'loudness': -3.37,
#   'mode': 1,
#   'speechiness': 0.0484,
#   'acousticness': 0.0847,
#   'instrumentalness': 0,
#   'liveness': 0.149,
#   'valence': 0.43,
#   'tempo': 130.049,
#   'duration_ms': 243837,
#   'time_signature': 4,
#   'name': 'goosebumps',
#   'artist(s)': ['Travis Scott'],
#   'genres': [['rap', 'slap house']]},
#  {'danceability': 0.872,
#   'energy': 0.391,
#   'key': 0,
#   'loudness': -9.144,
#   'mode': 0,
#   'speechiness': 0.242,
#   'acousticness': 0.469,
#   'instrumentalness': 4.13e-06,
#   'liveness': 0.297,
#   'valence': 0.437,
#   'tempo': 134.021,
#   'duration_ms': 119133,
#   'time_signature': 4,
#   'name': 'Jocelyn Flores',
#   'artist(s)': ['XXXTENTACION'],
#   'genres': [['emo rap', 'miami hip hop']]},
#  {'danceability': 0.765,
#   'energy': 0.523,
#   'key': 2,
#   'loudness': -4.333,
#   'mode': 1,
#   'speechiness': 0.03,
#   'acousticness': 0.184,
#   'instrumentalness': 3.56e-05,
#   'liveness': 0.132,
#   'valence': 0.394,
#   'tempo': 104.988,
#   'duration_ms': 217307,
#   'time_signature': 4,
#   'name': 'Havana (feat. Young Thug)',
#   'artist(s)': ['Camila Cabello', 'Young Thug'],
#   'genres': [['dance pop', 'pop', 'post-teen pop'],
#    ['atl hip hop',
#     'atl trap',
#     'gangster rap',
#     'hip hop',
#     'melodic rap',
#     'pop rap',
#     'rap',
#     'southern hip hop',
#     'trap']]},
#  {'danceability': 0.734,
#   'energy': 0.637,
#   'key': 4,
#   'loudness': -5.677,
#   'mode': 0,
#   'speechiness': 0.141,
#   'acousticness': 0.0462,
#   'instrumentalness': 2.29e-05,
#   'liveness': 0.0602,
#   'valence': 0.648,
#   'tempo': 169.977,
#   'duration_ms': 202333,
#   'time_signature': 4,
#   'name': 'Stressed Out',
#   'artist(s)': ['Twenty One Pilots'],
#   'genres': [['modern rock', 'rock']]},
#  {'danceability': 0.732,
#   'energy': 0.75,
#   'key': 11,
#   'loudness': -6.366,
#   'mode': 0,
#   'speechiness': 0.231,
#   'acousticness': 0.00264,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.401,
#   'tempo': 155.096,
#   'duration_ms': 182707,
#   'time_signature': 4,
#   'name': 'XO Tour Llif3',
#   'artist(s)': ['Lil Uzi Vert'],
#   'genres': [['melodic rap', 'philly rap', 'rap', 'trap']]},
#  {'danceability': 0.762,
#   'energy': 0.7,
#   'key': 9,
#   'loudness': -6.021,
#   'mode': 0,
#   'speechiness': 0.0694,
#   'acousticness': 0.00261,
#   'instrumentalness': 1.56e-05,
#   'liveness': 0.153,
#   'valence': 0.608,
#   'tempo': 116.073,
#   'duration_ms': 209320,
#   'time_signature': 4,
#   'name': 'New Rules',
#   'artist(s)': ['Dua Lipa'],
#   'genres': [['dance pop', 'pop', 'uk pop']]},
#  {'danceability': 0.687,
#   'energy': 0.792,
#   'key': 5,
#   'loudness': -2.749,
#   'mode': 1,
#   'speechiness': 0.0452,
#   'acousticness': 0.191,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.671,
#   'tempo': 100.015,
#   'duration_ms': 214290,
#   'time_signature': 4,
#   'name': 'Happier',
#   'artist(s)': ['Marshmello', 'Bastille'],
#   'genres': [['brostep',
#     'dance pop',
#     'edm',
#     'pop',
#     'pop dance',
#     'progressive electro house'],
#    ['metropopolis', 'modern rock', 'pop', 'pop rock']]},
#  {'danceability': 0.663,
#   'energy': 0.712,
#   'key': 1,
#   'loudness': -4.945,
#   'mode': 0,
#   'speechiness': 0.0381,
#   'acousticness': 0.0649,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.48,
#   'tempo': 122.014,
#   'duration_ms': 257280,
#   'time_signature': 4,
#   'name': 'Counting Stars',
#   'artist(s)': ['OneRepublic'],
#   'genres': [['piano rock', 'pop']]},
#  {'danceability': 0.908,
#   'energy': 0.621,
#   'key': 1,
#   'loudness': -6.638,
#   'mode': 0,
#   'speechiness': 0.102,
#   'acousticness': 0.000282,
#   'instrumentalness': 5.39e-05,
#   'liveness': 0.0958,
#   'valence': 0.421,
#   'tempo': 150.011,
#   'duration_ms': 177000,
#   'time_signature': 4,
#   'name': 'HUMBLE.',
#   'artist(s)': ['Kendrick Lamar'],
#   'genres': [['conscious hip hop', 'hip hop', 'rap', 'west coast rap']]},
#  {'danceability': 0.516,
#   'energy': 0.806,
#   'key': 2,
#   'loudness': -5.133,
#   'mode': 1,
#   'speechiness': 0.0538,
#   'acousticness': 0.00389,
#   'instrumentalness': 0.000674,
#   'liveness': 0.115,
#   'valence': 0.577,
#   'tempo': 124.118,
#   'duration_ms': 249693,
#   'time_signature': 4,
#   'name': 'Wake Me Up',
#   'artist(s)': ['Avicii'],
#   'genres': [['dance pop', 'edm', 'pop', 'pop dance', 'pop rap']]},
#  {'danceability': 0.479,
#   'energy': 0.545,
#   'key': 7,
#   'loudness': -7.346,
#   'mode': 1,
#   'speechiness': 0.0688,
#   'acousticness': 0.365,
#   'instrumentalness': 0,
#   'liveness': 0.0963,
#   'valence': 0.244,
#   'tempo': 74.897,
#   'duration_ms': 252733,
#   'time_signature': 4,
#   'name': 'Let Her Go',
#   'artist(s)': ['Passenger'],
#   'genres': [['folk-pop', 'neo mellow']]},
#  {'danceability': 0.834,
#   'energy': 0.73,
#   'key': 8,
#   'loudness': -3.714,
#   'mode': 1,
#   'speechiness': 0.222,
#   'acousticness': 0.00513,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.446,
#   'tempo': 155.008,
#   'duration_ms': 312820,
#   'time_signature': 4,
#   'name': 'SICKO MODE',
#   'artist(s)': ['Travis Scott'],
#   'genres': [['rap', 'slap house']]},
#  {'danceability': 0.52,
#   'energy': 0.731,
#   'key': 6,
#   'loudness': -5.338,
#   'mode': 0,
#   'speechiness': 0.0557,
#   'acousticness': 0.342,
#   'instrumentalness': 0.00101,
#   'liveness': 0.311,
#   'valence': 0.662,
#   'tempo': 173.93,
#   'duration_ms': 167303,
#   'time_signature': 4,
#   'name': 'As It Was',
#   'artist(s)': ['Harry Styles'],
#   'genres': [['pop']]},
#  {'danceability': 0.484,
#   'energy': 0.731,
#   'key': 1,
#   'loudness': -6.694,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.431,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.51,
#   'tempo': 101.654,
#   'duration_ms': 204280,
#   'time_signature': 4,
#   'name': 'Riptide',
#   'artist(s)': ['Vance Joy'],
#   'genres': [['folk-pop', 'pop']]},
#  {'danceability': 0.356,
#   'energy': 0.567,
#   'key': 0,
#   'loudness': -7.011,
#   'mode': 0,
#   'speechiness': 0.0798,
#   'acousticness': 0.0861,
#   'instrumentalness': 0,
#   'liveness': 0.137,
#   'valence': 0.109,
#   'tempo': 135.553,
#   'duration_ms': 242253,
#   'time_signature': 5,
#   'name': 'The Hills',
#   'artist(s)': ['The Weeknd'],
#   'genres': [['canadian contemporary r&b', 'canadian pop', 'pop']]},
#  {'danceability': 0.654,
#   'energy': 0.76,
#   'key': 0,
#   'loudness': -3.669,
#   'mode': 0,
#   'speechiness': 0.045,
#   'acousticness': 0.0797,
#   'instrumentalness': 0,
#   'liveness': 0.299,
#   'valence': 0.41,
#   'tempo': 99.945,
#   'duration_ms': 200787,
#   'time_signature': 4,
#   'name': 'Sorry',
#   'artist(s)': ['Justin Bieber'],
#   'genres': [['canadian pop', 'pop']]},
#  {'danceability': 0.641,
#   'energy': 0.922,
#   'key': 2,
#   'loudness': -4.457,
#   'mode': 1,
#   'speechiness': 0.0786,
#   'acousticness': 0.0291,
#   'instrumentalness': 0,
#   'liveness': 0.0862,
#   'valence': 0.847,
#   'tempo': 146.078,
#   'duration_ms': 258343,
#   'time_signature': 4,
#   'name': "Can't Hold Us (feat. Ray Dalton)",
#   'artist(s)': ['Macklemore & Ryan Lewis',
#    'Macklemore',
#    'Ryan Lewis',
#    'Ray Dalton'],
#   'genres': [['dance pop', 'pop', 'pop rap', 'seattle hip hop'],
#    ['pop rap', 'seattle hip hop'],
#    [],
#    []]},
#  {'danceability': 0.563,
#   'energy': 0.664,
#   'key': 9,
#   'loudness': -5.044,
#   'mode': 1,
#   'speechiness': 0.154,
#   'acousticness': 0.335,
#   'instrumentalness': 0,
#   'liveness': 0.0849,
#   'valence': 0.688,
#   'tempo': 166.928,
#   'duration_ms': 178147,
#   'time_signature': 4,
#   'name': 'good 4 u',
#   'artist(s)': ['Olivia Rodrigo'],
#   'genres': [['pop']]},
#  {'danceability': 0.649,
#   'energy': 0.716,
#   'key': 8,
#   'loudness': -5.371,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.0863,
#   'instrumentalness': 2.63e-05,
#   'liveness': 0.135,
#   'valence': 0.163,
#   'tempo': 99.988,
#   'duration_ms': 205947,
#   'time_signature': 4,
#   'name': 'Let Me Love You',
#   'artist(s)': ['DJ Snake', 'Justin Bieber'],
#   'genres': [['dance pop',
#     'edm',
#     'electronic trap',
#     'pop',
#     'pop dance',
#     'pop rap'],
#    ['canadian pop', 'pop']]},
#  {'danceability': 0.723,
#   'energy': 0.809,
#   'key': 7,
#   'loudness': -3.081,
#   'mode': 0,
#   'speechiness': 0.0625,
#   'acousticness': 0.00346,
#   'instrumentalness': 0.00123,
#   'liveness': 0.565,
#   'valence': 0.274,
#   'tempo': 98.007,
#   'duration_ms': 176561,
#   'time_signature': 4,
#   'name': 'Lean On (feat. MØ & DJ Snake)',
#   'artist(s)': ['Major Lazer', 'MØ', 'DJ Snake'],
#   'genres': [['dance pop',
#     'edm',
#     'electro house',
#     'moombahton',
#     'pop',
#     'pop dance',
#     'pop rap',
#     'tropical house'],
#    ['dance pop',
#     'danish pop',
#     'electropop',
#     'indie poptimism',
#     'pop',
#     'tropical house'],
#    ['dance pop', 'edm', 'electronic trap', 'pop', 'pop dance', 'pop rap']]},
#  {'danceability': 0.785,
#   'energy': 0.721,
#   'key': 8,
#   'loudness': -5.457,
#   'mode': 1,
#   'speechiness': 0.0506,
#   'acousticness': 0.0149,
#   'instrumentalness': 0.00432,
#   'liveness': 0.285,
#   'valence': 0.894,
#   'tempo': 121.962,
#   'duration_ms': 176219,
#   'time_signature': 4,
#   'name': 'Roses - Imanbek Remix',
#   'artist(s)': ['SAINt JHN', 'Imanbek'],
#   'genres': [['melodic rap', 'rap', 'slap house'],
#    ['dance pop',
#     'edm',
#     'electro house',
#     'pop dance',
#     'slap house',
#     'tropical house']]},
#  {'danceability': 0.791,
#   'energy': 0.862,
#   'key': 9,
#   'loudness': -3.24,
#   'mode': 0,
#   'speechiness': 0.11,
#   'acousticness': 0.037,
#   'instrumentalness': 2.19e-05,
#   'liveness': 0.0814,
#   'valence': 0.592,
#   'tempo': 123.994,
#   'duration_ms': 214847,
#   'time_signature': 4,
#   'name': 'One Kiss (with Dua Lipa)',
#   'artist(s)': ['Calvin Harris', 'Dua Lipa'],
#   'genres': [['dance pop',
#     'edm',
#     'electro house',
#     'house',
#     'pop',
#     'progressive house',
#     'uk dance'],
#    ['dance pop', 'pop', 'uk pop']]},
#  {'danceability': 0.68,
#   'energy': 0.578,
#   'key': 10,
#   'loudness': -5.804,
#   'mode': 1,
#   'speechiness': 0.04,
#   'acousticness': 0.331,
#   'instrumentalness': 0,
#   'liveness': 0.135,
#   'valence': 0.341,
#   'tempo': 145.038,
#   'duration_ms': 231267,
#   'time_signature': 4,
#   'name': 'Better Now',
#   'artist(s)': ['Post Malone'],
#   'genres': [['dfw rap', 'melodic rap', 'rap']]},
#  {'danceability': 0.561,
#   'energy': 0.431,
#   'key': 10,
#   'loudness': -8.81,
#   'mode': 1,
#   'speechiness': 0.0578,
#   'acousticness': 0.768,
#   'instrumentalness': 1.42e-05,
#   'liveness': 0.106,
#   'valence': 0.137,
#   'tempo': 143.875,
#   'duration_ms': 242013,
#   'time_signature': 4,
#   'name': 'drivers license',
#   'artist(s)': ['Olivia Rodrigo'],
#   'genres': [['pop']]},
#  {'danceability': 0.455,
#   'energy': 0.797,
#   'key': 10,
#   'loudness': -4.133,
#   'mode': 0,
#   'speechiness': 0.36,
#   'acousticness': 0.132,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.757,
#   'tempo': 165.717,
#   'duration_ms': 187973,
#   'time_signature': 4,
#   'name': 'Treat You Better',
#   'artist(s)': ['Shawn Mendes'],
#   'genres': [['canadian pop', 'dance pop', 'pop', 'viral pop']]},
#  {'danceability': 0.63,
#   'energy': 0.804,
#   'key': 6,
#   'loudness': -4.183,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.215,
#   'instrumentalness': 0,
#   'liveness': 0.253,
#   'valence': 0.492,
#   'tempo': 123.146,
#   'duration_ms': 220293,
#   'time_signature': 4,
#   'name': 'Congratulations',
#   'artist(s)': ['Post Malone', 'Quavo'],
#   'genres': [['dfw rap', 'melodic rap', 'rap'],
#    ['atl hip hop',
#     'hip hop',
#     'melodic rap',
#     'rap',
#     'southern hip hop',
#     'trap']]},
#  {'danceability': 0.589,
#   'energy': 0.651,
#   'key': 6,
#   'loudness': -5.097,
#   'mode': 1,
#   'speechiness': 0.0306,
#   'acousticness': 0.0291,
#   'instrumentalness': 3.2e-06,
#   'liveness': 0.111,
#   'valence': 0.166,
#   'tempo': 90.011,
#   'duration_ms': 212627,
#   'time_signature': 4,
#   'name': 'Faded',
#   'artist(s)': ['Alan Walker'],
#   'genres': [['electro house']]},
#  {'danceability': 0.418,
#   'energy': 0.42,
#   'key': 0,
#   'loudness': -6.444,
#   'mode': 1,
#   'speechiness': 0.0414,
#   'acousticness': 0.588,
#   'instrumentalness': 6.39e-05,
#   'liveness': 0.11,
#   'valence': 0.184,
#   'tempo': 84.094,
#   'duration_ms': 172724,
#   'time_signature': 4,
#   'name': 'Stay With Me',
#   'artist(s)': ['Sam Smith'],
#   'genres': [['pop', 'uk pop']]},
#  {'danceability': 0.752,
#   'energy': 0.488,
#   'key': 6,
#   'loudness': -7.05,
#   'mode': 1,
#   'speechiness': 0.0705,
#   'acousticness': 0.297,
#   'instrumentalness': 9.11e-06,
#   'liveness': 0.0936,
#   'valence': 0.533,
#   'tempo': 136.041,
#   'duration_ms': 201661,
#   'time_signature': 4,
#   'name': 'Without Me',
#   'artist(s)': ['Halsey'],
#   'genres': [['dance pop',
#     'electropop',
#     'etherpop',
#     'indie poptimism',
#     'pop']]},
#  {'danceability': 0.534,
#   'energy': 0.868,
#   'key': 11,
#   'loudness': -5.057,
#   'mode': 1,
#   'speechiness': 0.205,
#   'acousticness': 0.187,
#   'instrumentalness': 0.0032,
#   'liveness': 0.148,
#   'valence': 0.406,
#   'tempo': 159.763,
#   'duration_ms': 208667,
#   'time_signature': 4,
#   'name': "Don't Let Me Down",
#   'artist(s)': ['The Chainsmokers', 'Daya'],
#   'genres': [['dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    ['alt z',
#     'dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'post-teen pop',
#     'tropical house']]},
#  {'danceability': 0.856,
#   'energy': 0.609,
#   'key': 0,
#   'loudness': -7.223,
#   'mode': 1,
#   'speechiness': 0.0824,
#   'acousticness': 0.00801,
#   'instrumentalness': 8.15e-05,
#   'liveness': 0.0344,
#   'valence': 0.928,
#   'tempo': 114.988,
#   'duration_ms': 269667,
#   'time_signature': 4,
#   'name': 'Uptown Funk (feat. Bruno Mars)',
#   'artist(s)': ['Mark Ronson', 'Bruno Mars'],
#   'genres': [['dance pop', 'pop'], ['dance pop', 'pop']]},
#  {'danceability': 0.664,
#   'energy': 0.714,
#   'key': 7,
#   'loudness': -6.645,
#   'mode': 0,
#   'speechiness': 0.111,
#   'acousticness': 0.0353,
#   'instrumentalness': 8.42e-06,
#   'liveness': 0.0843,
#   'valence': 0.71,
#   'tempo': 101.969,
#   'duration_ms': 197933,
#   'time_signature': 4,
#   'name': 'I Took A Pill In Ibiza - Seeb Remix',
#   'artist(s)': ['Mike Posner', 'Seeb'],
#   'genres': [['dance pop', 'edm', 'pop', 'pop rap'],
#    ['dance pop',
#     'edm',
#     'electro house',
#     'norwegian pop',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'tropical house']]},
#  {'danceability': 0.741,
#   'energy': 0.691,
#   'key': 10,
#   'loudness': -7.395,
#   'mode': 0,
#   'speechiness': 0.0672,
#   'acousticness': 0.0221,
#   'instrumentalness': 0,
#   'liveness': 0.0476,
#   'valence': 0.892,
#   'tempo': 150.087,
#   'duration_ms': 212353,
#   'time_signature': 4,
#   'name': 'INDUSTRY BABY (feat. Jack Harlow)',
#   'artist(s)': ['Lil Nas X', 'Jack Harlow'],
#   'genres': [['lgbtq+ hip hop', 'pop'],
#    ['deep underground hip hop', 'kentucky hip hop', 'pop', 'rap']]},
#  {'danceability': 0.775,
#   'energy': 0.327,
#   'key': 11,
#   'loudness': -7.241,
#   'mode': 1,
#   'speechiness': 0.0557,
#   'acousticness': 0.841,
#   'instrumentalness': 0,
#   'liveness': 0.0821,
#   'valence': 0.595,
#   'tempo': 91.05,
#   'duration_ms': 189486,
#   'time_signature': 4,
#   'name': 'Memories',
#   'artist(s)': ['Maroon 5'],
#   'genres': [['pop']]},
#  {'danceability': 0.681,
#   'energy': 0.372,
#   'key': 5,
#   'loudness': -8.237,
#   'mode': 1,
#   'speechiness': 0.0432,
#   'acousticness': 0.64,
#   'instrumentalness': 0,
#   'liveness': 0.169,
#   'valence': 0.476,
#   'tempo': 91.873,
#   'duration_ms': 201000,
#   'time_signature': 4,
#   'name': 'Too Good At Goodbyes',
#   'artist(s)': ['Sam Smith'],
#   'genres': [['pop', 'uk pop']]},
#  {'danceability': 0.798,
#   'energy': 0.676,
#   'key': 6,
#   'loudness': -5.041,
#   'mode': 1,
#   'speechiness': 0.0442,
#   'acousticness': 0.0902,
#   'instrumentalness': 0,
#   'liveness': 0.0894,
#   'valence': 0.843,
#   'tempo': 101.956,
#   'duration_ms': 219947,
#   'time_signature': 4,
#   'name': "I Don't Care (with Justin Bieber)",
#   'artist(s)': ['Ed Sheeran', 'Justin Bieber'],
#   'genres': [['pop', 'uk pop'], ['canadian pop', 'pop']]},
#  {'danceability': 0.356,
#   'energy': 0.924,
#   'key': 1,
#   'loudness': -3.74,
#   'mode': 1,
#   'speechiness': 0.0808,
#   'acousticness': 0.00101,
#   'instrumentalness': 0,
#   'liveness': 0.0953,
#   'valence': 0.232,
#   'tempo': 148.017,
#   'duration_ms': 222587,
#   'time_signature': 4,
#   'name': 'Mr. Brightside',
#   'artist(s)': ['The Killers'],
#   'genres': [['alternative rock', 'dance rock', 'permanent wave', 'rock']]},
#  {'danceability': 0.717,
#   'energy': 0.653,
#   'key': 1,
#   'loudness': -5.634,
#   'mode': 1,
#   'speechiness': 0.0658,
#   'acousticness': 0.229,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.412,
#   'tempo': 106.966,
#   'duration_ms': 207320,
#   'time_signature': 4,
#   'name': 'thank u, next',
#   'artist(s)': ['Ariana Grande'],
#   'genres': [['dance pop', 'pop']]},
#  {'danceability': 0.505,
#   'energy': 0.71,
#   'key': 3,
#   'loudness': -3.015,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.19,
#   'instrumentalness': 0.00025,
#   'liveness': 0.329,
#   'valence': 0.428,
#   'tempo': 89.938,
#   'duration_ms': 175200,
#   'time_signature': 4,
#   'name': 'Demons',
#   'artist(s)': ['Imagine Dragons'],
#   'genres': [['modern rock', 'rock']]},
#  {'danceability': 0.692,
#   'energy': 0.744,
#   'key': 2,
#   'loudness': -4.565,
#   'mode': 1,
#   'speechiness': 0.257,
#   'acousticness': 0.00868,
#   'instrumentalness': 0.000423,
#   'liveness': 0.359,
#   'valence': 0.0612,
#   'tempo': 171.374,
#   'duration_ms': 326467,
#   'time_signature': 4,
#   'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#   'artist(s)': ['Eminem'],
#   'genres': [['detroit hip hop', 'hip hop', 'rap']]},
#  {'danceability': 0.702,
#   'energy': 0.825,
#   'key': 6,
#   'loudness': -3.787,
#   'mode': 0,
#   'speechiness': 0.0601,
#   'acousticness': 0.00883,
#   'instrumentalness': 0,
#   'liveness': 0.0674,
#   'valence': 0.915,
#   'tempo': 102.977,
#   'duration_ms': 203064,
#   'time_signature': 4,
#   'name': 'Levitating (feat. DaBaby)',
#   'artist(s)': ['Dua Lipa', 'DaBaby'],
#   'genres': [['dance pop', 'pop', 'uk pop'],
#    ['north carolina hip hop', 'rap', 'trap']]},
#  {'danceability': 0.593,
#   'energy': 0.503,
#   'key': 8,
#   'loudness': -6.725,
#   'mode': 0,
#   'speechiness': 0.22,
#   'acousticness': 0.293,
#   'instrumentalness': 0,
#   'liveness': 0.405,
#   'valence': 0.71,
#   'tempo': 178.781,
#   'duration_ms': 137704,
#   'time_signature': 4,
#   'name': 'MONTERO (Call Me By Your Name)',
#   'artist(s)': ['Lil Nas X'],
#   'genres': [['lgbtq+ hip hop', 'pop']]},
#  {'danceability': 0.731,
#   'energy': 0.573,
#   'key': 4,
#   'loudness': -10.059,
#   'mode': 0,
#   'speechiness': 0.0544,
#   'acousticness': 0.401,
#   'instrumentalness': 5.22e-05,
#   'liveness': 0.113,
#   'valence': 0.145,
#   'tempo': 109.928,
#   'duration_ms': 205090,
#   'time_signature': 4,
#   'name': 'DÁKITI',
#   'artist(s)': ['Bad Bunny', 'Jhayco'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino'],
#    ['reggaeton', 'trap latino', 'urbano latino']]},
#  {'danceability': 0.701,
#   'energy': 0.716,
#   'key': 7,
#   'loudness': -3.671,
#   'mode': 0,
#   'speechiness': 0.0361,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.324,
#   'valence': 0.732,
#   'tempo': 91.007,
#   'duration_ms': 140533,
#   'time_signature': 4,
#   'name': 'Mood (feat. iann dior)',
#   'artist(s)': ['24kGoldn', 'iann dior'],
#   'genres': [['cali rap', 'pop', 'pop rap', 'rap'],
#    ['melodic rap', 'pop', 'pop rap', 'rap']]},
#  {'danceability': 0.653,
#   'energy': 0.816,
#   'key': 2,
#   'loudness': -4.353,
#   'mode': 1,
#   'speechiness': 0.167,
#   'acousticness': 0.228,
#   'instrumentalness': 0,
#   'liveness': 0.0967,
#   'valence': 0.816,
#   'tempo': 178.085,
#   'duration_ms': 228827,
#   'time_signature': 4,
#   'name': 'Despacito - Remix',
#   'artist(s)': ['Luis Fonsi', 'Daddy Yankee', 'Justin Bieber'],
#   'genres': [['latin pop', 'puerto rican pop'],
#    ['latin hip hop', 'reggaeton', 'urbano latino'],
#    ['canadian pop', 'pop']]},
#  {'danceability': 0.726,
#   'energy': 0.769,
#   'key': 6,
#   'loudness': -5.043,
#   'mode': 1,
#   'speechiness': 0.123,
#   'acousticness': 0.0293,
#   'instrumentalness': 0.0101,
#   'liveness': 0.104,
#   'valence': 0.733,
#   'tempo': 97.985,
#   'duration_ms': 233902,
#   'time_signature': 4,
#   'name': 'Unforgettable',
#   'artist(s)': ['French Montana', 'Swae Lee'],
#   'genres': [['gangster rap',
#     'hip hop',
#     'pop rap',
#     'rap',
#     'southern hip hop',
#     'trap'],
#    ['melodic rap', 'trap']]},
#  {'danceability': 0.921,
#   'energy': 0.537,
#   'key': 9,
#   'loudness': -5.723,
#   'mode': 0,
#   'speechiness': 0.0804,
#   'acousticness': 0.556,
#   'instrumentalness': 0.00404,
#   'liveness': 0.102,
#   'valence': 0.711,
#   'tempo': 128.009,
#   'duration_ms': 135090,
#   'time_signature': 4,
#   'name': 'Moonlight',
#   'artist(s)': ['XXXTENTACION'],
#   'genres': [['emo rap', 'miami hip hop']]},
#  {'danceability': 0.746,
#   'energy': 0.765,
#   'key': 6,
#   'loudness': -4.41,
#   'mode': 0,
#   'speechiness': 0.0993,
#   'acousticness': 0.0112,
#   'instrumentalness': 0,
#   'liveness': 0.0936,
#   'valence': 0.737,
#   'tempo': 114.044,
#   'duration_ms': 199054,
#   'time_signature': 4,
#   'name': 'Dynamite',
#   'artist(s)': ['BTS'],
#   'genres': [['k-pop', 'k-pop boy group']]},
#  {'danceability': 0.548,
#   'energy': 0.532,
#   'key': 5,
#   'loudness': -7.596,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.186,
#   'instrumentalness': 0.000263,
#   'liveness': 0.217,
#   'valence': 0.405,
#   'tempo': 85.03,
#   'duration_ms': 272394,
#   'time_signature': 4,
#   'name': 'Do I Wanna Know?',
#   'artist(s)': ['Arctic Monkeys'],
#   'genres': [['garage rock',
#     'modern rock',
#     'permanent wave',
#     'rock',
#     'sheffield indie']]},
#  {'danceability': 0.896,
#   'energy': 0.586,
#   'key': 10,
#   'loudness': -6.687,
#   'mode': 0,
#   'speechiness': 0.0559,
#   'acousticness': 0.104,
#   'instrumentalness': 0,
#   'liveness': 0.79,
#   'valence': 0.642,
#   'tempo': 116.971,
#   'duration_ms': 196653,
#   'time_signature': 4,
#   'name': 'The Box',
#   'artist(s)': ['Roddy Ricch'],
#   'genres': [['melodic rap', 'rap', 'trap']]},
#  {'danceability': 0.372,
#   'energy': 0.865,
#   'key': 2,
#   'loudness': -4.918,
#   'mode': 1,
#   'speechiness': 0.0381,
#   'acousticness': 0.000453,
#   'instrumentalness': 0,
#   'liveness': 0.234,
#   'valence': 0.478,
#   'tempo': 174.53,
#   'duration_ms': 258733,
#   'time_signature': 4,
#   'name': 'Wonderwall - Remastered',
#   'artist(s)': ['Oasis'],
#   'genres': [['beatlesque',
#     'britpop',
#     'madchester',
#     'permanent wave',
#     'pop rock',
#     'rock']]},
#  {'danceability': 0.853,
#   'energy': 0.56,
#   'key': 1,
#   'loudness': -4.961,
#   'mode': 1,
#   'speechiness': 0.0406,
#   'acousticness': 0.013,
#   'instrumentalness': 0,
#   'liveness': 0.0944,
#   'valence': 0.86,
#   'tempo': 134.066,
#   'duration_ms': 206693,
#   'time_signature': 4,
#   'name': "That's What I Like",
#   'artist(s)': ['Bruno Mars'],
#   'genres': [['dance pop', 'pop']]},
#  {'danceability': 0.628,
#   'energy': 0.698,
#   'key': 6,
#   'loudness': -5.608,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.0472,
#   'instrumentalness': 0.00143,
#   'liveness': 0.0907,
#   'valence': 0.732,
#   'tempo': 89.976,
#   'duration_ms': 211667,
#   'time_signature': 4,
#   'name': 'Cheap Thrills',
#   'artist(s)': ['Sia'],
#   'genres': [['australian dance', 'australian pop', 'pop']]},
#  {'danceability': 0.866,
#   'energy': 0.813,
#   'key': 11,
#   'loudness': -4.063,
#   'mode': 0,
#   'speechiness': 0.0554,
#   'acousticness': 0.38,
#   'instrumentalness': 0,
#   'liveness': 0.0779,
#   'valence': 0.969,
#   'tempo': 121.998,
#   'duration_ms': 199440,
#   'time_signature': 4,
#   'name': "There's Nothing Holdin' Me Back",
#   'artist(s)': ['Shawn Mendes'],
#   'genres': [['canadian pop', 'dance pop', 'pop', 'viral pop']]},
#  {'danceability': 0.548,
#   'energy': 0.847,
#   'key': 1,
#   'loudness': -3.237,
#   'mode': 1,
#   'speechiness': 0.186,
#   'acousticness': 0.0622,
#   'instrumentalness': 0,
#   'liveness': 0.0816,
#   'valence': 0.1,
#   'tempo': 171.447,
#   'duration_ms': 297787,
#   'time_signature': 4,
#   'name': 'Till I Collapse',
#   'artist(s)': ['Eminem', 'Nate Dogg'],
#   'genres': [['detroit hip hop', 'hip hop', 'rap'],
#    ['g funk', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'west coast rap']]},
#  {'danceability': 0.746,
#   'energy': 0.754,
#   'key': 1,
#   'loudness': -6.684,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'acousticness': 0.0152,
#   'instrumentalness': 0,
#   'liveness': 0.0486,
#   'valence': 0.746,
#   'tempo': 149.882,
#   'duration_ms': 206880,
#   'time_signature': 4,
#   'name': 'Stitches',
#   'artist(s)': ['Shawn Mendes'],
#   'genres': [['canadian pop', 'dance pop', 'pop', 'viral pop']]},
#  {'danceability': 0.692,
#   'energy': 0.521,
#   'key': 10,
#   'loudness': -8.465,
#   'mode': 0,
#   'speechiness': 0.33,
#   'acousticness': 0.301,
#   'instrumentalness': 0,
#   'liveness': 0.0565,
#   'valence': 0.463,
#   'tempo': 100.45,
#   'duration_ms': 292987,
#   'time_signature': 4,
#   'name': 'No Role Modelz',
#   'artist(s)': ['J. Cole'],
#   'genres': [['conscious hip hop',
#     'hip hop',
#     'north carolina hip hop',
#     'rap']]},
#  {'danceability': 0.689,
#   'energy': 0.481,
#   'key': 10,
#   'loudness': -7.503,
#   'mode': 1,
#   'speechiness': 0.0815,
#   'acousticness': 0.369,
#   'instrumentalness': 1.03e-06,
#   'liveness': 0.0649,
#   'valence': 0.283,
#   'tempo': 80.025,
#   'duration_ms': 229526,
#   'time_signature': 4,
#   'name': 'See You Again (feat. Charlie Puth)',
#   'artist(s)': ['Wiz Khalifa', 'Charlie Puth'],
#   'genres': [['dance pop',
#     'hip hop',
#     'pittsburgh rap',
#     'pop rap',
#     'rap',
#     'southern hip hop',
#     'trap'],
#    ['dance pop', 'pop', 'viral pop']]},
#  {'danceability': 0.752,
#   'energy': 0.505,
#   'key': 9,
#   'loudness': -7.621,
#   'mode': 1,
#   'speechiness': 0.253,
#   'acousticness': 0.535,
#   'instrumentalness': 2.55e-06,
#   'liveness': 0.104,
#   'valence': 0.419,
#   'tempo': 91.97,
#   'duration_ms': 197437,
#   'time_signature': 4,
#   'name': 'I Like Me Better',
#   'artist(s)': ['Lauv'],
#   'genres': [['dance pop', 'electropop', 'pop']]},
#  {'danceability': 0.765,
#   'energy': 0.473,
#   'key': 10,
#   'loudness': -5.829,
#   'mode': 1,
#   'speechiness': 0.0514,
#   'acousticness': 0.287,
#   'instrumentalness': 0,
#   'liveness': 0.391,
#   'valence': 0.34,
#   'tempo': 119.992,
#   'duration_ms': 237300,
#   'time_signature': 4,
#   'name': '7 Years',
#   'artist(s)': ['Lukas Graham'],
#   'genres': [['danish pop', 'pop', 'scandipop']]},
#  {'danceability': 0.703,
#   'energy': 0.444,
#   'key': 11,
#   'loudness': -9.331,
#   'mode': 1,
#   'speechiness': 0.0417,
#   'acousticness': 0.559,
#   'instrumentalness': 0,
#   'liveness': 0.0973,
#   'valence': 0.712,
#   'tempo': 150.96,
#   'duration_ms': 242947,
#   'time_signature': 4,
#   'name': "I'm Yours",
#   'artist(s)': ['Jason Mraz'],
#   'genres': [['acoustic pop', 'neo mellow', 'pop', 'pop rock']]},
#  {'danceability': 0.502,
#   'energy': 0.912,
#   'key': 1,
#   'loudness': -4.556,
#   'mode': 1,
#   'speechiness': 0.0564,
#   'acousticness': 2.55e-05,
#   'instrumentalness': 0.000173,
#   'liveness': 0.106,
#   'valence': 0.72,
#   'tempo': 116.761,
#   'duration_ms': 301920,
#   'time_signature': 4,
#   'name': 'Smells Like Teen Spirit',
#   'artist(s)': ['Nirvana'],
#   'genres': [['alternative rock', 'grunge', 'permanent wave', 'rock']]},
#  {'danceability': 0.851,
#   'energy': 0.541,
#   'key': 0,
#   'loudness': -6.825,
#   'mode': 1,
#   'speechiness': 0.0505,
#   'acousticness': 0.568,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.448,
#   'tempo': 124.959,
#   'duration_ms': 235545,
#   'time_signature': 4,
#   'name': 'Girls Like You (feat. Cardi B) - Cardi B Version',
#   'artist(s)': ['Maroon 5', 'Cardi B'],
#   'genres': [['pop'], ['dance pop', 'pop', 'rap']]},
#  {'danceability': 0.655,
#   'energy': 0.797,
#   'key': 2,
#   'loudness': -4.787,
#   'mode': 1,
#   'speechiness': 0.153,
#   'acousticness': 0.198,
#   'instrumentalness': 0,
#   'liveness': 0.067,
#   'valence': 0.839,
#   'tempo': 177.928,
#   'duration_ms': 229360,
#   'time_signature': 4,
#   'name': 'Despacito',
#   'artist(s)': ['Luis Fonsi', 'Daddy Yankee'],
#   'genres': [['latin pop', 'puerto rican pop'],
#    ['latin hip hop', 'reggaeton', 'urbano latino']]},
#  {'danceability': 0.748,
#   'energy': 0.788,
#   'key': 1,
#   'loudness': -7.055,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.0591,
#   'instrumentalness': 0,
#   'liveness': 0.0863,
#   'valence': 0.884,
#   'tempo': 120.076,
#   'duration_ms': 235493,
#   'time_signature': 4,
#   'name': 'Sugar',
#   'artist(s)': ['Maroon 5'],
#   'genres': [['pop']]},
#  {'danceability': 0.746,
#   'energy': 0.69,
#   'key': 11,
#   'loudness': -7.956,
#   'mode': 1,
#   'speechiness': 0.164,
#   'acousticness': 0.247,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.497,
#   'tempo': 89.977,
#   'duration_ms': 181733,
#   'time_signature': 4,
#   'name': 'ROCKSTAR (feat. Roddy Ricch)',
#   'artist(s)': ['DaBaby', 'Roddy Ricch'],
#   'genres': [['north carolina hip hop', 'rap', 'trap'],
#    ['melodic rap', 'rap', 'trap']]},
#  {'danceability': 0.596,
#   'energy': 0.854,
#   'key': 7,
#   'loudness': -5.114,
#   'mode': 0,
#   'speechiness': 0.463,
#   'acousticness': 0.0169,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.152,
#   'tempo': 120.274,
#   'duration_ms': 203418,
#   'time_signature': 4,
#   'name': 'Youngblood',
#   'artist(s)': ['5 Seconds of Summer'],
#   'genres': [['boy band', 'dance pop', 'pop', 'post-teen pop']]},
#  {'danceability': 0.669,
#   'energy': 0.832,
#   'key': 0,
#   'loudness': -5.721,
#   'mode': 1,
#   'speechiness': 0.0682,
#   'acousticness': 0.0106,
#   'instrumentalness': 0,
#   'liveness': 0.0968,
#   'valence': 0.7,
#   'tempo': 113.035,
#   'duration_ms': 237547,
#   'time_signature': 4,
#   'name': 'CAN\'T STOP THE FEELING! (from DreamWorks Animation\'s "TROLLS")',
#   'artist(s)': ['Justin Timberlake'],
#   'genres': [['dance pop', 'pop']]},
#  {'danceability': 0.732,
#   'energy': 0.396,
#   'key': 4,
#   'loudness': -9.348,
#   'mode': 0,
#   'speechiness': 0.0286,
#   'acousticness': 0.0841,
#   'instrumentalness': 3.58e-05,
#   'liveness': 0.105,
#   'valence': 0.548,
#   'tempo': 90.024,
#   'duration_ms': 195920,
#   'time_signature': 4,
#   'name': 'Heathens',
#   'artist(s)': ['Twenty One Pilots'],
#   'genres': [['modern rock', 'rock']]},
#  {'danceability': 0.367,
#   'energy': 0.111,
#   'key': 4,
#   'loudness': -14.084,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.978,
#   'instrumentalness': 3.97e-05,
#   'liveness': 0.0897,
#   'valence': 0.198,
#   'tempo': 82.642,
#   'duration_ms': 196077,
#   'time_signature': 4,
#   'name': "when the party's over",
#   'artist(s)': ['Billie Eilish'],
#   'genres': [['art pop', 'electropop', 'pop']]},
#  {'danceability': 0.448,
#   'energy': 0.784,
#   'key': 9,
#   'loudness': -3.686,
#   'mode': 1,
#   'speechiness': 0.0627,
#   'acousticness': 0.106,
#   'instrumentalness': 0.000108,
#   'liveness': 0.668,
#   'valence': 0.236,
#   'tempo': 136.245,
#   'duration_ms': 186813,
#   'time_signature': 4,
#   'name': 'Radioactive',
#   'artist(s)': ['Imagine Dragons'],
#   'genres': [['modern rock', 'rock']]},
#  {'danceability': 0.556,
#   'energy': 0.538,
#   'key': 8,
#   'loudness': -5.408,
#   'mode': 0,
#   'speechiness': 0.0382,
#   'acousticness': 0.0689,
#   'instrumentalness': 0,
#   'liveness': 0.196,
#   'valence': 0.291,
#   'tempo': 143.95,
#   'duration_ms': 223347,
#   'time_signature': 4,
#   'name': 'I Fall Apart',
#   'artist(s)': ['Post Malone'],
#   'genres': [['dfw rap', 'melodic rap', 'rap']]},
#  {'danceability': 0.728,
#   'energy': 0.563,
#   'key': 1,
#   'loudness': -8.053,
#   'mode': 0,
#   'speechiness': 0.134,
#   'acousticness': 0.621,
#   'instrumentalness': 0,
#   'liveness': 0.179,
#   'valence': 0.352,
#   'tempo': 100.017,
#   'duration_ms': 217707,
#   'time_signature': 4,
#   'name': "We Don't Talk Anymore (feat. Selena Gomez)",
#   'artist(s)': ['Charlie Puth', 'Selena Gomez'],
#   'genres': [['dance pop', 'pop', 'viral pop'],
#    ['dance pop', 'pop', 'post-teen pop']]},
#  {'danceability': 0.563,
#   'energy': 0.865,
#   'key': 5,
#   'loudness': -5.277,
#   'mode': 1,
#   'speechiness': 0.16,
#   'acousticness': 0.0472,
#   'instrumentalness': 0.000191,
#   'liveness': 0.77,
#   'valence': 0.601,
#   'tempo': 156.271,
#   'duration_ms': 209413,
#   'time_signature': 4,
#   'name': "Don't Stop Me Now - Remastered 2011",
#   'artist(s)': ['Queen'],
#   'genres': [['classic rock', 'glam rock', 'rock']]},
#  {'danceability': 0.775,
#   'energy': 0.613,
#   'key': 3,
#   'loudness': -4.586,
#   'mode': 0,
#   'speechiness': 0.0542,
#   'acousticness': 0.109,
#   'instrumentalness': 2.33e-05,
#   'liveness': 0.134,
#   'valence': 0.797,
#   'tempo': 100.066,
#   'duration_ms': 208787,
#   'time_signature': 4,
#   'name': 'Attention',
#   'artist(s)': ['Charlie Puth'],
#   'genres': [['dance pop', 'pop', 'viral pop']]},
#  {'danceability': 0.5,
#   'energy': 0.748,
#   'key': 4,
#   'loudness': -9.072,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.127,
#   'instrumentalness': 0,
#   'liveness': 0.447,
#   'valence': 0.514,
#   'tempo': 118.852,
#   'duration_ms': 250987,
#   'time_signature': 4,
#   'name': "Don't Stop Believin'",
#   'artist(s)': ['Journey'],
#   'genres': [['album rock',
#     'classic rock',
#     'hard rock',
#     'mellow gold',
#     'rock',
#     'soft rock']]},
#  {'danceability': 0.559,
#   'energy': 0.33,
#   'key': 9,
#   'loudness': -8.251,
#   'mode': 1,
#   'speechiness': 0.0285,
#   'acousticness': 0.892,
#   'instrumentalness': 0,
#   'liveness': 0.0975,
#   'valence': 0.285,
#   'tempo': 135.109,
#   'duration_ms': 285040,
#   'time_signature': 4,
#   'name': 'Someone Like You',
#   'artist(s)': ['Adele'],
#   'genres': [['british soul', 'pop', 'pop soul', 'uk pop']]},
#  {'danceability': 0.632,
#   'energy': 0.686,
#   'key': 6,
#   'loudness': -7.665,
#   'mode': 0,
#   'speechiness': 0.243,
#   'acousticness': 0.549,
#   'instrumentalness': 0,
#   'liveness': 0.2,
#   'valence': 0.329,
#   'tempo': 89.949,
#   'duration_ms': 170770,
#   'time_signature': 4,
#   'name': 'Eastside (with Halsey & Khalid)',
#   'artist(s)': ['benny blanco', 'Halsey', 'Khalid'],
#   'genres': [['dance pop', 'edm', 'electropop', 'pop', 'pop rap'],
#    ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop'],
#    ['pop', 'pop r&b']]},
#  {'danceability': 0.878,
#   'energy': 0.619,
#   'key': 6,
#   'loudness': -5.56,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.0533,
#   'instrumentalness': 0,
#   'liveness': 0.113,
#   'valence': 0.639,
#   'tempo': 136.041,
#   'duration_ms': 157067,
#   'time_signature': 4,
#   'name': 'Old Town Road - Remix',
#   'artist(s)': ['Lil Nas X', 'Billy Ray Cyrus'],
#   'genres': [['lgbtq+ hip hop', 'pop'], ['country', 'country rock']]},
#  {'danceability': 0.557,
#   'energy': 0.442,
#   'key': 5,
#   'loudness': -7.224,
#   'mode': 1,
#   'speechiness': 0.0243,
#   'acousticness': 0.731,
#   'instrumentalness': 1.46e-05,
#   'liveness': 0.11,
#   'valence': 0.213,
#   'tempo': 146.277,
#   'duration_ms': 309600,
#   'time_signature': 4,
#   'name': 'The Scientist',
#   'artist(s)': ['Coldplay'],
#   'genres': [['permanent wave', 'pop']]},
#  {'danceability': 0.78,
#   'energy': 0.68,
#   'key': 4,
# ...
#   'tempo': 107.005,
#   'duration_ms': 173948,
#   'time_signature': 4,
#   'name': 'First Class',
#   'artist(s)': ['Jack Harlow'],
#   'genres': [['deep underground hip hop', 'kentucky hip hop', 'pop', 'rap']]},
#  {'danceability': 0.723,
#   'energy': 0.86,
#   'key': 11,
#   'loudness': -4.357,
#   'mode': 1,
#   'speechiness': 0.203,
#   'acousticness': 0.271,
#   'instrumentalness': 4.56e-06,
#   'liveness': 0.598,
#   'valence': 0.667,
#   'tempo': 126.979,
#   'duration_ms': 200013,
#   'time_signature': 4,
#   'name': 'Super Bass',
#   'artist(s)': ['Nicki Minaj'],
#   'genres': [['dance pop', 'hip pop', 'pop', 'queens hip hop', 'rap']]},
#  {'danceability': 0.721,
#   'energy': 0.939,
#   'key': 8,
#   'loudness': -11.823,
#   'mode': 1,
#   'speechiness': 0.0376,
#   'acousticness': 0.115,
#   'instrumentalness': 3.79e-05,
#   'liveness': 0.108,
#   'valence': 0.914,
#   'tempo': 113.309,
#   'duration_ms': 213573,
#   'time_signature': 4,
#   'name': 'Never Gonna Give You Up',
#   'artist(s)': ['Rick Astley'],
#   'genres': [['europop',
#     'new romantic',
#     'new wave',
#     'new wave pop',
#     'soft rock',
#     'sophisti-pop',
#     'synthpop']]},
#  {'danceability': 0.768,
#   'energy': 0.852,
#   'key': 4,
#   'loudness': -6.215,
#   'mode': 1,
#   'speechiness': 0.038,
#   'acousticness': 0.214,
#   'instrumentalness': 7.36e-05,
#   'liveness': 0.0723,
#   'valence': 0.867,
#   'tempo': 128.373,
#   'duration_ms': 271240,
#   'time_signature': 4,
#   'name': "I Was Made For Lovin' You",
#   'artist(s)': ['KISS'],
#   'genres': [['album rock', 'glam rock', 'hard rock', 'metal', 'rock']]},
#  {'danceability': 0.574,
#   'energy': 0.628,
#   'key': 2,
#   'loudness': -8.815,
#   'mode': 0,
#   'speechiness': 0.036,
#   'acousticness': 0.13,
#   'instrumentalness': 0,
#   'liveness': 0.271,
#   'valence': 0.803,
#   'tempo': 153.119,
#   'duration_ms': 300107,
#   'time_signature': 4,
#   'name': 'Careless Whisper',
#   'artist(s)': ['George Michael'],
#   'genres': [['dance pop', 'new wave pop']]},
#  {'danceability': 0.689,
#   'energy': 0.808,
#   'key': 0,
#   'loudness': -3.28,
#   'mode': 1,
#   'speechiness': 0.0572,
#   'acousticness': 0.0721,
#   'instrumentalness': 0,
#   'liveness': 0.241,
#   'valence': 0.674,
#   'tempo': 91.012,
#   'duration_ms': 207680,
#   'time_signature': 4,
#   'name': 'SUBEME LA RADIO (feat. Descemer Bueno & Zion & Lennox)',
#   'artist(s)': ['Enrique Iglesias', 'Descemer Bueno', 'Zion & Lennox'],
#   'genres': [['latin pop', 'mexican pop'],
#    [],
#    ['latin hip hop', 'reggaeton', 'urbano latino']]},
#  {'danceability': 0.573,
#   'energy': 0.711,
#   'key': 1,
#   'loudness': -6.268,
#   'mode': 0,
#   'speechiness': 0.0406,
#   'acousticness': 0.0114,
#   'instrumentalness': 0,
#   'liveness': 0.328,
#   'valence': 0.47,
#   'tempo': 105.006,
#   'duration_ms': 226198,
#   'time_signature': 4,
#   'name': 'My Universe',
#   'artist(s)': ['Coldplay', 'BTS'],
#   'genres': [['permanent wave', 'pop'], ['k-pop', 'k-pop boy group']]},
#  {'danceability': 0.652,
#   'energy': 0.812,
#   'key': 3,
#   'loudness': -3.797,
#   'mode': 0,
#   'speechiness': 0.0409,
#   'acousticness': 0.00125,
#   'instrumentalness': 3.01e-05,
#   'liveness': 0.667,
#   'valence': 0.72,
#   'tempo': 126.023,
#   'duration_ms': 230733,
#   'time_signature': 4,
#   'name': 'Last Friday Night (T.G.I.F.)',
#   'artist(s)': ['Katy Perry'],
#   'genres': [['dance pop', 'pop']]},
#  {'danceability': 0.737,
#   'energy': 0.846,
#   'key': 1,
#   'loudness': -4.51,
#   'mode': 0,
#   'speechiness': 0.22,
#   'acousticness': 0.00614,
#   'instrumentalness': 0,
#   'liveness': 0.0486,
#   'valence': 0.546,
#   'tempo': 87.981,
#   'duration_ms': 143901,
#   'time_signature': 4,
#   'name': 'THATS WHAT I WANT',
#   'artist(s)': ['Lil Nas X'],
#   'genres': [['lgbtq+ hip hop', 'pop']]},
#  {'danceability': 0.532,
#   'energy': 0.767,
#   'key': 7,
#   'loudness': -5.509,
#   'mode': 1,
#   'speechiness': 0.0574,
#   'acousticness': 0.00287,
#   'instrumentalness': 0.000513,
#   'liveness': 0.39,
#   'valence': 0.755,
#   'tempo': 127.361,
#   'duration_ms': 210173,
#   'time_signature': 4,
#   'name': 'You Shook Me All Night Long',
#   'artist(s)': ['AC/DC'],
#   'genres': [['australian rock', 'hard rock', 'rock']]},
#  {'danceability': 0.653,
#   'energy': 0.524,
#   'key': 11,
#   'loudness': -9.016,
#   'mode': 0,
#   'speechiness': 0.0502,
#   'acousticness': 0.112,
#   'instrumentalness': 0,
#   'liveness': 0.203,
#   'valence': 0.553,
#   'tempo': 83.97,
#   'duration_ms': 160191,
#   'time_signature': 4,
#   'name': 'telepatía',
#   'artist(s)': ['Kali Uchis'],
#   'genres': [['colombian pop', 'pop']]},
#  {'danceability': 0.812,
#   'energy': 0.761,
#   'key': 11,
#   'loudness': -5.222,
#   'mode': 1,
#   'speechiness': 0.0812,
#   'acousticness': 0.0465,
#   'instrumentalness': 0.000135,
#   'liveness': 0.0601,
#   'valence': 0.344,
#   'tempo': 130.032,
#   'duration_ms': 182956,
#   'time_signature': 4,
#   'name': 'How You Like That',
#   'artist(s)': ['BLACKPINK'],
#   'genres': [['k-pop', 'k-pop girl group']]},
#  {'danceability': 0.688,
#   'energy': 0.835,
#   'key': 8,
#   'loudness': -4.162,
#   'mode': 1,
#   'speechiness': 0.0911,
#   'acousticness': 0.0583,
#   'instrumentalness': 2.87e-06,
#   'liveness': 0.0795,
#   'valence': 0.88,
#   'tempo': 84.858,
#   'duration_ms': 230493,
#   'time_signature': 4,
#   'name': 'Remember the Name (feat. Styles of Beyond)',
#   'artist(s)': ['Fort Minor', 'Styles Of Beyond'],
#   'genres': [['pop rap', 'rap rock'], ['cali rap', 'rap rock']]},
#  {'danceability': 0.704,
#   'energy': 0.797,
#   'key': 0,
#   'loudness': -5.927,
#   'mode': 1,
#   'speechiness': 0.0475,
#   'acousticness': 0.0826,
#   'instrumentalness': 0.000745,
#   'liveness': 0.0546,
#   'valence': 0.825,
#   'tempo': 139.994,
#   'duration_ms': 148486,
#   'time_signature': 4,
#   'name': "I Ain't Worried",
#   'artist(s)': ['OneRepublic'],
#   'genres': [['piano rock', 'pop']]},
#  {'danceability': 0.464,
#   'energy': 0.417,
#   'key': 0,
#   'loudness': -9.345,
#   'mode': 0,
#   'speechiness': 0.0256,
#   'acousticness': 0.136,
#   'instrumentalness': 0.022,
#   'liveness': 0.0974,
#   'valence': 0.479,
#   'tempo': 67.528,
#   'duration_ms': 183956,
#   'time_signature': 4,
#   'name': 'I Wanna Be Yours',
#   'artist(s)': ['Arctic Monkeys'],
#   'genres': [['garage rock',
#     'modern rock',
#     'permanent wave',
#     'rock',
#     'sheffield indie']]},
#  {'danceability': 0.288,
#   'energy': 0.758,
#   'key': 6,
#   'loudness': -5.692,
#   'mode': 0,
#   'speechiness': 0.0371,
#   'acousticness': 0.00616,
#   'instrumentalness': 0,
#   'liveness': 0.303,
#   'valence': 0.619,
#   'tempo': 97.094,
#   'duration_ms': 201726,
#   'time_signature': 4,
#   'name': 'R U Mine?',
#   'artist(s)': ['Arctic Monkeys'],
#   'genres': [['garage rock',
#     'modern rock',
#     'permanent wave',
#     'rock',
#     'sheffield indie']]},
#  {'danceability': 0.646,
#   'energy': 0.813,
#   'key': 6,
#   'loudness': -5.29,
#   'mode': 0,
#   'speechiness': 0.0288,
#   'acousticness': 0.00178,
#   'instrumentalness': 2.26e-05,
#   'liveness': 0.144,
#   'valence': 0.821,
#   'tempo': 112.115,
#   'duration_ms': 173493,
#   'time_signature': 4,
#   'name': 'Fluorescent Adolescent',
#   'artist(s)': ['Arctic Monkeys'],
#   'genres': [['garage rock',
#     'modern rock',
#     'permanent wave',
#     'rock',
#     'sheffield indie']]},
#  {'danceability': 0.431,
#   'energy': 0.723,
#   'key': 8,
#   'loudness': -5.887,
#   'mode': 1,
#   'speechiness': 0.0568,
#   'acousticness': 0.145,
#   'instrumentalness': 0,
#   'liveness': 0.374,
#   'valence': 0.19,
#   'tempo': 130.141,
#   'duration_ms': 267360,
#   'time_signature': 4,
#   'name': 'Total Eclipse of the Heart',
#   'artist(s)': ['Bonnie Tyler'],
#   'genres': [['europop', 'new wave pop', 'soft rock']]},
#  {'danceability': 0.531,
#   'energy': 0.481,
#   'key': 4,
#   'loudness': -11.709,
#   'mode': 0,
#   'speechiness': 0.06,
#   'acousticness': 0.699,
#   'instrumentalness': 0,
#   'liveness': 0.0842,
#   'valence': 0.491,
#   'tempo': 138.45,
#   'duration_ms': 516893,
#   'time_signature': 4,
#   'name': 'American Pie',
#   'artist(s)': ['Don McLean'],
#   'genres': [['adult standards',
#     'classic rock',
#     'folk',
#     'folk rock',
#     'mellow gold',
#     'singer-songwriter',
#     'soft rock']]},
#  {'danceability': 0.492,
#   'energy': 0.81,
#   'key': 7,
#   'loudness': -5.315,
#   'mode': 1,
#   'speechiness': 0.0847,
#   'acousticness': 0.0416,
#   'instrumentalness': 0.00379,
#   'liveness': 0.117,
#   'valence': 0.245,
#   'tempo': 149.954,
#   'duration_ms': 251840,
#   'time_signature': 4,
#   'name': 'Dog Days Are Over',
#   'artist(s)': ['Florence + The Machine'],
#   'genres': [['baroque pop', 'pop', 'uk alternative pop']]},
#  {'danceability': 0.747,
#   'energy': 0.716,
#   'key': 11,
#   'loudness': -2.457,
#   'mode': 0,
#   'speechiness': 0.075,
#   'acousticness': 0.135,
#   'instrumentalness': 0,
#   'liveness': 0.251,
#   'valence': 0.751,
#   'tempo': 125.008,
#   'duration_ms': 210627,
#   'time_signature': 4,
#   'name': 'Starships',
#   'artist(s)': ['Nicki Minaj'],
#   'genres': [['dance pop', 'hip pop', 'pop', 'queens hip hop', 'rap']]},
#  {'danceability': 0.569,
#   'energy': 0.83,
#   'key': 9,
#   'loudness': -4.106,
#   'mode': 0,
#   'speechiness': 0.14,
#   'acousticness': 0.0807,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.609,
#   'tempo': 170.094,
#   'duration_ms': 186635,
#   'time_signature': 4,
#   'name': 'I Write Sins Not Tragedies',
#   'artist(s)': ['Panic! At The Disco'],
#   'genres': [['modern rock']]},
#  {'danceability': 0.657,
#   'energy': 0.56,
#   'key': 6,
#   'loudness': -9.049,
#   'mode': 0,
#   'speechiness': 0.0467,
#   'acousticness': 0.498,
#   'instrumentalness': 0,
#   'liveness': 0.0794,
#   'valence': 0.854,
#   'tempo': 161.993,
#   'duration_ms': 182947,
#   'time_signature': 4,
#   'name': 'Mistletoe',
#   'artist(s)': ['Justin Bieber'],
#   'genres': [['canadian pop', 'pop']]},
#  {'danceability': 0.65,
#   'energy': 0.715,
#   'key': 5,
#   'loudness': -5.198,
#   'mode': 0,
#   'speechiness': 0.253,
#   'acousticness': 0.0993,
#   'instrumentalness': 0.000291,
#   'liveness': 0.126,
#   'valence': 0.187,
#   'tempo': 106.672,
#   'duration_ms': 243717,
#   'time_signature': 4,
#   'name': 'Tití Me Preguntó',
#   'artist(s)': ['Bad Bunny'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino']]},
#  {'danceability': 0.801,
#   'energy': 0.475,
#   'key': 7,
#   'loudness': -8.797,
#   'mode': 0,
#   'speechiness': 0.0516,
#   'acousticness': 0.141,
#   'instrumentalness': 1.73e-05,
#   'liveness': 0.0639,
#   'valence': 0.234,
#   'tempo': 98.047,
#   'duration_ms': 213061,
#   'time_signature': 4,
#   'name': 'Efecto',
#   'artist(s)': ['Bad Bunny'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino']]},
#  {'danceability': 0.647,
#   'energy': 0.686,
#   'key': 3,
#   'loudness': -5.745,
#   'mode': 0,
#   'speechiness': 0.0413,
#   'acousticness': 0.08,
#   'instrumentalness': 1.34e-06,
#   'liveness': 0.528,
#   'valence': 0.268,
#   'tempo': 79.928,
#   'duration_ms': 258299,
#   'time_signature': 4,
#   'name': 'Ojitos Lindos',
#   'artist(s)': ['Bad Bunny', 'Bomba Estéreo'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino'],
#    ['cumbia',
#     'latin alternative',
#     'pop electronico',
#     'tropical alternativo']]},
#  {'danceability': 0.804,
#   'energy': 0.674,
#   'key': 5,
#   'loudness': -5.453,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.294,
#   'instrumentalness': 1.18e-06,
#   'liveness': 0.115,
#   'valence': 0.292,
#   'tempo': 99.968,
#   'duration_ms': 245940,
#   'time_signature': 4,
#   'name': 'Moscow Mule',
#   'artist(s)': ['Bad Bunny'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino']]},
#  {'danceability': 0.634,
#   'energy': 0.886,
#   'key': 2,
#   'loudness': -3.466,
#   'mode': 1,
#   'speechiness': 0.0517,
#   'acousticness': 0.0291,
#   'instrumentalness': 0,
#   'liveness': 0.342,
#   'valence': 0.922,
#   'tempo': 161.933,
#   'duration_ms': 168253,
#   'time_signature': 4,
#   'name': 'The Middle',
#   'artist(s)': ['Jimmy Eat World'],
#   'genres': [['emo',
#     'modern power pop',
#     'modern rock',
#     'neo mellow',
#     'pop punk',
#     'pop rock',
#     'rock']]},
#  {'danceability': 0.55,
#   'energy': 0.917,
#   'key': 0,
#   'loudness': -3.159,
#   'mode': 1,
#   'speechiness': 0.0638,
#   'acousticness': 0.00428,
#   'instrumentalness': 0,
#   'liveness': 0.197,
#   'valence': 0.601,
#   'tempo': 126.115,
#   'duration_ms': 177827,
#   'time_signature': 4,
#   'name': "You're Gonna Go Far, Kid",
#   'artist(s)': ['The Offspring'],
#   'genres': [['alternative metal',
#     'permanent wave',
#     'punk',
#     'rock',
#     'skate punk',
#     'socal pop punk']]},
#  {'danceability': 0.44,
#   'energy': 0.317,
#   'key': 8,
#   'loudness': -9.258,
#   'mode': 1,
#   'speechiness': 0.0531,
#   'acousticness': 0.891,
#   'instrumentalness': 4.78e-06,
#   'liveness': 0.141,
#   'valence': 0.268,
#   'tempo': 169.914,
#   'duration_ms': 233456,
#   'time_signature': 3,
#   'name': 'Glimpse of Us',
#   'artist(s)': ['Joji'],
#   'genres': [['viral pop']]},
#  {'danceability': 0.729,
#   'energy': 0.65,
#   'key': 5,
#   'loudness': -3.539,
#   'mode': 1,
#   'speechiness': 0.0313,
#   'acousticness': 0.0702,
#   'instrumentalness': 6.69e-05,
#   'liveness': 0.0829,
#   'valence': 0.347,
#   'tempo': 110.02,
#   'duration_ms': 209160,
#   'time_signature': 4,
#   'name': 'Habits (Stay High)',
#   'artist(s)': ['Tove Lo'],
#   'genres': [['dance pop',
#     'electropop',
#     'metropopolis',
#     'pop',
#     'swedish electropop',
#     'swedish pop',
#     'swedish synthpop']]},
#  {'danceability': 0.504,
#   'energy': 0.904,
#   'key': 6,
#   'loudness': -6.863,
#   'mode': 1,
#   'speechiness': 0.179,
#   'acousticness': 0.356,
#   'instrumentalness': 0.121,
#   'liveness': 0.14,
#   'valence': 0.772,
#   'tempo': 176.808,
#   'duration_ms': 183440,
#   'time_signature': 4,
#   'name': "I'm Still Standing",
#   'artist(s)': ['Elton John'],
#   'genres': [['glam rock', 'mellow gold', 'piano rock']]},
#  {'danceability': 0.554,
#   'energy': 0.315,
#   'key': 3,
#   'loudness': -11.028,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.828,
#   'instrumentalness': 5.53e-06,
#   'liveness': 0.101,
#   'valence': 0.325,
#   'tempo': 128.157,
#   'duration_ms': 241787,
#   'time_signature': 4,
#   'name': 'Your Song',
#   'artist(s)': ['Elton John'],
#   'genres': [['glam rock', 'mellow gold', 'piano rock']]},
#  {'danceability': 0.414,
#   'energy': 0.428,
#   'key': 0,
#   'loudness': -11.097,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.382,
#   'instrumentalness': 0.000243,
#   'liveness': 0.148,
#   'valence': 0.282,
#   'tempo': 145.075,
#   'duration_ms': 377093,
#   'time_signature': 4,
#   'name': 'Tiny Dancer',
#   'artist(s)': ['Elton John'],
#   'genres': [['glam rock', 'mellow gold', 'piano rock']]},
#  {'danceability': 0.749,
#   'energy': 0.491,
#   'key': 10,
#   'loudness': -9.655,
#   'mode': 1,
#   'speechiness': 0.0403,
#   'acousticness': 0.02,
#   'instrumentalness': 0.00899,
#   'liveness': 0.159,
#   'valence': 0.536,
#   'tempo': 119.528,
#   'duration_ms': 292613,
#   'time_signature': 4,
#   'name': 'Gimme! Gimme! Gimme! (A Man After Midnight)',
#   'artist(s)': ['ABBA'],
#   'genres': [['europop', 'swedish pop']]},
#  {'danceability': 0.561,
#   'energy': 0.965,
#   'key': 7,
#   'loudness': -3.673,
#   'mode': 0,
#   'speechiness': 0.0343,
#   'acousticness': 0.00383,
#   'instrumentalness': 7.07e-06,
#   'liveness': 0.371,
#   'valence': 0.304,
#   'tempo': 128.04,
#   'duration_ms': 175238,
#   'time_signature': 4,
#   'name': "I'm Good (Blue)",
#   'artist(s)': ['David Guetta', 'Bebe Rexha'],
#   'genres': [['big room', 'dance pop', 'edm', 'pop', 'pop dance'],
#    ['dance pop', 'edm', 'pop', 'post-teen pop']]},
#  {'danceability': 0.552,
#   'energy': 0.608,
#   'key': 1,
#   'loudness': -9.786,
#   'mode': 0,
#   'speechiness': 0.0345,
#   'acousticness': 0.352,
#   'instrumentalness': 0,
#   'liveness': 0.0533,
#   'valence': 0.637,
#   'tempo': 112.367,
#   'duration_ms': 162373,
#   'time_signature': 4,
#   'name': "California Dreamin' - Single Version",
#   'artist(s)': ['The Mamas & The Papas'],
#   'genres': [['bubblegum pop',
#     'classic rock',
#     'folk rock',
#     'mellow gold',
#     'psychedelic rock',
#     'rock',
#     'sunshine pop']]},
#  {'danceability': 0.674,
#   'energy': 0.789,
#   'key': 8,
#   'loudness': -6.903,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'acousticness': 0.00178,
#   'instrumentalness': 0.00708,
#   'liveness': 0.0753,
#   'valence': 0.918,
#   'tempo': 129.802,
#   'duration_ms': 121160,
#   'time_signature': 4,
#   'name': 'Song 2 - 2012 Remaster',
#   'artist(s)': ['Blur'],
#   'genres': [['alternative rock',
#     'britpop',
#     'madchester',
#     'modern rock',
#     'permanent wave',
#     'pop rock',
#     'rock']]}]

# %%
num_track_data = [[track[data] for data in track if 
    (isinstance(track[data], float) 
        | isinstance(track[data], int))] for track in track_info]

num_track_data
# Out:
# [[0.514,
#   0.73,
#   1,
#   -5.934,
#   1,
#   0.0598,
#   0.00146,
#   9.54e-05,
#   0.0897,
#   0.334,
#   171.005,
#   200040,
#   4],
#  [0.825,
#   0.652,
#   1,
#   -3.183,
#   0,
#   0.0802,
#   0.581,
#   0,
#   0.0931,
#   0.931,
#   95.977,
#   233713,
#   4],
#  [0.824,
#   0.587,
#   6,
#   -6.401,
#   0,
#   0.0937,
#   0.69,
#   0.000105,
#   0.149,
#   0.514,
#   98.029,
#   209438,
#   4],
#  [0.501,
#   0.405,
#   1,
#   -5.679,
#   1,
#   0.0319,
#   0.751,
#   0,
#   0.105,
#   0.446,
#   109.891,
#   182161,
#   4],
#  [0.585,
#   0.52,
#   5,
#   -6.136,
#   0,
#   0.0712,
#   0.124,
#   7.01e-05,
#   0.131,
#   0.129,
#   159.801,
#   218147,
#   4],
#  [0.76,
#   0.479,
#   2,
#   -5.574,
#   1,
#   0.0466,
#   0.556,
#   0,
#   0.0703,
#   0.913,
#   89.911,
#   158040,
#   4],
#  [0.792,
#   0.625,
#   1,
#   -5.609,
#   1,
#   0.0536,
#   0.00776,
#   0.00188,
#   0.329,
#   0.37,
#   103.967,
#   173987,
#   4],
#  [0.738,
#   0.541,
#   8,
#   -5.597,
#   1,
#   0.0303,
#   0.415,
#   0,
#   0.11,
#   0.657,
#   94.949,
#   245507,
#   4],
#  [0.772,
#   0.78,
#   10,
#   -4.288,
#   0,
#   0.108,
#   0.0512,
#   0,
#   0.119,
#   0.719,
#   124.988,
#   204347,
#   4],
#  [0.591,
#   0.764,
#   1,
#   -5.484,
#   1,
#   0.0483,
#   0.0383,
#   0,
#   0.103,
#   0.478,
#   169.928,
#   141806,
#   4],
#  [0.759,
#   0.548,
#   9,
#   -6.049,
#   0,
#   0.029,
#   0.0392,
#   0,
#   0.0828,
#   0.749,
#   116.967,
#   190800,
#   4],
#  [0.599,
#   0.448,
#   8,
#   -6.312,
#   1,
#   0.0232,
#   0.163,
#   0,
#   0.106,
#   0.168,
#   95.05,
#   263400,
#   3],
#  [0.761,
#   0.525,
#   11,
#   -6.9,
#   1,
#   0.0944,
#   0.44,
#   6.7e-06,
#   0.0921,
#   0.531,
#   80.87,
#   238805,
#   4],
#  [0.358,
#   0.557,
#   10,
#   -7.398,
#   1,
#   0.059,
#   0.695,
#   0,
#   0.0902,
#   0.494,
#   85.043,
#   211467,
#   4],
#  [0.701,
#   0.425,
#   7,
#   -10.965,
#   1,
#   0.375,
#   0.328,
#   0.13,
#   0.1,
#   0.562,
#   135.128,
#   194088,
#   4],
#  [0.781,
#   0.445,
#   2,
#   -6.061,
#   1,
#   0.0295,
#   0.474,
#   0,
#   0.184,
#   0.591,
#   78.998,
#   281560,
#   4],
#  [0.511, 0.566, 6, -7.23, 0, 0.2, 0.349, 0, 0.34, 0.218, 83.903, 239836, 4],
#  [0.679,
#   0.587,
#   7,
#   -7.015,
#   1,
#   0.276,
#   0.141,
#   6.35e-06,
#   0.137,
#   0.486,
#   186.003,
#   230453,
#   4],
#  [0.793,
#   0.793,
#   11,
#   -4.521,
#   0,
#   0.083,
#   0.0123,
#   0,
#   0.0951,
#   0.679,
#   123.95,
#   183290,
#   4],
#  [0.754,
#   0.449,
#   7,
#   -9.211,
#   1,
#   0.109,
#   0.0332,
#   8.29e-05,
#   0.552,
#   0.357,
#   77.169,
#   198973,
#   4],
#  [0.351,
#   0.296,
#   4,
#   -10.109,
#   0,
#   0.0333,
#   0.934,
#   0,
#   0.095,
#   0.12,
#   115.284,
#   200186,
#   4],
#  [0.548,
#   0.816,
#   0,
#   -4.209,
#   1,
#   0.0465,
#   0.122,
#   0,
#   0.335,
#   0.557,
#   95.39,
#   174000,
#   4],
#  [0.614,
#   0.379,
#   4,
#   -10.48,
#   1,
#   0.0476,
#   0.607,
#   0.000464,
#   0.0986,
#   0.201,
#   107.989,
#   258987,
#   4],
#  [0.392,
#   0.402,
#   0,
#   -9.961,
#   0,
#   0.0536,
#   0.288,
#   0,
#   0.243,
#   0.228,
#   143.883,
#   354320,
#   4],
#  [0.617,
#   0.635,
#   11,
#   -6.769,
#   0,
#   0.0317,
#   0.0498,
#   1.44e-05,
#   0.164,
#   0.446,
#   103.019,
#   247160,
#   4],
#  [0.572,
#   0.385,
#   7,
#   -6.362,
#   1,
#   0.0308,
#   0.371,
#   0,
#   0.231,
#   0.323,
#   95.799,
#   215733,
#   4],
#  [0.609,
#   0.378,
#   4,
#   -9.828,
#   1,
#   0.438,
#   0.835,
#   0,
#   0.28,
#   0.515,
#   100.418,
#   233720,
#   4],
#  [0.74,
#   0.613,
#   8,
#   -4.88,
#   1,
#   0.145,
#   0.258,
#   0.00372,
#   0.123,
#   0.473,
#   75.023,
#   166606,
#   4],
#  [0.695,
#   0.762,
#   0,
#   -3.497,
#   1,
#   0.0395,
#   0.192,
#   0.00244,
#   0.0863,
#   0.553,
#   120.042,
#   215280,
#   4],
#  [0.575,
#   0.664,
#   4,
#   -5.303,
#   0,
#   0.0481,
#   0.637,
#   0,
#   0.116,
#   0.437,
#   129.07,
#   241693,
#   4],
#  [0.422,
#   0.264,
#   8,
#   -7.064,
#   1,
#   0.0322,
#   0.922,
#   0,
#   0.132,
#   0.331,
#   119.93,
#   269560,
#   4],
#  [0.612,
#   0.807,
#   10,
#   -2.81,
#   1,
#   0.0336,
#   0.0495,
#   0.0177,
#   0.101,
#   0.398,
#   124.053,
#   240400,
#   4],
#  [0.604,
#   0.826,
#   0,
#   -4.804,
#   1,
#   0.0434,
#   0.00782,
#   0.15,
#   0.154,
#   0.241,
#   167.985,
#   187147,
#   4],
#  [0.778,
#   0.317,
#   1,
#   -10.732,
#   0,
#   0.334,
#   0.592,
#   0,
#   0.0881,
#   0.327,
#   140.048,
#   178627,
#   4],
#  [0.841,
#   0.728,
#   7,
#   -3.37,
#   1,
#   0.0484,
#   0.0847,
#   0,
#   0.149,
#   0.43,
#   130.049,
#   243837,
#   4],
#  [0.872,
#   0.391,
#   0,
#   -9.144,
#   0,
#   0.242,
#   0.469,
#   4.13e-06,
#   0.297,
#   0.437,
#   134.021,
#   119133,
#   4],
#  [0.765,
#   0.523,
#   2,
#   -4.333,
#   1,
#   0.03,
#   0.184,
#   3.56e-05,
#   0.132,
#   0.394,
#   104.988,
#   217307,
#   4],
#  [0.734,
#   0.637,
#   4,
#   -5.677,
#   0,
#   0.141,
#   0.0462,
#   2.29e-05,
#   0.0602,
#   0.648,
#   169.977,
#   202333,
#   4],
#  [0.732,
#   0.75,
#   11,
#   -6.366,
#   0,
#   0.231,
#   0.00264,
#   0,
#   0.109,
#   0.401,
#   155.096,
#   182707,
#   4],
#  [0.762,
#   0.7,
#   9,
#   -6.021,
#   0,
#   0.0694,
#   0.00261,
#   1.56e-05,
#   0.153,
#   0.608,
#   116.073,
#   209320,
#   4],
#  [0.687,
#   0.792,
#   5,
#   -2.749,
#   1,
#   0.0452,
#   0.191,
#   0,
#   0.167,
#   0.671,
#   100.015,
#   214290,
#   4],
#  [0.663,
#   0.712,
#   1,
#   -4.945,
#   0,
#   0.0381,
#   0.0649,
#   0,
#   0.119,
#   0.48,
#   122.014,
#   257280,
#   4],
#  [0.908,
#   0.621,
#   1,
#   -6.638,
#   0,
#   0.102,
#   0.000282,
#   5.39e-05,
#   0.0958,
#   0.421,
#   150.011,
#   177000,
#   4],
#  [0.516,
#   0.806,
#   2,
#   -5.133,
#   1,
#   0.0538,
#   0.00389,
#   0.000674,
#   0.115,
#   0.577,
#   124.118,
#   249693,
#   4],
#  [0.479,
#   0.545,
#   7,
#   -7.346,
#   1,
#   0.0688,
#   0.365,
#   0,
#   0.0963,
#   0.244,
#   74.897,
#   252733,
#   4],
#  [0.834,
#   0.73,
#   8,
#   -3.714,
#   1,
#   0.222,
#   0.00513,
#   0,
#   0.124,
#   0.446,
#   155.008,
#   312820,
#   4],
#  [0.52,
#   0.731,
#   6,
#   -5.338,
#   0,
#   0.0557,
#   0.342,
#   0.00101,
#   0.311,
#   0.662,
#   173.93,
#   167303,
#   4],
#  [0.484,
#   0.731,
#   1,
#   -6.694,
#   1,
#   0.0379,
#   0.431,
#   0,
#   0.151,
#   0.51,
#   101.654,
#   204280,
#   4],
#  [0.356,
#   0.567,
#   0,
#   -7.011,
#   0,
#   0.0798,
#   0.0861,
#   0,
#   0.137,
#   0.109,
#   135.553,
#   242253,
#   5],
#  [0.654, 0.76, 0, -3.669, 0, 0.045, 0.0797, 0, 0.299, 0.41, 99.945, 200787, 4],
#  [0.641,
#   0.922,
#   2,
#   -4.457,
#   1,
#   0.0786,
#   0.0291,
#   0,
#   0.0862,
#   0.847,
#   146.078,
#   258343,
#   4],
#  [0.563,
#   0.664,
#   9,
#   -5.044,
#   1,
#   0.154,
#   0.335,
#   0,
#   0.0849,
#   0.688,
#   166.928,
#   178147,
#   4],
#  [0.649,
#   0.716,
#   8,
#   -5.371,
#   1,
#   0.0349,
#   0.0863,
#   2.63e-05,
#   0.135,
#   0.163,
#   99.988,
#   205947,
#   4],
#  [0.723,
#   0.809,
#   7,
#   -3.081,
#   0,
#   0.0625,
#   0.00346,
#   0.00123,
#   0.565,
#   0.274,
#   98.007,
#   176561,
#   4],
#  [0.785,
#   0.721,
#   8,
#   -5.457,
#   1,
#   0.0506,
#   0.0149,
#   0.00432,
#   0.285,
#   0.894,
#   121.962,
#   176219,
#   4],
#  [0.791,
#   0.862,
#   9,
#   -3.24,
#   0,
#   0.11,
#   0.037,
#   2.19e-05,
#   0.0814,
#   0.592,
#   123.994,
#   214847,
#   4],
#  [0.68,
#   0.578,
#   10,
#   -5.804,
#   1,
#   0.04,
#   0.331,
#   0,
#   0.135,
#   0.341,
#   145.038,
#   231267,
#   4],
#  [0.561,
#   0.431,
#   10,
#   -8.81,
#   1,
#   0.0578,
#   0.768,
#   1.42e-05,
#   0.106,
#   0.137,
#   143.875,
#   242013,
#   4],
#  [0.455,
#   0.797,
#   10,
#   -4.133,
#   0,
#   0.36,
#   0.132,
#   0,
#   0.11,
#   0.757,
#   165.717,
#   187973,
#   4],
#  [0.63,
#   0.804,
#   6,
#   -4.183,
#   1,
#   0.0363,
#   0.215,
#   0,
#   0.253,
#   0.492,
#   123.146,
#   220293,
#   4],
#  [0.589,
#   0.651,
#   6,
#   -5.097,
#   1,
#   0.0306,
#   0.0291,
#   3.2e-06,
#   0.111,
#   0.166,
#   90.011,
#   212627,
#   4],
#  [0.418,
#   0.42,
#   0,
#   -6.444,
#   1,
#   0.0414,
#   0.588,
#   6.39e-05,
#   0.11,
#   0.184,
#   84.094,
#   172724,
#   4],
#  [0.752,
#   0.488,
#   6,
#   -7.05,
#   1,
#   0.0705,
#   0.297,
#   9.11e-06,
#   0.0936,
#   0.533,
#   136.041,
#   201661,
#   4],
#  [0.534,
#   0.868,
#   11,
#   -5.057,
#   1,
#   0.205,
#   0.187,
#   0.0032,
#   0.148,
#   0.406,
#   159.763,
#   208667,
#   4],
#  [0.856,
#   0.609,
#   0,
#   -7.223,
#   1,
#   0.0824,
#   0.00801,
#   8.15e-05,
#   0.0344,
#   0.928,
#   114.988,
#   269667,
#   4],
#  [0.664,
#   0.714,
#   7,
#   -6.645,
#   0,
#   0.111,
#   0.0353,
#   8.42e-06,
#   0.0843,
#   0.71,
#   101.969,
#   197933,
#   4],
#  [0.741,
#   0.691,
#   10,
#   -7.395,
#   0,
#   0.0672,
#   0.0221,
#   0,
#   0.0476,
#   0.892,
#   150.087,
#   212353,
#   4],
#  [0.775,
#   0.327,
#   11,
#   -7.241,
#   1,
#   0.0557,
#   0.841,
#   0,
#   0.0821,
#   0.595,
#   91.05,
#   189486,
#   4],
#  [0.681,
#   0.372,
#   5,
#   -8.237,
#   1,
#   0.0432,
#   0.64,
#   0,
#   0.169,
#   0.476,
#   91.873,
#   201000,
#   4],
#  [0.798,
#   0.676,
#   6,
#   -5.041,
#   1,
#   0.0442,
#   0.0902,
#   0,
#   0.0894,
#   0.843,
#   101.956,
#   219947,
#   4],
#  [0.356,
#   0.924,
#   1,
#   -3.74,
#   1,
#   0.0808,
#   0.00101,
#   0,
#   0.0953,
#   0.232,
#   148.017,
#   222587,
#   4],
#  [0.717,
#   0.653,
#   1,
#   -5.634,
#   1,
#   0.0658,
#   0.229,
#   0,
#   0.101,
#   0.412,
#   106.966,
#   207320,
#   4],
#  [0.505,
#   0.71,
#   3,
#   -3.015,
#   1,
#   0.0321,
#   0.19,
#   0.00025,
#   0.329,
#   0.428,
#   89.938,
#   175200,
#   4],
#  [0.692,
#   0.744,
#   2,
#   -4.565,
#   1,
#   0.257,
#   0.00868,
#   0.000423,
#   0.359,
#   0.0612,
#   171.374,
#   326467,
#   4],
#  [0.702,
#   0.825,
#   6,
#   -3.787,
#   0,
#   0.0601,
#   0.00883,
#   0,
#   0.0674,
#   0.915,
#   102.977,
#   203064,
#   4],
#  [0.593, 0.503, 8, -6.725, 0, 0.22, 0.293, 0, 0.405, 0.71, 178.781, 137704, 4],
#  [0.731,
#   0.573,
#   4,
#   -10.059,
#   0,
#   0.0544,
#   0.401,
#   5.22e-05,
#   0.113,
#   0.145,
#   109.928,
#   205090,
#   4],
#  [0.701,
#   0.716,
#   7,
#   -3.671,
#   0,
#   0.0361,
#   0.174,
#   0,
#   0.324,
#   0.732,
#   91.007,
#   140533,
#   4],
#  [0.653,
#   0.816,
#   2,
#   -4.353,
#   1,
#   0.167,
#   0.228,
#   0,
#   0.0967,
#   0.816,
#   178.085,
#   228827,
#   4],
#  [0.726,
#   0.769,
#   6,
#   -5.043,
#   1,
#   0.123,
#   0.0293,
#   0.0101,
#   0.104,
#   0.733,
#   97.985,
#   233902,
#   4],
#  [0.921,
#   0.537,
#   9,
#   -5.723,
#   0,
#   0.0804,
#   0.556,
#   0.00404,
#   0.102,
#   0.711,
#   128.009,
#   135090,
#   4],
#  [0.746,
#   0.765,
#   6,
#   -4.41,
#   0,
#   0.0993,
#   0.0112,
#   0,
#   0.0936,
#   0.737,
#   114.044,
#   199054,
#   4],
#  [0.548,
#   0.532,
#   5,
#   -7.596,
#   1,
#   0.0323,
#   0.186,
#   0.000263,
#   0.217,
#   0.405,
#   85.03,
#   272394,
#   4],
#  [0.896,
#   0.586,
#   10,
#   -6.687,
#   0,
#   0.0559,
#   0.104,
#   0,
#   0.79,
#   0.642,
#   116.971,
#   196653,
#   4],
#  [0.372,
#   0.865,
#   2,
#   -4.918,
#   1,
#   0.0381,
#   0.000453,
#   0,
#   0.234,
#   0.478,
#   174.53,
#   258733,
#   4],
#  [0.853,
#   0.56,
#   1,
#   -4.961,
#   1,
#   0.0406,
#   0.013,
#   0,
#   0.0944,
#   0.86,
#   134.066,
#   206693,
#   4],
#  [0.628,
#   0.698,
#   6,
#   -5.608,
#   0,
#   0.105,
#   0.0472,
#   0.00143,
#   0.0907,
#   0.732,
#   89.976,
#   211667,
#   4],
#  [0.866,
#   0.813,
#   11,
#   -4.063,
#   0,
#   0.0554,
#   0.38,
#   0,
#   0.0779,
#   0.969,
#   121.998,
#   199440,
#   4],
#  [0.548,
#   0.847,
#   1,
#   -3.237,
#   1,
#   0.186,
#   0.0622,
#   0,
#   0.0816,
#   0.1,
#   171.447,
#   297787,
#   4],
#  [0.746,
#   0.754,
#   1,
#   -6.684,
#   1,
#   0.0676,
#   0.0152,
#   0,
#   0.0486,
#   0.746,
#   149.882,
#   206880,
#   4],
#  [0.692,
#   0.521,
#   10,
#   -8.465,
#   0,
#   0.33,
#   0.301,
#   0,
#   0.0565,
#   0.463,
#   100.45,
#   292987,
#   4],
#  [0.689,
#   0.481,
#   10,
#   -7.503,
#   1,
#   0.0815,
#   0.369,
#   1.03e-06,
#   0.0649,
#   0.283,
#   80.025,
#   229526,
#   4],
#  [0.752,
#   0.505,
#   9,
#   -7.621,
#   1,
#   0.253,
#   0.535,
#   2.55e-06,
#   0.104,
#   0.419,
#   91.97,
#   197437,
#   4],
#  [0.765,
#   0.473,
#   10,
#   -5.829,
#   1,
#   0.0514,
#   0.287,
#   0,
#   0.391,
#   0.34,
#   119.992,
#   237300,
#   4],
#  [0.703,
#   0.444,
#   11,
#   -9.331,
#   1,
#   0.0417,
#   0.559,
#   0,
#   0.0973,
#   0.712,
#   150.96,
#   242947,
#   4],
#  [0.502,
#   0.912,
#   1,
#   -4.556,
#   1,
#   0.0564,
#   2.55e-05,
#   0.000173,
#   0.106,
#   0.72,
#   116.761,
#   301920,
#   4],
#  [0.851,
#   0.541,
#   0,
#   -6.825,
#   1,
#   0.0505,
#   0.568,
#   0,
#   0.13,
#   0.448,
#   124.959,
#   235545,
#   4],
#  [0.655,
#   0.797,
#   2,
#   -4.787,
#   1,
#   0.153,
#   0.198,
#   0,
#   0.067,
#   0.839,
#   177.928,
#   229360,
#   4],
#  [0.748,
#   0.788,
#   1,
#   -7.055,
#   1,
#   0.0334,
#   0.0591,
#   0,
#   0.0863,
#   0.884,
#   120.076,
#   235493,
#   4],
#  [0.746,
#   0.69,
#   11,
#   -7.956,
#   1,
#   0.164,
#   0.247,
#   0,
#   0.101,
#   0.497,
#   89.977,
#   181733,
#   4],
#  [0.596,
#   0.854,
#   7,
#   -5.114,
#   0,
#   0.463,
#   0.0169,
#   0,
#   0.124,
#   0.152,
#   120.274,
#   203418,
#   4],
#  [0.669,
#   0.832,
#   0,
#   -5.721,
#   1,
#   0.0682,
#   0.0106,
#   0,
#   0.0968,
#   0.7,
#   113.035,
#   237547,
#   4],
#  [0.732,
#   0.396,
#   4,
#   -9.348,
#   0,
#   0.0286,
#   0.0841,
#   3.58e-05,
#   0.105,
#   0.548,
#   90.024,
#   195920,
#   4],
#  [0.367,
#   0.111,
#   4,
#   -14.084,
#   1,
#   0.0972,
#   0.978,
#   3.97e-05,
#   0.0897,
#   0.198,
#   82.642,
#   196077,
#   4],
#  [0.448,
#   0.784,
#   9,
#   -3.686,
#   1,
#   0.0627,
#   0.106,
#   0.000108,
#   0.668,
#   0.236,
#   136.245,
#   186813,
#   4],
#  [0.556,
#   0.538,
#   8,
#   -5.408,
#   0,
#   0.0382,
#   0.0689,
#   0,
#   0.196,
#   0.291,
#   143.95,
#   223347,
#   4],
#  [0.728,
#   0.563,
#   1,
#   -8.053,
#   0,
#   0.134,
#   0.621,
#   0,
#   0.179,
#   0.352,
#   100.017,
#   217707,
#   4],
#  [0.563,
#   0.865,
#   5,
#   -5.277,
#   1,
#   0.16,
#   0.0472,
#   0.000191,
#   0.77,
#   0.601,
#   156.271,
#   209413,
#   4],
#  [0.775,
#   0.613,
#   3,
#   -4.586,
#   0,
#   0.0542,
#   0.109,
#   2.33e-05,
#   0.134,
#   0.797,
#   100.066,
#   208787,
#   4],
#  [0.5,
#   0.748,
#   4,
#   -9.072,
#   1,
#   0.0363,
#   0.127,
#   0,
#   0.447,
#   0.514,
#   118.852,
#   250987,
#   4],
#  [0.559,
#   0.33,
#   9,
#   -8.251,
#   1,
#   0.0285,
#   0.892,
#   0,
#   0.0975,
#   0.285,
#   135.109,
#   285040,
#   4],
#  [0.632, 0.686, 6, -7.665, 0, 0.243, 0.549, 0, 0.2, 0.329, 89.949, 170770, 4],
#  [0.878,
#   0.619,
#   6,
#   -5.56,
#   1,
#   0.102,
#   0.0533,
#   0,
#   0.113,
#   0.639,
#   136.041,
#   157067,
#   4],
#  [0.557,
#   0.442,
#   5,
#   -7.224,
#   1,
#   0.0243,
#   0.731,
#   1.46e-05,
#   0.11,
#   0.213,
#   146.277,
#   309600,
#   4],
#  [0.78,
#   0.68,
#   4,
#   -6.081,
#   1,
#   0.0305,
#   0.141,
#   1.2e-05,
#   0.138,
#   0.594,
#   118.026,
#   180560,
#   4],
#  [0.933,
#   0.528,
#   5,
#   -6.472,
#   0,
#   0.162,
#   0.112,
#   0.329,
#   0.163,
#   0.756,
#   109.975,
#   214653,
#   4],
#  [0.635,
#   0.841,
#   5,
#   -5.379,
#   1,
#   0.0422,
#   0.0134,
#   0,
#   0.0622,
#   0.424,
#   109.021,
#   220734,
#   4],
#  [0.645,
#   0.713,
#   6,
#   -5.355,
#   1,
#   0.0393,
#   0.00835,
#   0,
#   0.113,
#   0.566,
#   74.989,
#   214507,
#   4],
#  [0.702,
#   0.77,
#   9,
#   -5.416,
#   0,
#   0.0482,
#   0.124,
#   0,
#   0.103,
#   0.593,
#   107.951,
#   213520,
#   4],
#  [0.845,
#   0.567,
#   5,
#   -8.118,
#   0,
#   0.0956,
#   0.59,
#   0.00142,
#   0.0811,
#   0.793,
#   125.02,
#   205680,
#   4],
#  [0.72,
#   0.706,
#   1,
#   -4.719,
#   1,
#   0.0473,
#   0.0684,
#   0,
#   0.166,
#   0.62,
#   133.002,
#   187436,
#   4],
#  [0.399,
#   0.787,
#   1,
#   -2.88,
#   1,
#   0.0499,
#   0.0197,
#   6.07e-05,
#   0.0685,
#   0.572,
#   117.089,
#   216120,
#   5],
#  [0.816,
#   0.726,
#   5,
#   -3.998,
#   0,
#   0.129,
#   0.099,
#   0,
#   0.372,
#   0.65,
#   136.048,
#   253390,
#   4],
#  [0.459,
#   0.575,
#   3,
#   -4.858,
#   1,
#   0.0573,
#   0.604,
#   0,
#   0.0885,
#   0.183,
#   111.881,
#   215107,
#   4],
#  [0.785,
#   0.431,
#   10,
#   -8.756,
#   0,
#   0.0364,
#   0.123,
#   0,
#   0.0887,
#   0.236,
#   127.085,
#   159382,
#   4],
#  [0.842,
#   0.801,
#   8,
#   -4.167,
#   0,
#   0.228,
#   0.157,
#   4.82e-06,
#   0.0642,
#   0.617,
#   95.881,
#   212500,
#   4],
#  [0.631,
#   0.927,
#   9,
#   -2.787,
#   0,
#   0.0332,
#   0.199,
#   0.119,
#   0.148,
#   0.465,
#   123.962,
#   222160,
#   4],
#  [0.773,
#   0.819,
#   0,
#   -5.946,
#   0,
#   0.118,
#   0.426,
#   0,
#   0.0679,
#   0.585,
#   92.99,
#   269187,
#   4],
#  [0.75, 0.56, 8, -8.094, 1, 0.105, 0.546, 0, 0.111, 0.459, 140.06, 221440, 4],
#  [0.556,
#   0.864,
#   3,
#   -5.87,
#   0,
#   0.0584,
#   0.00958,
#   0,
#   0.209,
#   0.4,
#   105.143,
#   216880,
#   4],
#  [0.829,
#   0.539,
#   11,
#   -7.359,
#   0,
#   0.208,
#   0.136,
#   1.78e-06,
#   0.103,
#   0.388,
#   99.96,
#   149547,
#   4],
#  [0.481,
#   0.451,
#   5,
#   -6.095,
#   0,
#   0.0347,
#   0.336,
#   0,
#   0.0872,
#   0.289,
#   157.966,
#   295493,
#   4],
#  [0.551,
#   0.537,
#   11,
#   -7.595,
#   1,
#   0.034,
#   0.705,
#   0,
#   0.0802,
#   0.493,
#   126.421,
#   196493,
#   4],
#  [0.608,
#   0.798,
#   6,
#   -5.092,
#   0,
#   0.0432,
#   0.0736,
#   0,
#   0.156,
#   0.501,
#   92.943,
#   185360,
#   4],
#  [0.807,
#   0.893,
#   11,
#   -3.745,
#   0,
#   0.0347,
#   0.0451,
#   2.79e-05,
#   0.366,
#   0.537,
#   126.011,
#   230747,
#   4],
#  [0.733,
#   0.71,
#   5,
#   -5.849,
#   0,
#   0.0292,
#   0.145,
#   0.115,
#   0.0956,
#   0.965,
#   127.975,
#   239600,
#   4],
#  [0.836,
#   0.544,
#   7,
#   -5.975,
#   1,
#   0.0943,
#   0.0403,
#   0,
#   0.0824,
#   0.51,
#   97.028,
#   217947,
#   4],
#  [0.726,
#   0.431,
#   8,
#   -8.765,
#   0,
#   0.135,
#   0.731,
#   0,
#   0.696,
#   0.348,
#   144.026,
#   173333,
#   4],
#  [0.764,
#   0.705,
#   8,
#   -3.463,
#   1,
#   0.0284,
#   0.259,
#   8.92e-05,
#   0.12,
#   0.781,
#   110.97,
#   208667,
#   4],
#  [0.744,
#   0.804,
#   1,
#   -6.327,
#   1,
#   0.0677,
#   0.0231,
#   0,
#   0.0494,
#   0.426,
#   104.823,
#   205715,
#   4],
#  [0.621,
#   0.601,
#   6,
#   -5.616,
#   0,
#   0.148,
#   0.0522,
#   0,
#   0.46,
#   0.457,
#   116.735,
#   163636,
#   5],
#  [0.259,
#   0.437,
#   11,
#   -6.589,
#   0,
#   0.0386,
#   0.102,
#   1.32e-06,
#   0.106,
#   0.0951,
#   180.042,
#   239000,
#   4],
#  [0.734,
#   0.442,
#   0,
#   -8.432,
#   1,
#   0.0557,
#   0.0594,
#   1.63e-05,
#   0.213,
#   0.0973,
#   117.967,
#   245653,
#   4],
#  [0.612,
#   0.28,
#   0,
#   -8.648,
#   1,
#   0.0434,
#   0.932,
#   0,
#   0.088,
#   0.387,
#   72.795,
#   213827,
#   4],
#  [0.429,
#   0.661,
#   11,
#   -7.227,
#   1,
#   0.0281,
#   0.00239,
#   0.000121,
#   0.234,
#   0.285,
#   173.372,
#   266773,
#   4],
#  [0.453,
#   0.496,
#   5,
#   -5.785,
#   1,
#   0.0453,
#   0.554,
#   2.65e-05,
#   0.0772,
#   0.501,
#   80.994,
#   239317,
#   4],
#  [0.579,
#   0.904,
#   5,
#   -2.729,
#   1,
#   0.0618,
#   0.193,
#   0,
#   0.064,
#   0.681,
#   82.014,
#   190947,
#   4],
#  [0.908,
#   0.669,
#   7,
#   -2.827,
#   1,
#   0.0738,
#   0.00286,
#   0,
#   0.237,
#   0.662,
#   112.238,
#   290320,
#   4],
#  [0.446,
#   0.952,
#   6,
#   -5.321,
#   1,
#   0.0523,
#   0.0901,
#   0.0857,
#   0.112,
#   0.624,
#   125.303,
#   356067,
#   4],
#  [0.262,
#   0.606,
#   8,
#   -6.646,
#   1,
#   0.0484,
#   0.247,
#   0,
#   0.125,
#   0.275,
#   189.857,
#   252534,
#   4],
#  [0.717,
#   0.73,
#   9,
#   -4.729,
#   0,
#   0.0568,
#   0.383,
#   0,
#   0.398,
#   0.792,
#   102.002,
#   251173,
#   4],
#  [0.671,
#   0.373,
#   9,
#   -18.064,
#   1,
#   0.0323,
#   0.257,
#   8.01e-05,
#   0.0481,
#   0.732,
#   92.718,
#   295893,
#   4],
#  [0.82,
#   0.452,
#   1,
#   -9.796,
#   1,
#   0.0348,
#   0.543,
#   0.00294,
#   0.0714,
#   0.74,
#   117.401,
#   253920,
#   4],
#  [0.52,
#   0.761,
#   4,
#   -3.093,
#   1,
#   0.0853,
#   0.256,
#   4.96e-06,
#   0.17,
#   0.286,
#   141.971,
#   180823,
#   4],
#  [0.799,
#   0.701,
#   2,
#   -3.272,
#   1,
#   0.282,
#   0.309,
#   7.36e-05,
#   0.0514,
#   0.607,
#   100.946,
#   201920,
#   4],
#  [0.774,
#   0.753,
#   4,
#   -5.446,
#   0,
#   0.0517,
#   0.152,
#   0,
#   0.0371,
#   0.896,
#   119.002,
#   219147,
#   4],
#  [0.753,
#   0.657,
#   7,
#   -3.061,
#   1,
#   0.0449,
#   0.171,
#   0,
#   0.112,
#   0.437,
#   107.01,
#   184732,
#   4],
#  [0.659,
#   0.291,
#   2,
#   -8.275,
#   0,
#   0.0348,
#   0.405,
#   0,
#   0.0771,
#   0.406,
#   119.829,
#   277680,
#   3],
#  [0.835,
#   0.626,
#   1,
#   -5.833,
#   1,
#   0.125,
#   0.0589,
#   6e-05,
#   0.396,
#   0.35,
#   91.03,
#   217925,
#   4],
#  [0.548,
#   0.704,
#   11,
#   -4.838,
#   0,
#   0.0777,
#   0.0168,
#   2.25e-05,
#   0.143,
#   0.288,
#   104.666,
#   185040,
#   4],
#  [0.803,
#   0.585,
#   8,
#   -5.861,
#   1,
#   0.0432,
#   0.103,
#   3.94e-06,
#   0.0644,
#   0.593,
#   105.017,
#   214480,
#   4],
#  [0.799,
#   0.539,
#   1,
#   -6.351,
#   1,
#   0.0421,
#   0.199,
#   1.66e-05,
#   0.165,
#   0.394,
#   136.948,
#   202547,
#   4],
#  [0.677, 0.696, 0, -6.181, 1, 0.119, 0.321, 0, 0.42, 0.464, 90.03, 198082, 4],
#  [0.626,
#   0.88,
#   9,
#   -2.384,
#   0,
#   0.0504,
#   0.205,
#   0,
#   0.128,
#   0.534,
#   95.079,
#   202621,
#   4],
#  [0.833,
#   0.434,
#   2,
#   -8.795,
#   1,
#   0.431,
#   0.0102,
#   0.0219,
#   0.165,
#   0.281,
#   150.062,
#   204600,
#   4],
#  [0.492, 0.275, 6, -13.4, 0, 0.3, 0.687, 0, 0.101, 0.18, 92.6, 251034, 4],
#  [0.797,
#   0.533,
#   0,
#   -9.74,
#   0,
#   0.0412,
#   0.0172,
#   0.000152,
#   0.103,
#   0.329,
#   131.036,
#   146520,
#   4],
#  [0.598,
#   0.427,
#   7,
#   -8.764,
#   0,
#   0.0317,
#   0.0546,
#   5.83e-06,
#   0.21,
#   0.0605,
#   76.469,
#   175721,
#   4],
#  [0.864,
#   0.495,
#   0,
#   -7.036,
#   1,
#   0.037,
#   0.591,
#   0.000133,
#   0.0992,
#   0.72,
#   129.062,
#   244973,
#   4],
#  [0.64,
#   0.533,
#   0,
#   -6.596,
#   1,
#   0.0706,
#   0.119,
#   0,
#   0.0864,
#   0.515,
#   99.968,
#   220781,
#   4],
#  [0.578,
#   0.866,
#   1,
#   -3.804,
#   1,
#   0.0619,
#   0.00701,
#   0,
#   0.257,
#   0.619,
#   128.038,
#   199080,
#   4],
#  [0.697,
#   0.683,
#   1,
#   -2.881,
#   0,
#   0.117,
#   0.0372,
#   0,
#   0.137,
#   0.603,
#   96.133,
#   186987,
#   4],
#  [0.676,
#   0.771,
#   8,
#   -3.675,
#   1,
#   0.0483,
#   0.0237,
#   7e-06,
#   0.102,
#   0.569,
#   99.048,
#   207133,
#   4],
#  [0.64,
#   0.647,
#   5,
#   -8.114,
#   0,
#   0.186,
#   0.124,
#   0,
#   0.0801,
#   0.546,
#   92.979,
#   197867,
#   4],
#  [0.662,
#   0.714,
#   5,
#   -5.68,
#   0,
#   0.121,
#   0.312,
#   0,
#   0.179,
#   0.464,
#   147.997,
#   212120,
#   4],
#  [0.508,
#   0.72,
#   11,
#   -5.908,
#   0,
#   0.0628,
#   0.272,
#   0,
#   0.0563,
#   0.472,
#   79.983,
#   261640,
#   4],
#  [0.745,
#   0.356,
#   1,
#   -10.425,
#   1,
#   0.0941,
#   0.172,
#   0.00943,
#   0.123,
#   0.607,
#   160.033,
#   326933,
#   4],
#  [0.92,
#   0.654,
#   11,
#   -3.051,
#   0,
#   0.0401,
#   0.0236,
#   0.0153,
#   0.036,
#   0.847,
#   117.046,
#   293827,
#   4],
#  [0.604,
#   0.788,
#   0,
#   -3.673,
#   0,
#   0.103,
#   0.0678,
#   0.153,
#   0.127,
#   0.301,
#   126.06,
#   245040,
#   4],
#  [0.729,
#   0.756,
#   8,
#   -5.119,
#   1,
#   0.0294,
#   0.131,
#   0,
#   0.0527,
#   0.522,
#   104.945,
#   228293,
#   4],
#  [0.573,
#   0.902,
#   6,
#   -7.638,
#   0,
#   0.054,
#   0.018,
#   0.00125,
#   0.0928,
#   0.876,
#   84.412,
#   225280,
#   4],
#  [0.694,
#   0.77,
#   6,
#   -5.335,
#   1,
#   0.149,
#   0.176,
#   1.1e-05,
#   0.118,
#   0.163,
#   125.905,
#   184560,
#   4],
#  [0.736,
#   0.449,
#   1,
#   -11.462,
#   0,
#   0.425,
#   0.33,
#   0.000162,
#   0.0898,
#   0.326,
#   80.126,
#   219080,
#   4],
#  [0.65,
#   0.736,
#   6,
#   -5.84,
#   0,
#   0.229,
#   0.0528,
#   0,
#   0.235,
#   0.613,
#   159.173,
#   226160,
#   4],
#  [0.62,
#   0.574,
#   5,
#   -7.788,
#   0,
#   0.0479,
#   0.569,
#   0,
#   0.19,
#   0.357,
#   100.023,
#   250173,
#   4],
#  [0.643,
#   0.783,
#   10,
#   -6.458,
#   1,
#   0.0856,
#   0.047,
#   0,
#   0.083,
#   0.579,
#   154.084,
#   163870,
#   4],
#  [0.421,
#   0.407,
#   10,
#   -7.445,
#   1,
#   0.0267,
#   0.309,
#   0.000961,
#   0.11,
#   0.161,
#   139.028,
#   285120,
#   3],
#  [0.68,
#   0.826,
#   0,
#   -5.487,
#   1,
#   0.0309,
#   0.0212,
#   1.24e-05,
#   0.543,
#   0.644,
#   118.051,
#   215627,
#   4],
#  [0.715,
#   0.605,
#   0,
#   -5.128,
#   0,
#   0.0428,
#   0.239,
#   1.41e-05,
#   0.189,
#   0.454,
#   122.956,
#   212733,
#   4],
#  [0.501,
#   0.519,
#   4,
#   -5.88,
#   0,
#   0.0409,
#   0.109,
#   0,
#   0.454,
#   0.168,
#   133.99,
#   195707,
#   4],
#  [0.671,
#   0.711,
#   2,
#   -7.813,
#   1,
#   0.0478,
#   0.422,
#   0,
#   0.104,
#   0.466,
#   113.809,
#   248440,
#   4],
#  [0.669,
#   0.308,
#   11,
#   -10.068,
#   1,
#   0.029,
#   0.883,
#   0,
#   0.0984,
#   0.52,
#   64.934,
#   121887,
#   4],
#  [0.336,
#   0.627,
#   7,
#   -7.463,
#   1,
#   0.0384,
#   0.164,
#   0,
#   0.0708,
#   0.35,
#   150.273,
#   241107,
#   4],
#  [0.739,
#   0.756,
#   4,
#   -4.828,
#   1,
#   0.0394,
#   0.0136,
#   0,
#   0.37,
#   0.523,
#   110.028,
#   231387,
#   4],
#  [0.527,
#   0.835,
#   6,
#   -5.298,
#   1,
#   0.0433,
#   0.0166,
#   0,
#   0.249,
#   0.654,
#   125.983,
#   176658,
#   4],
#  [0.866,
#   0.613,
#   0,
#   -6.385,
#   1,
#   0.151,
#   0.0293,
#   0,
#   0.104,
#   0.359,
#   98.001,
#   229210,
#   4],
#  [0.486,
#   0.617,
#   5,
#   -7.115,
#   0,
#   0.0287,
#   0.0954,
#   3.23e-06,
#   0.109,
#   0.417,
#   138.015,
#   242373,
#   4],
#  [0.725,
#   0.534,
#   11,
#   -6.238,
#   1,
#   0.0946,
#   0.0752,
#   0,
#   0.0919,
#   0.558,
#   91.974,
#   219320,
#   4],
#  [0.726,
#   0.698,
#   5,
#   -4.165,
#   1,
#   0.0431,
#   0.049,
#   0,
#   0.309,
#   0.867,
#   143.994,
#   233478,
#   4],
#  [0.679,
#   0.715,
#   9,
#   -6.383,
#   1,
#   0.0407,
#   0.0755,
#   0,
#   0.271,
#   0.571,
#   127.435,
#   214148,
#   4],
#  [0.809,
#   0.463,
#   11,
#   -11.377,
#   1,
#   0.0396,
#   0.256,
#   0.085,
#   0.109,
#   0.364,
#   111.98,
#   298941,
#   4],
#  [0.699,
#   0.713,
#   9,
#   -5.507,
#   0,
#   0.0594,
#   0.04,
#   3.11e-06,
#   0.294,
#   0.354,
#   121.993,
#   205920,
#   4],
#  [0.599,
#   0.667,
#   7,
#   -4.267,
#   1,
#   0.0367,
#   0.0533,
#   0,
#   0.134,
#   0.817,
#   80.984,
#   288877,
#   4],
#  [0.704,
#   0.225,
#   6,
#   -14.454,
#   0,
#   0.0994,
#   0.902,
#   0.657,
#   0.106,
#   0.243,
#   120.006,
#   245426,
#   4],
#  [0.724,
#   0.804,
#   11,
#   -4.614,
#   0,
#   0.0448,
#   0.124,
#   0,
#   0.204,
#   0.306,
#   124.987,
#   197993,
#   4],
#  [0.818,
#   0.803,
#   1,
#   -4.282,
#   1,
#   0.0797,
#   0.034,
#   0,
#   0.153,
#   0.632,
#   106.97,
#   225983,
#   4],
#  [0.842,
#   0.734,
#   1,
#   -5.065,
#   0,
#   0.0588,
#   0.0427,
#   0,
#   0.106,
#   0.952,
#   137.958,
#   181027,
#   4],
#  [0.743,
#   0.446,
#   4,
#   -7.807,
#   0,
#   0.0683,
#   0.0039,
#   0.118,
#   0.337,
#   0.278,
#   123.596,
#   232107,
#   4],
#  [0.579,
#   0.508,
#   2,
#   -9.484,
#   1,
#   0.027,
#   0.00574,
#   0.000494,
#   0.0575,
#   0.609,
#   147.125,
#   391376,
#   4],
#  [0.737,
#   0.86,
#   8,
#   -2.652,
#   0,
#   0.0593,
#   0.11,
#   1.94e-06,
#   0.0574,
#   0.656,
#   93.989,
#   193227,
#   4],
#  [0.694,
#   0.712,
#   7,
#   -3.923,
#   0,
#   0.046,
#   0.132,
#   0,
#   0.211,
#   0.799,
#   98.023,
#   201122,
#   4],
#  [0.714,
#   0.8,
#   11,
#   -4.808,
#   0,
#   0.0504,
#   0.127,
#   0,
#   0.359,
#   0.589,
#   134.002,
#   211560,
#   4],
#  [0.891,
#   0.628,
#   2,
#   -7.863,
#   1,
#   0.0551,
#   0.00258,
#   0.00019,
#   0.0504,
#   0.552,
#   134.966,
#   267067,
#   4],
#  [0.61,
#   0.624,
#   2,
#   -4.773,
#   1,
#   0.309,
#   0.6,
#   2.12e-06,
#   0.243,
#   0.244,
#   176.169,
#   250534,
#   4],
#  [0.795,
#   0.8,
#   1,
#   -6.32,
#   1,
#   0.0309,
#   0.0354,
#   7.25e-05,
#   0.0915,
#   0.934,
#   116.032,
#   202735,
#   4],
#  [0.522,
#   0.385,
#   0,
#   -7.355,
#   1,
#   0.0288,
#   0.536,
#   0,
#   0.135,
#   0.236,
#   89.792,
#   207520,
#   4],
#  [0.697,
#   0.832,
#   9,
#   -7.264,
#   1,
#   0.0298,
#   0.168,
#   0.00131,
#   0.269,
#   0.979,
#   125.926,
#   215093,
#   4],
#  [0.461,
#   0.834,
#   2,
#   -4.868,
#   1,
#   0.0989,
#   0.0232,
#   1.14e-05,
#   0.14,
#   0.471,
#   135.007,
#   261154,
#   4],
#  [0.516,
#   0.595,
#   5,
#   -4.63,
#   1,
#   0.0313,
#   0.0275,
#   0,
#   0.109,
#   0.222,
#   119.972,
#   340707,
#   4],
#  [0.596,
#   0.856,
#   4,
#   -3.556,
#   0,
#   0.0346,
#   0.0211,
#   0.0178,
#   0.141,
#   0.743,
#   127.949,
#   222533,
#   4],
#  [0.734,
#   0.57,
#   7,
#   -7.066,
#   0,
#   0.133,
#   0.847,
#   2.14e-05,
#   0.112,
#   0.689,
#   129.953,
#   95467,
#   4],
#  [0.763,
#   0.726,
#   1,
#   -6.405,
#   1,
#   0.282,
#   0.259,
#   0,
#   0.0976,
#   0.349,
#   139.059,
#   126346,
#   4],
#  [0.652,
#   0.557,
#   1,
#   -5.714,
#   0,
#   0.0318,
#   0.74,
#   0,
#   0.124,
#   0.483,
#   150.073,
#   169354,
#   4],
#  [0.496,
#   0.863,
#   9,
#   -4.153,
#   1,
#   0.0381,
#   0.0046,
#   0,
#   0.639,
#   0.243,
#   110.018,
#   185587,
#   4],
#  [0.573,
#   0.739,
#   0,
#   -5.74,
#   1,
#   0.129,
#   0.0285,
#   0,
#   0.111,
#   0.451,
#   97.085,
#   230227,
#   4],
#  [0.64,
#   0.74,
#   4,
#   -4.083,
#   1,
#   0.0284,
#   0.0115,
#   0.00678,
#   0.167,
#   0.785,
#   116.879,
#   216320,
#   4],
#  [0.817,
#   0.539,
#   6,
#   -6.349,
#   0,
#   0.0621,
#   0.0141,
#   0.000496,
#   0.099,
#   0.158,
#   97.062,
#   210368,
#   4],
#  [0.756,
#   0.674,
#   0,
#   -6.518,
#   0,
#   0.0959,
#   0.0184,
#   0,
#   0.158,
#   0.389,
#   111.995,
#   251467,
#   4],
#  [0.545,
#   0.366,
#   2,
#   -9.51,
#   1,
#   0.0378,
#   0.969,
#   0.267,
#   0.641,
#   0.1,
#   86.997,
#   208212,
#   3],
#  [0.584,
#   0.7,
#   11,
#   -4.275,
#   1,
#   0.0456,
#   0.117,
#   0,
#   0.0939,
#   0.438,
#   124.944,
#   202747,
#   4],
#  [0.671,
#   0.529,
#   0,
#   -7.226,
#   1,
#   0.307,
#   0.0769,
#   0.000335,
#   0.0856,
#   0.203,
#   161.989,
#   165820,
#   4],
#  [0.31,
#   0.7,
#   9,
#   -5.678,
#   1,
#   0.047,
#   0.011,
#   0.00965,
#   0.0828,
#   0.763,
#   188.386,
#   255493,
#   4],
#  [0.88,
#   0.751,
#   7,
#   -4.258,
#   0,
#   0.0874,
#   0.177,
#   6.43e-05,
#   0.106,
#   0.884,
#   117.948,
#   157606,
#   4],
#  [0.662,
#   0.757,
#   5,
#   -6.818,
#   0,
#   0.144,
#   0.291,
#   0,
#   0.0885,
#   0.962,
#   159.945,
#   233293,
#   4],
#  [0.673,
#   0.886,
#   1,
#   -4.44,
#   0,
#   0.0431,
#   0.185,
#   0,
#   0.0826,
#   0.795,
#   97.012,
#   216773,
#   4],
#  [0.624, 0.876, 9, -3.374, 1, 0.1, 0.0735, 0, 0.327, 0.781, 99.943, 170827, 4],
#  [0.935,
#   0.454,
#   1,
#   -7.509,
#   1,
#   0.375,
#   0.0194,
#   0,
#   0.0824,
#   0.357,
#   133.073,
#   187541,
#   4],
#  [0.671,
#   0.314,
#   5,
#   -8.091,
#   0,
#   0.244,
#   0.11,
#   0,
#   0.0825,
#   0.296,
#   110.898,
#   191600,
#   4],
#  [0.8, 0.658, 1, -6.142, 0, 0.079, 0.25, 0, 0.111, 0.462, 140.042, 195429, 4],
#  [0.596,
#   0.552,
#   0,
#   -10.278,
#   0,
#   0.097,
#   0.0765,
#   0.334,
#   0.104,
#   0.112,
#   97.949,
#   229320,
#   4],
#  [0.773,
#   0.758,
#   1,
#   -4.993,
#   1,
#   0.0381,
#   0.0422,
#   0,
#   0.305,
#   0.925,
#   144.033,
#   224840,
#   4],
#  [0.754,
#   0.646,
#   7,
#   -5.795,
#   1,
#   0.317,
#   0.152,
#   1.85e-05,
#   0.108,
#   0.429,
#   176.089,
#   242573,
#   4],
#  [0.774,
#   0.554,
#   0,
#   -7.909,
#   1,
#   0.0383,
#   0.207,
#   0,
#   0.132,
#   0.349,
#   99.034,
#   162547,
#   4],
#  [0.576,
#   0.766,
#   10,
#   -4.943,
#   0,
#   0.449,
#   0.028,
#   1.68e-06,
#   0.366,
#   0.236,
#   144.833,
#   246761,
#   4],
#  [0.706, 0.786, 0, -3.417, 0, 0.091, 0.26, 0, 0.38, 0.751, 150.028, 199387, 4],
#  [0.747,
#   0.877,
#   9,
#   -3.782,
#   0,
#   0.0664,
#   0.0375,
#   0.000833,
#   0.233,
#   0.752,
#   107.991,
#   166138,
#   4],
#  [0.646,
#   0.741,
#   5,
#   -4.973,
#   0,
#   0.034,
#   0.0275,
#   0,
#   0.312,
#   0.571,
#   123.077,
#   203000,
#   4],
#  [0.698,
#   0.633,
#   8,
#   -4.946,
#   1,
#   0.0597,
#   0.0605,
#   0.000194,
#   0.0926,
#   0.552,
#   96.924,
#   232187,
#   4],
#  [0.69,
#   0.622,
#   5,
#   -5.025,
#   0,
#   0.0622,
#   0.253,
#   0,
#   0.116,
#   0.544,
#   102.04,
#   210091,
#   4],
#  [0.728,
#   0.616,
#   4,
#   -4.238,
#   1,
#   0.0645,
#   0.378,
#   0,
#   0.105,
#   0.508,
#   99.962,
#   181880,
#   4],
#  [0.949,
#   0.661,
#   5,
#   -4.244,
#   0,
#   0.0572,
#   0.0302,
#   0,
#   0.0454,
#   0.76,
#   104.504,
#   284200,
#   4],
#  [0.778,
#   0.824,
#   10,
#   -5.892,
#   0,
#   0.0707,
#   0.284,
#   0,
#   0.405,
#   0.758,
#   100.024,
#   218093,
#   4],
#  [0.782,
#   0.559,
#   6,
#   -7.106,
#   0,
#   0.0767,
#   0.125,
#   0,
#   0.385,
#   0.685,
#   129.992,
#   188344,
#   1],
#  [0.715,
#   0.655,
#   0,
#   -6.425,
#   1,
#   0.137,
#   0.0525,
#   0,
#   0.115,
#   0.531,
#   95.078,
#   207333,
#   4],
#  [0.584,
#   0.54,
#   1,
#   -7.786,
#   0,
#   0.0576,
#   0.0895,
#   0,
#   0.261,
#   0.195,
#   137.972,
#   220883,
#   4],
#  [0.625,
#   0.726,
#   10,
#   -7.731,
#   0,
#   0.155,
#   0.00728,
#   0,
#   0.318,
#   0.483,
#   103.98,
#   311867,
#   4],
#  [0.799,
#   0.586,
#   11,
#   -6.735,
#   1,
#   0.0377,
#   0.162,
#   2.03e-06,
#   0.193,
#   0.549,
#   120.97,
#   227833,
#   4],
#  [0.88,
#   0.428,
#   9,
#   -8.28,
#   1,
#   0.206,
#   0.149,
#   5.05e-05,
#   0.114,
#   0.333,
#   100.007,
#   172800,
#   4],
#  [0.461,
#   0.593,
#   1,
#   -4.954,
#   1,
#   0.0356,
#   0.17,
#   0,
#   0.307,
#   0.175,
#   134.17,
#   228373,
#   3],
#  [0.801,
#   0.795,
#   1,
#   -5.115,
#   0,
#   0.0504,
#   0.0417,
#   0.000113,
#   0.0717,
#   0.754,
#   79.028,
#   163253,
#   4],
#  [0.651,
#   0.663,
#   0,
#   -5.569,
#   0,
#   0.0281,
#   0.228,
#   0,
#   0.0994,
#   0.465,
#   102.0,
#   259453,
#   4],
#  [0.741,
#   0.52,
#   8,
#   -7.513,
#   1,
#   0.0656,
#   0.45,
#   1.97e-06,
#   0.222,
#   0.347,
#   102.998,
#   171030,
#   4],
#  [0.828,
#   0.492,
#   0,
#   -9.744,
#   1,
#   0.0276,
#   0.0644,
#   0.00428,
#   0.128,
#   0.789,
#   120.151,
#   257800,
#   4],
#  [0.581,
#   0.963,
#   11,
#   -4.087,
#   1,
#   0.0981,
#   0.0295,
#   0,
#   0.139,
#   0.788,
#   129.992,
#   204160,
#   4],
#  [0.585,
#   0.909,
#   8,
#   -6.474,
#   1,
#   0.0707,
#   0.0891,
#   9.7e-05,
#   0.119,
#   0.758,
#   93.372,
#   210747,
#   4],
#  [0.728,
#   0.415,
#   8,
#   -6.852,
#   1,
#   0.0639,
#   0.401,
#   0,
#   0.0616,
#   0.455,
#   114.145,
#   176320,
#   4],
#  [0.737,
#   0.802,
#   0,
#   -4.771,
#   1,
#   0.0878,
#   0.468,
#   0,
#   0.0931,
#   0.682,
#   144.015,
#   172325,
#   4],
#  [0.574,
#   0.913,
#   6,
#   -4.793,
#   0,
#   0.133,
#   0.061,
#   0.00158,
#   0.156,
#   0.423,
#   115.728,
#   208400,
#   4],
#  [0.799,
#   0.597,
#   5,
#   -5.131,
#   0,
#   0.0611,
#   0.0788,
#   5.66e-06,
#   0.1,
#   0.419,
#   110.001,
#   199849,
#   4],
#  [0.568,
#   0.686,
#   11,
#   -4.901,
#   0,
#   0.0903,
#   0.133,
#   0,
#   0.11,
#   0.4,
#   148.294,
#   208733,
#   4],
#  [0.742,
#   0.713,
#   1,
#   -5.522,
#   0,
#   0.0303,
#   0.0205,
#   0,
#   0.059,
#   0.879,
#   120.032,
#   189960,
#   4],
#  [0.623,
#   0.734,
#   9,
#   -5.948,
#   1,
#   0.107,
#   0.0162,
#   1.75e-06,
#   0.145,
#   0.37,
#   107.853,
#   244453,
#   4],
#  [0.532,
#   0.887,
#   0,
#   -3.757,
#   1,
#   0.0335,
#   0.0778,
#   0.000214,
#   0.294,
#   0.795,
#   122.511,
#   249293,
#   4],
#  [0.762,
#   0.766,
#   7,
#   -3.955,
#   1,
#   0.0343,
#   0.00776,
#   6.98e-05,
#   0.128,
#   0.442,
#   130.001,
#   287120,
#   4],
#  [0.745,
#   0.642,
#   7,
#   -6.257,
#   0,
#   0.287,
#   0.0204,
#   0,
#   0.0658,
#   0.226,
#   179.974,
#   131240,
#   4],
#  [0.685,
#   0.692,
#   2,
#   -5.122,
#   1,
#   0.0457,
#   0.328,
#   0,
#   0.153,
#   0.578,
#   159.966,
#   240051,
#   5],
#  [0.885,
#   0.581,
#   11,
#   -8.813,
#   1,
#   0.0378,
#   0.427,
#   0.000204,
#   0.0759,
#   0.728,
#   114.016,
#   313684,
#   4],
#  [0.749,
#   0.925,
#   10,
#   -5.034,
#   1,
#   0.227,
#   0.241,
#   0,
#   0.52,
#   0.641,
#   86.989,
#   263373,
#   4],
#  [0.209,
#   0.417,
#   3,
#   -8.74,
#   1,
#   0.0338,
#   0.164,
#   0.00196,
#   0.113,
#   0.124,
#   138.178,
#   295533,
#   4],
#  [0.604,
#   0.366,
#   5,
#   -7.519,
#   1,
#   0.0282,
#   0.578,
#   0,
#   0.133,
#   0.13,
#   141.981,
#   224695,
#   4],
#  [0.826,
#   0.773,
#   11,
#   -4.218,
#   0,
#   0.0524,
#   0.323,
#   0,
#   0.143,
#   0.761,
#   126.899,
#   238200,
#   4],
#  [0.706,
#   0.643,
#   11,
#   -6.929,
#   0,
#   0.234,
#   0.0242,
#   0,
#   0.262,
#   0.885,
#   143.931,
#   203760,
#   4],
#  [0.763,
#   0.598,
#   11,
#   -6.865,
#   1,
#   0.0539,
#   0.0714,
#   0,
#   0.112,
#   0.182,
#   140.987,
#   190678,
#   4],
#  [0.421,
#   0.873,
#   10,
#   -4.343,
#   1,
#   0.0564,
#   0.0654,
#   0,
#   0.123,
#   0.629,
#   84.786,
#   202533,
#   4],
#  [0.897,
#   0.662,
#   1,
#   -6.903,
#   0,
#   0.292,
#   0.0852,
#   0,
#   0.534,
#   0.389,
#   112.511,
#   145543,
#   4],
#  [0.548,
#   0.653,
#   5,
#   -3.875,
#   1,
#   0.081,
#   0.456,
#   0,
#   0.103,
#   0.163,
#   150.068,
#   174853,
#   4],
#  [0.315,
#   0.715,
#   11,
#   -8.072,
#   0,
#   0.0362,
#   0.00125,
#   7.97e-06,
#   0.0942,
#   0.497,
#   155.925,
#   289533,
#   3],
#  [0.579,
#   0.736,
#   6,
#   -3.863,
#   0,
#   0.0527,
#   0.31,
#   0,
#   0.198,
#   0.613,
#   127.999,
#   230613,
#   4],
#  [0.636,
#   0.815,
#   5,
#   -5.098,
#   0,
#   0.0581,
#   0.0185,
#   0,
#   0.163,
#   0.636,
#   123.063,
#   219043,
#   4],
#  [0.445,
#   0.537,
#   4,
#   -8.532,
#   0,
#   0.04,
#   0.695,
#   1.6e-05,
#   0.0941,
#   0.131,
#   122.764,
#   244360,
#   4],
#  [0.652,
#   0.698,
#   10,
#   -4.667,
#   0,
#   0.042,
#   0.00112,
#   0.000115,
#   0.0886,
#   0.47,
#   96.021,
#   202067,
#   4],
#  [0.647,
#   0.514,
#   8,
#   -10.05,
#   1,
#   0.0593,
#   0.0655,
#   0,
#   0.398,
#   0.386,
#   79.975,
#   240693,
#   4],
#  [0.824,
#   0.764,
#   5,
#   -4.175,
#   0,
#   0.0854,
#   0.0888,
#   0.00294,
#   0.117,
#   0.881,
#   107.998,
#   172627,
#   4],
#  [0.787,
#   0.673,
#   11,
#   -4.583,
#   0,
#   0.159,
#   0.264,
#   3.35e-06,
#   0.0904,
#   0.779,
#   110.962,
#   237893,
#   4],
#  [0.628,
#   0.593,
#   8,
#   -5.036,
#   1,
#   0.0323,
#   0.093,
#   1.65e-06,
#   0.096,
#   0.104,
#   125.026,
#   197267,
#   4],
#  [0.689, 0.694, 6, -5.83, 0, 0.027, 0.257, 0, 0.148, 0.482, 99.039, 213307, 4],
#  [0.502,
#   0.89,
#   4,
#   -5.175,
#   1,
#   0.0364,
#   0.000147,
#   0.0117,
#   0.217,
#   0.259,
#   133.52,
#   292880,
#   4],
#  [0.72,
#   0.791,
#   1,
#   -4.689,
#   1,
#   0.124,
#   0.0384,
#   0,
#   0.157,
#   0.756,
#   102.071,
#   175427,
#   4],
#  [0.778,
#   0.695,
#   4,
#   -6.865,
#   0,
#   0.0913,
#   0.175,
#   0,
#   0.15,
#   0.472,
#   149.996,
#   132780,
#   4],
#  [0.667,
#   0.373,
#   4,
#   -9.389,
#   1,
#   0.05,
#   0.785,
#   0,
#   0.0906,
#   0.0823,
#   124.148,
#   169266,
#   4],
#  [0.653,
#   0.658,
#   2,
#   -6.428,
#   1,
#   0.0304,
#   0.0215,
#   1.66e-06,
#   0.0939,
#   0.219,
#   99.99,
#   221507,
#   4],
#  [0.786,
#   0.808,
#   7,
#   -3.702,
#   1,
#   0.0881,
#   0.0846,
#   0.000289,
#   0.0822,
#   0.608,
#   105.029,
#   301714,
#   4],
#  [0.559,
#   0.345,
#   4,
#   -13.496,
#   1,
#   0.0459,
#   0.0576,
#   0.000105,
#   0.141,
#   0.458,
#   84.581,
#   264307,
#   4],
#  [0.816,
#   0.775,
#   11,
#   -3.323,
#   1,
#   0.234,
#   0.16,
#   0.00031,
#   0.0543,
#   0.527,
#   93.431,
#   270587,
#   4],
#  [0.644,
#   0.648,
#   1,
#   -4.601,
#   1,
#   0.118,
#   0.276,
#   0,
#   0.135,
#   0.44,
#   179.951,
#   206710,
#   4],
#  [0.515,
#   0.43,
#   7,
#   -9.935,
#   1,
#   0.0369,
#   0.0102,
#   0.000141,
#   0.129,
#   0.104,
#   91.841,
#   238640,
#   4],
#  [0.442,
#   0.612,
#   2,
#   -7.222,
#   1,
#   0.112,
#   0.584,
#   5.7e-06,
#   0.37,
#   0.178,
#   180.917,
#   215507,
#   4],
#  [0.903,
#   0.675,
#   11,
#   -3.445,
#   0,
#   0.214,
#   0.542,
#   1.28e-05,
#   0.0595,
#   0.442,
#   96.507,
#   417920,
#   4],
#  [0.4, 0.915, 0, -4.89, 1, 0.28, 0.0846, 0, 0.0503, 0.878, 88.917, 198773, 3],
#  [0.795,
#   0.574,
#   2,
#   -6.903,
#   0,
#   0.487,
#   0.067,
#   0,
#   0.15,
#   0.537,
#   142.053,
#   237918,
#   4],
#  [0.808,
#   0.745,
#   10,
#   -5.26,
#   0,
#   0.342,
#   0.145,
#   0,
#   0.292,
#   0.829,
#   165.995,
#   210800,
#   4],
#  [0.357,
#   0.425,
#   5,
#   -7.301,
#   1,
#   0.0333,
#   0.584,
#   0,
#   0.322,
#   0.27,
#   102.078,
#   198040,
#   3],
#  [0.546,
#   0.311,
#   1,
#   -10.396,
#   1,
#   0.0288,
#   0.818,
#   1.65e-05,
#   0.107,
#   0.246,
#   147.464,
#   260533,
#   4],
#  [0.759,
#   0.459,
#   8,
#   -5.187,
#   1,
#   0.0948,
#   0.00323,
#   0,
#   0.0788,
#   0.695,
#   109.997,
#   164952,
#   4],
#  [0.592,
#   0.767,
#   9,
#   -2.788,
#   0,
#   0.027,
#   0.0021,
#   0.00165,
#   0.127,
#   0.328,
#   96.483,
#   329733,
#   4],
#  [0.596,
#   0.605,
#   7,
#   -12.145,
#   1,
#   0.0255,
#   0.181,
#   0.000331,
#   0.0863,
#   0.886,
#   97.798,
#   283800,
#   4],
#  [0.783,
#   0.727,
#   6,
#   -3.454,
#   0,
#   0.389,
#   0.185,
#   2.46e-05,
#   0.0626,
#   0.558,
#   180.067,
#   199112,
#   4],
#  [0.586,
#   0.525,
#   1,
#   -7.163,
#   0,
#   0.0615,
#   0.111,
#   0,
#   0.134,
#   0.508,
#   133.629,
#   260253,
#   4],
#  [0.735,
#   0.478,
#   2,
#   -12.472,
#   1,
#   0.0293,
#   0.189,
#   2.48e-06,
#   0.355,
#   0.947,
#   107.682,
#   262960,
#   4],
#  [0.788,
#   0.859,
#   2,
#   -2.724,
#   1,
#   0.0856,
#   0.281,
#   0,
#   0.0424,
#   0.822,
#   141.02,
#   207853,
#   4],
#  [0.645,
#   0.585,
#   6,
#   -6.122,
#   1,
#   0.0513,
#   0.00314,
#   0,
#   0.165,
#   0.353,
#   131.931,
#   215672,
#   4],
#  [0.788,
#   0.859,
#   1,
#   -5.542,
#   1,
#   0.315,
#   0.127,
#   0,
#   0.348,
#   0.769,
#   140.027,
#   219333,
#   4],
#  [0.542,
#   0.905,
#   9,
#   -5.653,
#   1,
#   0.054,
#   0.00172,
#   0.0104,
#   0.136,
#   0.374,
#   153.398,
#   203347,
#   4],
#  [0.38,
#   0.339,
#   3,
#   -7.885,
#   1,
#   0.0338,
#   0.691,
#   0,
#   0.12,
#   0.0849,
#   100.607,
#   229227,
#   4],
#  [0.491,
#   0.693,
#   0,
#   -6.487,
#   0,
#   0.0377,
#   0.211,
#   6.92e-06,
#   0.325,
#   0.412,
#   90.027,
#   258267,
#   4],
#  [0.691,
#   0.631,
#   2,
#   -6.478,
#   1,
#   0.0368,
#   0.0483,
#   1.13e-05,
#   0.104,
#   0.8,
#   92.004,
#   161124,
#   4],
#  [0.592,
#   0.457,
#   9,
#   -6.081,
#   0,
#   0.0603,
#   0.661,
#   0.000331,
#   0.146,
#   0.225,
#   146.04,
#   110886,
#   4],
#  [0.78,
#   0.719,
#   3,
#   -3.613,
#   0,
#   0.0506,
#   0.302,
#   0.000196,
#   0.0931,
#   0.336,
#   127.962,
#   199604,
#   4],
#  [0.911,
#   0.712,
#   1,
#   -5.105,
#   0,
#   0.0817,
#   0.0901,
#   2.68e-05,
#   0.0933,
#   0.425,
#   92.005,
#   178567,
#   4],
#  [0.753,
#   0.678,
#   5,
#   -5.421,
#   1,
#   0.0644,
#   0.085,
#   1.64e-06,
#   0.13,
#   0.583,
#   96.006,
#   231827,
#   4],
#  [0.818,
#   0.705,
#   6,
#   -6.679,
#   1,
#   0.177,
#   0.00836,
#   0.00233,
#   0.613,
#   0.772,
#   138.559,
#   222640,
#   4],
#  [0.583,
#   0.829,
#   1,
#   -4.603,
#   1,
#   0.134,
#   0.00864,
#   0,
#   0.0426,
#   0.575,
#   174.028,
#   275987,
#   4],
#  [0.563,
#   0.592,
#   9,
#   -4.571,
#   1,
#   0.0276,
#   0.209,
#   5.08e-05,
#   0.132,
#   0.136,
#   104.016,
#   267933,
#   4],
#  [0.696,
#   0.817,
#   1,
#   -3.862,
#   1,
#   0.109,
#   0.075,
#   0,
#   0.187,
#   0.782,
#   98.064,
#   216409,
#   4],
#  [0.734,
#   0.874,
#   8,
#   -3.158,
#   1,
#   0.0662,
#   0.168,
#   1.14e-05,
#   0.0489,
#   0.905,
#   122.953,
#   166028,
#   4],
#  [0.279,
#   0.742,
#   4,
#   -6.46,
#   0,
#   0.0898,
#   0.000185,
#   0,
#   0.593,
#   0.328,
#   189.868,
#   231013,
#   4],
#  [0.509,
#   0.637,
#   4,
#   -4.83,
#   0,
#   0.0471,
#   0.0717,
#   1.08e-05,
#   0.0789,
#   0.378,
#   172.006,
#   224000,
#   3],
#  [0.902, 0.72, 6, -2.776, 0, 0.347, 0.26, 0, 0.0749, 0.805, 90.059, 193467, 4],
#  [0.432,
#   0.781,
#   4,
#   -4.038,
#   0,
#   0.0567,
#   0.041,
#   4.21e-06,
#   0.0789,
#   0.197,
#   139.432,
#   250286,
#   4],
#  [0.728,
#   0.783,
#   11,
#   -4.424,
#   0,
#   0.266,
#   0.237,
#   0,
#   0.434,
#   0.555,
#   77.011,
#   173381,
#   4],
#  [0.806,
#   0.546,
#   9,
#   -6.637,
#   1,
#   0.0575,
#   0.3,
#   0,
#   0.102,
#   0.874,
#   147.986,
#   212867,
#   4],
#  [0.381,
#   0.594,
#   3,
#   -5.97,
#   1,
#   0.0486,
#   0.348,
#   0,
#   0.0925,
#   0.273,
#   143.86,
#   290907,
#   4],
#  [0.566,
#   0.834,
#   6,
#   -8.412,
#   0,
#   0.0298,
#   0.00277,
#   0.008,
#   0.0625,
#   0.621,
#   123.296,
#   331560,
#   4],
#  [0.475,
#   0.37,
#   4,
#   -7.725,
#   0,
#   0.0361,
#   0.819,
#   0.0577,
#   0.0841,
#   0.157,
#   144.828,
#   200560,
#   4],
#  [0.767,
#   0.481,
#   0,
#   -8.52,
#   0,
#   0.0803,
#   0.234,
#   0,
#   0.269,
#   0.761,
#   150.076,
#   171375,
#   4],
#  [0.789,
#   0.72,
#   8,
#   -5.652,
#   0,
#   0.218,
#   0.223,
#   0,
#   0.129,
#   0.664,
#   122.031,
#   166794,
#   4],
#  [0.738,
#   0.776,
#   1,
#   -4.808,
#   1,
#   0.0392,
#   0.0234,
#   0.0018,
#   0.0775,
#   0.608,
#   127.984,
#   215520,
#   4],
#  [0.515,
#   0.479,
#   3,
#   -7.458,
#   1,
#   0.0261,
#   0.544,
#   0.00598,
#   0.191,
#   0.284,
#   88.964,
#   209274,
#   4],
#  [0.65,
#   0.825,
#   0,
#   -4.645,
#   1,
#   0.0325,
#   0.0215,
#   2.44e-05,
#   0.0936,
#   0.593,
#   118.091,
#   191014,
#   4],
#  [0.545,
#   0.675,
#   6,
#   -6.474,
#   1,
#   0.0279,
#   0.00617,
#   0.00197,
#   0.209,
#   0.162,
#   124.97,
#   267867,
#   4],
#  [0.746,
#   0.873,
#   7,
#   -3.803,
#   1,
#   0.128,
#   0.0244,
#   0,
#   0.354,
#   0.817,
#   148.075,
#   222093,
#   4],
#  [0.502,
#   0.786,
#   9,
#   -4.378,
#   0,
#   0.317,
#   0.255,
#   0,
#   0.65,
#   0.739,
#   169.021,
#   243491,
#   4],
#  [0.884,
#   0.347,
#   8,
#   -8.227,
#   0,
#   0.35,
#   0.015,
#   7e-06,
#   0.0871,
#   0.376,
#   75.016,
#   220307,
#   4],
#  [0.837,
#   0.364,
#   8,
#   -11.713,
#   1,
#   0.276,
#   0.149,
#   0,
#   0.271,
#   0.463,
#   123.984,
#   213594,
#   4],
#  [0.644,
#   0.57,
#   9,
#   -6.994,
#   1,
#   0.052,
#   0.484,
#   0,
#   0.299,
#   0.527,
#   113.945,
#   212424,
#   4],
#  [0.752,
#   0.764,
#   1,
#   -4.399,
#   1,
#   0.038,
#   0.0476,
#   9.44e-05,
#   0.0543,
#   0.582,
#   121.958,
#   163216,
#   4],
#  [0.664,
#   0.708,
#   8,
#   -4.154,
#   1,
#   0.0474,
#   0.0337,
#   0,
#   0.0841,
#   0.742,
#   103.07,
#   174800,
#   4],
#  [0.654,
#   0.798,
#   0,
#   -4.084,
#   1,
#   0.0451,
#   0.188,
#   0,
#   0.15,
#   0.574,
#   92.207,
#   211760,
#   4],
#  [0.675,
#   0.562,
#   7,
#   -7.678,
#   1,
#   0.0352,
#   0.233,
#   0,
#   0.0816,
#   0.309,
#   130.098,
#   256533,
#   4],
#  [0.674,
#   0.428,
#   7,
#   -9.504,
#   1,
#   0.122,
#   0.121,
#   0,
#   0.132,
#   0.337,
#   84.878,
#   190185,
#   4],
#  [0.889,
#   0.496,
#   4,
#   -6.365,
#   0,
#   0.0905,
#   0.259,
#   0,
#   0.252,
#   0.544,
#   86.003,
#   180522,
#   4],
#  [0.486,
#   0.652,
#   11,
#   -7.226,
#   0,
#   0.052,
#   0.408,
#   6.63e-05,
#   0.077,
#   0.391,
#   113.055,
#   273684,
#   4],
#  [0.893,
#   0.745,
#   11,
#   -3.105,
#   0,
#   0.0571,
#   0.0642,
#   0,
#   0.0943,
#   0.872,
#   101.018,
#   223413,
#   4],
#  [0.778,
#   0.547,
#   2,
#   -7.273,
#   1,
#   0.0489,
#   0.346,
#   0.000302,
#   0.132,
#   0.441,
#   95.002,
#   242733,
#   4],
#  [0.74,
#   0.622,
#   11,
#   -4.608,
#   0,
#   0.0446,
#   0.0357,
#   4.85e-05,
#   0.356,
#   0.556,
#   104.966,
#   222707,
#   4],
#  [0.727,
#   0.974,
#   4,
#   -2.261,
#   0,
#   0.0664,
#   0.103,
#   0.000532,
#   0.174,
#   0.965,
#   79.526,
#   235213,
#   4],
#  [0.73,
#   0.729,
#   4,
#   -3.434,
#   0,
#   0.0884,
#   0.167,
#   1.39e-06,
#   0.349,
#   0.467,
#   113.011,
#   221820,
#   4],
#  [0.721,
#   0.802,
#   1,
#   -5.797,
#   1,
#   0.0583,
#   0.0921,
#   0,
#   0.694,
#   0.724,
#   124.022,
#   229360,
#   4],
#  [0.798,
#   0.62,
#   8,
#   -7.079,
#   0,
#   0.232,
#   0.414,
#   0.0192,
#   0.112,
#   0.235,
#   120.031,
#   164000,
#   4],
#  [0.693,
#   0.497,
#   2,
#   -7.316,
#   1,
#   0.119,
#   0.679,
#   0,
#   0.258,
#   0.473,
#   81.308,
#   122067,
#   4],
#  [0.64,
#   0.743,
#   10,
#   -4.08,
#   1,
#   0.0379,
#   0.269,
#   0,
#   0.101,
#   0.361,
#   122.035,
#   262533,
#   4],
#  [0.793,
#   0.653,
#   7,
#   -7.839,
#   1,
#   0.103,
#   0.0484,
#   4.91e-05,
#   0.1,
#   0.393,
#   117.993,
#   263373,
#   4],
#  [0.71,
#   0.789,
#   4,
#   -3.874,
#   1,
#   0.0722,
#   0.0161,
#   2.77e-06,
#   0.451,
#   0.717,
#   142.929,
#   131064,
#   4],
#  [0.564,
#   0.737,
#   9,
#   -4.079,
#   1,
#   0.0414,
#   0.0175,
#   0,
#   0.054,
#   0.211,
#   104.764,
#   220573,
#   4],
#  [0.692,
#   0.711,
#   0,
#   -7.498,
#   0,
#   0.0317,
#   0.225,
#   0,
#   0.12,
#   0.875,
#   125.135,
#   216933,
#   4],
#  [0.722,
#   0.758,
#   11,
#   -4.477,
#   0,
#   0.0471,
#   0.0111,
#   0,
#   0.308,
#   0.62,
#   128.047,
#   201160,
#   4],
#  [0.582,
#   0.272,
#   2,
#   -5.662,
#   1,
#   0.0501,
#   0.875,
#   0,
#   0.13,
#   0.354,
#   205.846,
#   188238,
#   4],
#  [0.671,
#   0.672,
#   0,
#   -3.094,
#   0,
#   0.0688,
#   0.0329,
#   0,
#   0.118,
#   0.632,
#   97.979,
#   204173,
#   4],
#  [0.713,
#   0.802,
#   4,
#   -7.055,
#   1,
#   0.0561,
#   0.0435,
#   0.00377,
#   0.309,
#   0.343,
#   100.001,
#   226739,
#   4],
#  [0.786,
#   0.69,
#   3,
#   -4.665,
#   1,
#   0.04,
#   0.0865,
#   9.03e-05,
#   0.238,
#   0.485,
#   122.006,
#   195561,
#   4],
#  [0.645,
#   0.862,
#   11,
#   -4.757,
#   0,
#   0.0965,
#   0.0923,
#   0,
#   0.192,
#   0.798,
#   119.991,
#   229773,
#   4],
#  [0.675,
#   0.674,
#   1,
#   -4.984,
#   1,
#   0.0305,
#   0.0409,
#   0,
#   0.128,
#   0.569,
#   134.941,
#   201240,
#   4],
#  [0.488,
#   0.343,
#   4,
#   -8.985,
#   1,
#   0.0436,
#   0.556,
#   0,
#   0.21,
#   0.0978,
#   102.819,
#   206459,
#   4],
#  [0.743,
#   0.766,
#   0,
#   -6.375,
#   1,
#   0.0265,
#   0.0873,
#   0,
#   0.509,
#   0.61,
#   127.96,
#   289133,
#   4],
#  [0.869,
#   0.485,
#   6,
#   -5.595,
#   1,
#   0.0545,
#   0.246,
#   0,
#   0.0765,
#   0.527,
#   106.028,
#   204502,
#   4],
#  [0.704,
#   0.611,
#   2,
#   -6.112,
#   1,
#   0.0409,
#   0.217,
#   0,
#   0.0812,
#   0.22,
#   100.0,
#   189467,
#   4],
#  [0.738,
#   0.868,
#   11,
#   -4.373,
#   0,
#   0.0731,
#   0.0392,
#   0.00169,
#   0.388,
#   0.336,
#   122.003,
#   212640,
#   4],
#  [0.586,
#   0.616,
#   5,
#   -7.964,
#   1,
#   0.0324,
#   0.182,
#   0,
#   0.0927,
#   0.719,
#   148.088,
#   242096,
#   4],
#  [0.524, 0.364, 7, -10.209, 1, 0.0367, 0.808, 0, 0.1, 0.436, 75.24, 209831, 4],
#  [0.815,
#   0.438,
#   0,
#   -14.522,
#   0,
#   0.0346,
#   0.216,
#   0.000466,
#   0.0787,
#   0.552,
#   108.965,
#   243773,
#   4],
#  [0.393,
#   0.858,
#   4,
#   -2.868,
#   0,
#   0.0729,
#   0.00359,
#   0,
#   0.102,
#   0.56,
#   176.042,
#   228360,
#   4],
#  [0.781,
#   0.768,
#   11,
#   -5.991,
#   1,
#   0.0394,
#   0.0119,
#   4.91e-06,
#   0.325,
#   0.486,
#   123.07,
#   213309,
#   4],
#  [0.912,
#   0.412,
#   7,
#   -8.074,
#   1,
#   0.123,
#   0.0165,
#   0.0126,
#   0.104,
#   0.423,
#   154.983,
#   238614,
#   4],
#  [0.861,
#   0.603,
#   8,
#   -5.788,
#   0,
#   0.176,
#   0.0521,
#   0,
#   0.0924,
#   0.504,
#   98.043,
#   228760,
#   4],
#  [0.905,
#   0.389,
#   8,
#   -14.505,
#   1,
#   0.332,
#   0.74,
#   0.162,
#   0.106,
#   0.196,
#   120.046,
#   193143,
#   4],
#  [0.8,
#   0.585,
#   10,
#   -7.343,
#   1,
#   0.0924,
#   0.264,
#   0,
#   0.153,
#   0.779,
#   126.058,
#   213400,
#   4],
#  [0.783,
#   0.584,
#   7,
#   -6.572,
#   1,
#   0.0409,
#   0.0109,
#   2.91e-06,
#   0.108,
#   0.632,
#   120.031,
#   193467,
#   4],
#  [0.823, 0.586, 6, -6.606, 0, 0.2, 0.114, 0, 0.193, 0.347, 125.971, 190476, 4],
#  [0.407,
#   0.147,
#   2,
#   -8.822,
#   1,
#   0.0355,
#   0.857,
#   2.89e-06,
#   0.0913,
#   0.0765,
#   141.284,
#   229400,
#   3],
#  [0.638,
#   0.523,
#   1,
#   -6.664,
#   1,
#   0.357,
#   0.00454,
#   0,
#   0.0842,
#   0.422,
#   139.913,
#   185947,
#   4],
#  [0.739,
#   0.833,
#   1,
#   -5.012,
#   1,
#   0.0463,
#   0.35,
#   0,
#   0.266,
#   0.699,
#   117.99,
#   195313,
#   4],
#  [0.775,
#   0.68,
#   0,
#   -5.508,
#   0,
#   0.0629,
#   0.00906,
#   0,
#   0.109,
#   0.656,
#   114.025,
#   207719,
#   4],
#  [0.666,
#   0.855,
#   9,
#   -5.051,
#   0,
#   0.0295,
#   0.179,
#   1.2e-06,
#   0.0987,
#   0.803,
#   125.639,
#   268427,
#   4],
#  [0.688,
#   0.702,
#   7,
#   -4.792,
#   0,
#   0.0499,
#   0.0215,
#   0,
#   0.128,
#   0.74,
#   94.006,
#   192191,
#   4],
#  [0.669,
#   0.574,
#   4,
#   -6.442,
#   0,
#   0.0286,
#   0.0175,
#   0.00294,
#   0.146,
#   0.273,
#   120.013,
#   196400,
#   4],
#  [0.765,
#   0.688,
#   4,
#   -5.566,
#   1,
#   0.0841,
#   0.633,
#   0,
#   0.0734,
#   0.434,
#   90.013,
#   229573,
#   4],
#  [0.922,
#   0.581,
#   10,
#   -7.495,
#   1,
#   0.27,
#   0.00104,
#   5.86e-05,
#   0.105,
#   0.595,
#   140.022,
#   181263,
#   4],
#  [0.781,
#   0.526,
#   6,
#   -6.985,
#   0,
#   0.293,
#   0.0619,
#   0,
#   0.0457,
#   0.662,
#   94.992,
#   235613,
#   4],
#  [0.445,
#   0.955,
#   8,
#   -8.027,
#   1,
#   0.0856,
#   0.0326,
#   0.284,
#   0.317,
#   0.336,
#   123.343,
#   273600,
#   4],
#  [0.924,
#   0.543,
#   9,
#   -7.474,
#   0,
#   0.298,
#   0.182,
#   0,
#   0.103,
#   0.736,
#   133.907,
#   207813,
#   4],
#  [0.679,
#   0.662,
#   8,
#   -6.069,
#   0,
#   0.174,
#   0.155,
#   0,
#   0.152,
#   0.438,
#   99.879,
#   222801,
#   4],
#  [0.67,
#   0.838,
#   0,
#   -4.031,
#   1,
#   0.0362,
#   0.0604,
#   0.000611,
#   0.159,
#   0.717,
#   104.998,
#   222041,
#   4],
#  [0.641,
#   0.176,
#   6,
#   -11.692,
#   1,
#   0.0349,
#   0.638,
#   5.14e-06,
#   0.252,
#   0.297,
#   76.031,
#   299147,
#   4],
#  [0.763,
#   0.875,
#   9,
#   -5.797,
#   0,
#   0.0262,
#   0.024,
#   5.41e-06,
#   0.599,
#   0.8,
#   123.013,
#   189413,
#   4],
#  [0.671,
#   0.916,
#   6,
#   -4.014,
#   0,
#   0.0397,
#   0.0282,
#   0.00762,
#   0.24,
#   0.803,
#   126.01,
#   189127,
#   4],
#  [0.829,
#   0.51,
#   5,
#   -9.334,
#   0,
#   0.0369,
#   0.00821,
#   0.0014,
#   0.0829,
#   0.45,
#   119.993,
#   208133,
#   4],
#  [0.628, 0.69, 8, -5.83, 1, 0.0511, 0.443, 0, 0.113, 0.66, 179.908, 205907, 4],
#  [0.794,
#   0.632,
#   0,
#   -6.163,
#   1,
#   0.0649,
#   0.142,
#   0,
#   0.128,
#   0.355,
#   145.926,
#   291893,
#   4],
#  [0.509,
#   0.671,
#   1,
#   -5.709,
#   1,
#   0.0678,
#   0.304,
#   0,
#   0.0452,
#   0.55,
#   118.413,
#   227480,
#   5],
#  [0.777,
#   0.564,
#   2,
#   -6.967,
#   0,
#   0.0315,
#   0.683,
#   0.000252,
#   0.0696,
#   0.465,
#   117.973,
#   186147,
#   4],
#  [0.647,
#   0.785,
#   7,
#   -5.414,
#   1,
#   0.165,
#   0.0561,
#   0,
#   0.148,
#   0.943,
#   160.015,
#   219200,
#   4],
#  [0.687,
#   0.702,
#   7,
#   -5.324,
#   0,
#   0.0455,
#   0.0064,
#   4.35e-05,
#   0.204,
#   0.284,
#   129.956,
#   214840,
#   4],
#  [0.884,
#   0.765,
#   8,
#   -3.865,
#   1,
#   0.0882,
#   0.063,
#   7.04e-06,
#   0.118,
#   0.594,
#   99.987,
#   224573,
#   4],
#  [0.477,
#   0.682,
#   1,
#   -4.931,
#   0,
#   0.0925,
#   0.153,
#   0,
#   0.0763,
#   0.345,
#   110.567,
#   202205,
#   5],
#  [0.654,
#   0.63,
#   10,
#   -4.644,
#   1,
#   0.0259,
#   0.153,
#   0,
#   0.111,
#   0.43,
#   89.991,
#   167693,
#   4],
#  [0.498,
#   0.59,
#   1,
#   -4.721,
#   0,
#   0.032,
#   0.511,
#   0,
#   0.107,
#   0.0784,
#   145.867,
#   217867,
#   4],
#  [0.332,
#   0.225,
#   0,
#   -8.697,
#   1,
#   0.0348,
#   0.767,
#   0.00349,
#   0.128,
#   0.297,
#   81.055,
#   298899,
#   3],
#  [0.723,
#   0.711,
#   0,
#   -5.576,
#   0,
#   0.0378,
#   0.0997,
#   0,
#   0.0528,
#   0.606,
#   138.098,
#   192107,
#   4],
#  [0.861,
#   0.504,
#   7,
#   -7.707,
#   1,
#   0.0489,
#   0.00412,
#   1.78e-05,
#   0.0783,
#   0.881,
#   120.0,
#   263053,
#   4],
#  [0.638,
#   0.924,
#   7,
#   -3.887,
#   1,
#   0.036,
#   0.00205,
#   0.000175,
#   0.149,
#   0.53,
#   111.995,
#   263787,
#   4],
#  [0.671,
#   0.771,
#   7,
#   -4.821,
#   0,
#   0.0316,
#   0.00492,
#   7.28e-06,
#   0.354,
#   0.436,
#   90.003,
#   223546,
#   4],
#  [0.911,
#   0.709,
#   10,
#   -4.139,
#   0,
#   0.0673,
#   0.105,
#   0,
#   0.0491,
#   0.365,
#   94.979,
#   199938,
#   4],
#  [0.545,
#   0.78,
#   7,
#   -4.867,
#   0,
#   0.0436,
#   0.0309,
#   4.64e-05,
#   0.0828,
#   0.458,
#   125.014,
#   255093,
#   4],
#  [0.776,
#   0.413,
#   6,
#   -7.438,
#   0,
#   0.0952,
#   0.00415,
#   2.68e-05,
#   0.0724,
#   0.287,
#   100.003,
#   227880,
#   4],
#  [0.706,
#   0.247,
#   5,
#   -17.961,
#   1,
#   0.0311,
#   0.261,
#   0,
#   0.103,
#   0.424,
#   127.812,
#   202120,
#   4],
#  [0.685,
#   0.466,
#   0,
#   -9.074,
#   1,
#   0.0304,
#   0.794,
#   2.06e-06,
#   0.0915,
#   0.353,
#   79.936,
#   163133,
#   4],
#  [0.65,
#   0.825,
#   0,
#   -4.645,
#   1,
#   0.0325,
#   0.0215,
#   2.44e-05,
#   0.0936,
#   0.593,
#   118.091,
#   191014,
#   4],
#  [0.618,
#   0.717,
#   7,
#   -5.738,
#   1,
#   0.318,
#   0.00256,
#   0,
#   0.625,
#   0.603,
#   190.05,
#   196693,
#   4],
#  [0.506,
#   0.805,
#   1,
#   -4.119,
#   1,
#   0.0469,
#   0.00711,
#   0.00193,
#   0.0856,
#   0.383,
#   126.008,
#   227074,
#   4],
#  [0.69,
#   0.524,
#   6,
#   -8.39,
#   0,
#   0.103,
#   0.0415,
#   3.16e-06,
#   0.17,
#   0.562,
#   164.023,
#   223080,
#   4],
#  [0.344,
#   0.509,
#   5,
#   -6.607,
#   0,
#   0.0722,
#   0.24,
#   0,
#   0.083,
#   0.529,
#   76.004,
#   485360,
#   4],
# ...
#   0,
#   0.612,
#   0.684,
#   148.726,
#   167067,
#   4],
#  [0.356,
#   0.917,
#   9,
#   -6.006,
#   1,
#   0.0479,
#   0.0335,
#   0,
#   0.406,
#   0.518,
#   171.176,
#   357267,
#   4],
#  [0.497,
#   0.693,
#   8,
#   -7.024,
#   1,
#   0.0565,
#   0.19,
#   0,
#   0.215,
#   0.358,
#   111.539,
#   296493,
#   3],
#  [0.39,
#   0.649,
#   2,
#   -5.163,
#   1,
#   0.0345,
#   0.172,
#   0,
#   0.216,
#   0.144,
#   121.16,
#   299760,
#   4],
#  [0.61,
#   0.83,
#   0,
#   -4.105,
#   1,
#   0.0571,
#   0.033,
#   0,
#   0.118,
#   0.728,
#   182.162,
#   193000,
#   4],
#  [0.61,
#   0.683,
#   2,
#   -3.879,
#   0,
#   0.0253,
#   0.00382,
#   1.79e-06,
#   0.125,
#   0.466,
#   108.003,
#   241693,
#   4],
#  [0.601,
#   0.532,
#   10,
#   -9.119,
#   1,
#   0.0286,
#   0.432,
#   6.25e-06,
#   0.0925,
#   0.341,
#   136.571,
#   281613,
#   4],
#  [0.736,
#   0.458,
#   5,
#   -7.437,
#   1,
#   0.0316,
#   0.441,
#   0,
#   0.148,
#   0.65,
#   98.977,
#   162547,
#   4],
#  [0.317,
#   0.172,
#   10,
#   -10.636,
#   1,
#   0.0326,
#   0.907,
#   0.000383,
#   0.105,
#   0.0963,
#   65.18,
#   212040,
#   3],
#  [0.597,
#   0.45,
#   8,
#   -6.658,
#   1,
#   0.0418,
#   0.223,
#   0,
#   0.382,
#   0.537,
#   178.765,
#   228482,
#   3],
#  [0.771,
#   0.671,
#   2,
#   -5.617,
#   1,
#   0.0553,
#   0.00929,
#   0,
#   0.0637,
#   0.714,
#   85.026,
#   171360,
#   4],
#  [0.458,
#   0.795,
#   0,
#   -3.265,
#   1,
#   0.0574,
#   0.00316,
#   0.000202,
#   0.0756,
#   0.513,
#   123.229,
#   255373,
#   4],
#  [0.545,
#   0.67,
#   9,
#   -8.81,
#   1,
#   0.0496,
#   0.009,
#   0.000822,
#   0.0451,
#   0.481,
#   151.553,
#   270213,
#   4],
#  [0.586,
#   0.941,
#   5,
#   -5.139,
#   1,
#   0.0375,
#   0.0167,
#   0.000776,
#   0.068,
#   0.831,
#   135.448,
#   223613,
#   4],
#  [0.388,
#   0.338,
#   10,
#   -10.054,
#   1,
#   0.0329,
#   0.652,
#   3.73e-06,
#   0.248,
#   0.478,
#   177.765,
#   303373,
#   4],
#  [0.862,
#   0.631,
#   7,
#   -4.746,
#   1,
#   0.0515,
#   0.291,
#   0.000209,
#   0.123,
#   0.841,
#   128.978,
#   223488,
#   4],
#  [0.656,
#   0.291,
#   2,
#   -10.572,
#   1,
#   0.0293,
#   0.872,
#   0,
#   0.114,
#   0.298,
#   103.971,
#   232533,
#   4],
#  [0.672,
#   0.855,
#   9,
#   -3.764,
#   1,
#   0.0397,
#   0.021,
#   0,
#   0.323,
#   0.646,
#   123.056,
#   182200,
#   4],
#  [0.696,
#   0.921,
#   0,
#   -3.755,
#   1,
#   0.0363,
#   0.00314,
#   5.24e-05,
#   0.0842,
#   0.714,
#   119.001,
#   294573,
#   4],
#  [0.851,
#   0.806,
#   4,
#   -4.62,
#   1,
#   0.0787,
#   0.118,
#   1.64e-06,
#   0.121,
#   0.787,
#   118.999,
#   237200,
#   4],
#  [0.608,
#   0.86,
#   5,
#   -5.324,
#   0,
#   0.0554,
#   0.0991,
#   0,
#   0.262,
#   0.437,
#   127.075,
#   232947,
#   4],
#  [0.545,
#   0.865,
#   11,
#   -5.708,
#   0,
#   0.0286,
#   0.00664,
#   1.1e-05,
#   0.168,
#   0.543,
#   99.009,
#   233933,
#   4],
#  [0.785,
#   0.525,
#   6,
#   -7.556,
#   1,
#   0.042,
#   0.669,
#   0.439,
#   0.114,
#   0.251,
#   90.853,
#   238907,
#   4],
#  [0.498,
#   0.235,
#   1,
#   -16.541,
#   0,
#   0.188,
#   0.72,
#   0,
#   0.144,
#   0.0895,
#   118.917,
#   179080,
#   4],
#  [0.58,
#   0.695,
#   6,
#   -8.244,
#   0,
#   0.0671,
#   0.00638,
#   0,
#   0.174,
#   0.402,
#   168.124,
#   232147,
#   4],
#  [0.694,
#   0.758,
#   11,
#   -2.986,
#   1,
#   0.218,
#   0.278,
#   1.34e-06,
#   0.102,
#   0.371,
#   192.091,
#   185195,
#   4],
#  [0.598,
#   0.526,
#   10,
#   -8.659,
#   0,
#   0.0415,
#   0.129,
#   0,
#   0.14,
#   0.529,
#   123.935,
#   168387,
#   4],
#  [0.647,
#   0.844,
#   0,
#   -3.756,
#   1,
#   0.0457,
#   0.0137,
#   0.000658,
#   0.102,
#   0.746,
#   146.967,
#   193829,
#   4],
#  [0.67, 0.693, 6, -8.34, 1, 0.35, 0.2, 0, 0.0909, 0.388, 87.017, 212093, 4],
#  [0.732,
#   0.716,
#   10,
#   -6.968,
#   0,
#   0.0561,
#   0.0295,
#   0.000758,
#   0.73,
#   0.666,
#   105.093,
#   214855,
#   4],
#  [0.834, 0.696, 5, -3.224, 1, 0.197, 0.11, 0, 0.13, 0.804, 94.09, 272533, 4],
#  [0.736,
#   0.308,
#   4,
#   -7.83,
#   1,
#   0.0677,
#   0.946,
#   0,
#   0.186,
#   0.361,
#   111.202,
#   220492,
#   4],
#  [0.638,
#   0.656,
#   5,
#   -5.886,
#   1,
#   0.0357,
#   0.188,
#   0,
#   0.146,
#   0.225,
#   104.036,
#   262467,
#   4],
#  [0.621,
#   0.31,
#   9,
#   -10.164,
#   0,
#   0.0283,
#   0.945,
#   6.12e-05,
#   0.117,
#   0.125,
#   111.893,
#   240707,
#   4],
#  [0.564,
#   0.71,
#   11,
#   -4.92,
#   0,
#   0.0461,
#   0.00125,
#   0,
#   0.109,
#   0.393,
#   91.972,
#   225147,
#   4],
#  [0.704,
#   0.558,
#   2,
#   -7.273,
#   0,
#   0.0542,
#   0.148,
#   0,
#   0.107,
#   0.245,
#   110.444,
#   222091,
#   4],
#  [0.807,
#   0.887,
#   9,
#   -3.726,
#   1,
#   0.0503,
#   0.0573,
#   2.87e-06,
#   0.124,
#   0.961,
#   134.052,
#   187920,
#   4],
#  [0.609,
#   0.444,
#   7,
#   -9.129,
#   1,
#   0.106,
#   0.603,
#   6.86e-06,
#   0.104,
#   0.166,
#   118.402,
#   228707,
#   3],
#  [0.644,
#   0.549,
#   1,
#   -5.415,
#   0,
#   0.0285,
#   0.0209,
#   8.85e-06,
#   0.134,
#   0.167,
#   90.04,
#   253813,
#   4],
#  [0.464,
#   0.473,
#   1,
#   -10.086,
#   1,
#   0.129,
#   0.866,
#   0,
#   0.109,
#   0.604,
#   75.801,
#   208687,
#   4],
#  [0.726,
#   0.787,
#   4,
#   -2.494,
#   1,
#   0.0737,
#   0.009,
#   0,
#   0.0596,
#   0.888,
#   124.99,
#   199987,
#   4],
#  [0.675,
#   0.479,
#   0,
#   -9.87,
#   0,
#   0.0278,
#   0.633,
#   1.76e-05,
#   0.088,
#   0.454,
#   81.998,
#   209493,
#   4],
#  [0.868,
#   0.347,
#   5,
#   -9.529,
#   1,
#   0.0536,
#   0.308,
#   2e-05,
#   0.11,
#   0.659,
#   110.059,
#   207680,
#   4],
#  [0.815,
#   0.518,
#   7,
#   -6.594,
#   0,
#   0.0897,
#   0.223,
#   0,
#   0.104,
#   0.877,
#   151.891,
#   177667,
#   4],
#  [0.707,
#   0.955,
#   10,
#   -4.593,
#   0,
#   0.222,
#   0.127,
#   0,
#   0.202,
#   0.575,
#   125.989,
#   134240,
#   4],
#  [0.611,
#   0.797,
#   6,
#   -7.627,
#   0,
#   0.0533,
#   0.00543,
#   0.00137,
#   0.26,
#   0.518,
#   120.041,
#   218107,
#   4],
#  [0.693,
#   0.678,
#   8,
#   -7.159,
#   1,
#   0.0324,
#   0.0151,
#   5.71e-06,
#   0.101,
#   0.404,
#   103.952,
#   228267,
#   4],
#  [0.512,
#   0.662,
#   3,
#   -6.797,
#   1,
#   0.0439,
#   0.0275,
#   0,
#   0.118,
#   0.472,
#   180.114,
#   228347,
#   4],
#  [0.625,
#   0.814,
#   0,
#   -5.181,
#   1,
#   0.0657,
#   0.0172,
#   0,
#   0.158,
#   0.535,
#   144.991,
#   205485,
#   4],
#  [0.709,
#   0.548,
#   10,
#   -8.493,
#   1,
#   0.353,
#   0.65,
#   1.59e-06,
#   0.133,
#   0.543,
#   83.995,
#   160000,
#   4],
#  [0.747,
#   0.833,
#   3,
#   -2.867,
#   0,
#   0.045,
#   0.374,
#   0,
#   0.0586,
#   0.687,
#   128.008,
#   215760,
#   4],
#  [0.684,
#   0.619,
#   10,
#   -7.005,
#   1,
#   0.0386,
#   0.0716,
#   0,
#   0.122,
#   0.284,
#   125.046,
#   217440,
#   4],
#  [0.567,
#   0.267,
#   4,
#   -6.502,
#   1,
#   0.0299,
#   0.839,
#   1.46e-06,
#   0.089,
#   0.0592,
#   110.011,
#   240133,
#   4],
#  [0.548,
#   0.805,
#   7,
#   -5.732,
#   1,
#   0.351,
#   0.212,
#   0.000389,
#   0.408,
#   0.648,
#   142.094,
#   216387,
#   4],
#  [0.923,
#   0.604,
#   11,
#   -6.671,
#   0,
#   0.245,
#   0.017,
#   0,
#   0.272,
#   0.826,
#   145.062,
#   139741,
#   4],
#  [0.857,
#   0.621,
#   9,
#   -6.376,
#   0,
#   0.0825,
#   0.148,
#   0,
#   0.0865,
#   0.668,
#   97.989,
#   204467,
#   4],
#  [0.674,
#   0.774,
#   11,
#   -7.567,
#   0,
#   0.0892,
#   0.0686,
#   0.00188,
#   0.393,
#   0.33,
#   112.05,
#   176547,
#   4],
#  [0.442,
#   0.943,
#   3,
#   -3.205,
#   1,
#   0.0602,
#   0.00293,
#   8.71e-06,
#   0.091,
#   0.781,
#   85.064,
#   181533,
#   4],
#  [0.54,
#   0.429,
#   2,
#   -11.822,
#   1,
#   0.0285,
#   0.000202,
#   0.355,
#   0.141,
#   0.113,
#   110.171,
#   295516,
#   4],
#  [0.658,
#   0.294,
#   4,
#   -8.533,
#   0,
#   0.0321,
#   0.422,
#   5.2e-05,
#   0.0749,
#   0.358,
#   74.038,
#   278180,
#   4],
#  [0.713,
#   0.678,
#   5,
#   -3.525,
#   0,
#   0.102,
#   0.273,
#   0,
#   0.149,
#   0.734,
#   138.009,
#   271333,
#   4],
#  [0.662,
#   0.413,
#   0,
#   -7.357,
#   1,
#   0.0299,
#   0.213,
#   0,
#   0.134,
#   0.467,
#   93.005,
#   161385,
#   4],
#  [0.491,
#   0.583,
#   7,
#   -10.964,
#   1,
#   0.0376,
#   0.185,
#   0,
#   0.406,
#   0.908,
#   150.566,
#   183307,
#   4],
#  [0.662,
#   0.858,
#   2,
#   -4.844,
#   1,
#   0.0428,
#   0.00163,
#   0,
#   0.0456,
#   0.295,
#   133.993,
#   181673,
#   4],
#  [0.751,
#   0.783,
#   4,
#   -3.724,
#   1,
#   0.0859,
#   0.00379,
#   0,
#   0.036,
#   0.816,
#   119.975,
#   202613,
#   4],
#  [0.671,
#   0.939,
#   8,
#   -3.206,
#   1,
#   0.161,
#   0.191,
#   0,
#   0.298,
#   0.53,
#   129.024,
#   252307,
#   4],
#  [0.646,
#   0.795,
#   9,
#   -3.293,
#   1,
#   0.0976,
#   0.0319,
#   0,
#   0.267,
#   0.796,
#   89.99,
#   210960,
#   4],
#  [0.588,
#   0.521,
#   10,
#   -9.461,
#   1,
#   0.0329,
#   0.0678,
#   0.149,
#   0.123,
#   0.337,
#   85.012,
#   260173,
#   4],
#  [0.672,
#   0.52,
#   8,
#   -7.747,
#   1,
#   0.0353,
#   0.859,
#   0,
#   0.115,
#   0.37,
#   120.001,
#   226600,
#   4],
#  [0.696,
#   0.454,
#   1,
#   -6.756,
#   0,
#   0.153,
#   0.123,
#   0,
#   0.155,
#   0.136,
#   92.928,
#   260640,
#   4],
#  [0.824,
#   0.862,
#   2,
#   -3.424,
#   1,
#   0.126,
#   0.0076,
#   0.000132,
#   0.303,
#   0.801,
#   122.98,
#   169153,
#   4],
#  [0.554,
#   0.498,
#   9,
#   -8.866,
#   1,
#   0.0685,
#   0.23,
#   5.98e-06,
#   0.795,
#   0.413,
#   79.635,
#   190067,
#   4],
#  [0.646,
#   0.77,
#   2,
#   -6.596,
#   0,
#   0.226,
#   0.00249,
#   0,
#   0.0715,
#   0.681,
#   99.165,
#   236133,
#   4],
#  [0.294,
#   0.641,
#   11,
#   -9.316,
#   1,
#   0.0291,
#   0.0163,
#   0.22,
#   0.112,
#   0.226,
#   79.759,
#   536067,
#   4],
#  [0.268,
#   0.98,
#   11,
#   -5.958,
#   1,
#   0.103,
#   0.0192,
#   0.00709,
#   0.182,
#   0.395,
#   100.315,
#   405600,
#   4],
#  [0.6,
#   0.688,
#   5,
#   -8.339,
#   0,
#   0.201,
#   0.159,
#   1.29e-05,
#   0.409,
#   0.0793,
#   99.977,
#   156600,
#   4],
#  [0.276,
#   0.715,
#   0,
#   -5.356,
#   1,
#   0.0432,
#   0.00552,
#   0.000417,
#   0.201,
#   0.173,
#   137.028,
#   230760,
#   4],
#  [0.73,
#   0.868,
#   5,
#   -7.325,
#   1,
#   0.0288,
#   0.0632,
#   0.0661,
#   0.318,
#   0.923,
#   148.217,
#   350400,
#   4],
#  [0.547,
#   0.394,
#   4,
#   -9.793,
#   0,
#   0.0262,
#   0.0522,
#   6.4e-06,
#   0.0795,
#   0.17,
#   142.37,
#   388733,
#   3],
#  [0.855,
#   0.954,
#   0,
#   -1.19,
#   0,
#   0.264,
#   0.529,
#   0,
#   0.205,
#   0.668,
#   114.635,
#   248133,
#   5],
#  [0.449,
#   0.465,
#   0,
#   -8.964,
#   1,
#   0.0791,
#   0.524,
#   1.02e-06,
#   0.303,
#   0.543,
#   89.087,
#   198371,
#   3],
#  [0.918,
#   0.609,
#   10,
#   -5.64,
#   0,
#   0.0791,
#   0.0928,
#   0,
#   0.139,
#   0.304,
#   128.008,
#   231400,
#   4],
#  [0.543,
#   0.87,
#   9,
#   -6.514,
#   1,
#   0.0428,
#   0.358,
#   0.000939,
#   0.792,
#   0.754,
#   100.804,
#   230400,
#   4],
#  [0.75,
#   0.608,
#   1,
#   -4.008,
#   1,
#   0.0387,
#   0.00165,
#   0,
#   0.178,
#   0.958,
#   132.507,
#   173347,
#   4],
#  [0.967,
#   0.583,
#   7,
#   -5.562,
#   0,
#   0.0789,
#   0.0584,
#   0,
#   0.0519,
#   0.964,
#   117.0,
#   242733,
#   4],
#  [0.73,
#   0.487,
#   4,
#   -10.991,
#   1,
#   0.0303,
#   0.258,
#   0.01,
#   0.0852,
#   0.731,
#   114.965,
#   226653,
#   4],
#  [0.307,
#   0.433,
#   1,
#   -10.057,
#   1,
#   0.029,
#   0.388,
#   9.08e-05,
#   0.332,
#   0.224,
#   160.9,
#   266960,
#   4],
#  [0.446,
#   0.764,
#   10,
#   -5.042,
#   1,
#   0.033,
#   0.00135,
#   0,
#   0.099,
#   0.543,
#   172.094,
#   223840,
#   4],
#  [0.453,
#   0.35,
#   9,
#   -11.639,
#   0,
#   0.0425,
#   0.827,
#   0.00122,
#   0.144,
#   0.279,
#   72.017,
#   185147,
#   3],
#  [0.871,
#   0.701,
#   5,
#   -5.594,
#   0,
#   0.0458,
#   0.257,
#   7.52e-06,
#   0.0589,
#   0.716,
#   126.975,
#   198440,
#   4],
#  [0.66, 0.867, 6, -4.285, 0, 0.116, 0.11, 0, 0.0368, 0.377, 93.033, 180480, 4],
#  [0.711,
#   0.292,
#   4,
#   -15.523,
#   0,
#   0.037,
#   0.313,
#   0,
#   0.131,
#   0.194,
#   103.951,
#   296800,
#   4],
#  [0.664,
#   0.609,
#   1,
#   -6.509,
#   1,
#   0.0707,
#   0.304,
#   0,
#   0.0926,
#   0.194,
#   130.041,
#   210560,
#   4],
#  [0.749,
#   0.463,
#   11,
#   -8.433,
#   1,
#   0.0842,
#   0.21,
#   0.0382,
#   0.338,
#   0.189,
#   90.035,
#   226987,
#   4],
#  [0.673,
#   0.902,
#   2,
#   -2.392,
#   1,
#   0.0346,
#   0.0591,
#   0.000262,
#   0.0558,
#   0.538,
#   100.012,
#   194240,
#   4],
#  [0.66,
#   0.816,
#   2,
#   -6.61,
#   1,
#   0.0299,
#   0.168,
#   0.0181,
#   0.0608,
#   0.678,
#   111.346,
#   263040,
#   4],
#  [0.643,
#   0.849,
#   2,
#   -5.428,
#   1,
#   0.0526,
#   0.0371,
#   0,
#   0.058,
#   0.903,
#   162.152,
#   165853,
#   4],
#  [0.52,
#   0.852,
#   0,
#   -5.866,
#   1,
#   0.0543,
#   0.00237,
#   5.79e-05,
#   0.0733,
#   0.234,
#   140.267,
#   253587,
#   4],
#  [0.585,
#   0.776,
#   5,
#   -5.898,
#   1,
#   0.0459,
#   0.0572,
#   7.74e-06,
#   0.3,
#   0.427,
#   77.987,
#   244507,
#   4],
#  [0.377,
#   0.681,
#   7,
#   -8.039,
#   1,
#   0.0298,
#   0.00088,
#   0.0023,
#   0.0504,
#   0.285,
#   108.789,
#   285133,
#   4],
#  [0.78,
#   0.768,
#   6,
#   -4.325,
#   0,
#   0.238,
#   0.0371,
#   2.34e-06,
#   0.518,
#   0.507,
#   80.063,
#   404107,
#   4],
#  [0.495,
#   0.722,
#   6,
#   -8.108,
#   0,
#   0.357,
#   0.0697,
#   0,
#   0.113,
#   0.539,
#   175.627,
#   239267,
#   4],
#  [0.746,
#   0.251,
#   11,
#   -16.169,
#   0,
#   0.259,
#   0.782,
#   0.00203,
#   0.106,
#   0.18,
#   139.999,
#   120027,
#   4],
#  [0.699,
#   0.304,
#   1,
#   -11.192,
#   1,
#   0.0993,
#   0.779,
#   0.000993,
#   0.137,
#   0.271,
#   119.705,
#   160184,
#   4],
#  [0.695,
#   0.54,
#   4,
#   -5.688,
#   1,
#   0.0491,
#   0.299,
#   0,
#   0.369,
#   0.415,
#   121.947,
#   168552,
#   4],
#  [0.494,
#   0.842,
#   7,
#   -4.784,
#   1,
#   0.0843,
#   0.00579,
#   0,
#   0.122,
#   0.574,
#   162.011,
#   229093,
#   4],
#  [0.79,
#   0.647,
#   10,
#   -5.983,
#   0,
#   0.136,
#   0.0515,
#   0,
#   0.248,
#   0.654,
#   87.999,
#   211000,
#   4],
#  [0.359,
#   0.543,
#   7,
#   -7.582,
#   1,
#   0.0919,
#   0.492,
#   1.58e-05,
#   0.118,
#   0.453,
#   68.534,
#   221307,
#   4],
#  [0.902,
#   0.582,
#   5,
#   -5.902,
#   0,
#   0.109,
#   0.111,
#   3.18e-06,
#   0.111,
#   0.332,
#   107.005,
#   173948,
#   4],
#  [0.723,
#   0.86,
#   11,
#   -4.357,
#   1,
#   0.203,
#   0.271,
#   4.56e-06,
#   0.598,
#   0.667,
#   126.979,
#   200013,
#   4],
#  [0.721,
#   0.939,
#   8,
#   -11.823,
#   1,
#   0.0376,
#   0.115,
#   3.79e-05,
#   0.108,
#   0.914,
#   113.309,
#   213573,
#   4],
#  [0.768,
#   0.852,
#   4,
#   -6.215,
#   1,
#   0.038,
#   0.214,
#   7.36e-05,
#   0.0723,
#   0.867,
#   128.373,
#   271240,
#   4],
#  [0.574,
#   0.628,
#   2,
#   -8.815,
#   0,
#   0.036,
#   0.13,
#   0,
#   0.271,
#   0.803,
#   153.119,
#   300107,
#   4],
#  [0.689,
#   0.808,
#   0,
#   -3.28,
#   1,
#   0.0572,
#   0.0721,
#   0,
#   0.241,
#   0.674,
#   91.012,
#   207680,
#   4],
#  [0.573,
#   0.711,
#   1,
#   -6.268,
#   0,
#   0.0406,
#   0.0114,
#   0,
#   0.328,
#   0.47,
#   105.006,
#   226198,
#   4],
#  [0.652,
#   0.812,
#   3,
#   -3.797,
#   0,
#   0.0409,
#   0.00125,
#   3.01e-05,
#   0.667,
#   0.72,
#   126.023,
#   230733,
#   4],
#  [0.737,
#   0.846,
#   1,
#   -4.51,
#   0,
#   0.22,
#   0.00614,
#   0,
#   0.0486,
#   0.546,
#   87.981,
#   143901,
#   4],
#  [0.532,
#   0.767,
#   7,
#   -5.509,
#   1,
#   0.0574,
#   0.00287,
#   0.000513,
#   0.39,
#   0.755,
#   127.361,
#   210173,
#   4],
#  [0.653,
#   0.524,
#   11,
#   -9.016,
#   0,
#   0.0502,
#   0.112,
#   0,
#   0.203,
#   0.553,
#   83.97,
#   160191,
#   4],
#  [0.812,
#   0.761,
#   11,
#   -5.222,
#   1,
#   0.0812,
#   0.0465,
#   0.000135,
#   0.0601,
#   0.344,
#   130.032,
#   182956,
#   4],
#  [0.688,
#   0.835,
#   8,
#   -4.162,
#   1,
#   0.0911,
#   0.0583,
#   2.87e-06,
#   0.0795,
#   0.88,
#   84.858,
#   230493,
#   4],
#  [0.704,
#   0.797,
#   0,
#   -5.927,
#   1,
#   0.0475,
#   0.0826,
#   0.000745,
#   0.0546,
#   0.825,
#   139.994,
#   148486,
#   4],
#  [0.464,
#   0.417,
#   0,
#   -9.345,
#   0,
#   0.0256,
#   0.136,
#   0.022,
#   0.0974,
#   0.479,
#   67.528,
#   183956,
#   4],
#  [0.288,
#   0.758,
#   6,
#   -5.692,
#   0,
#   0.0371,
#   0.00616,
#   0,
#   0.303,
#   0.619,
#   97.094,
#   201726,
#   4],
#  [0.646,
#   0.813,
#   6,
#   -5.29,
#   0,
#   0.0288,
#   0.00178,
#   2.26e-05,
#   0.144,
#   0.821,
#   112.115,
#   173493,
#   4],
#  [0.431,
#   0.723,
#   8,
#   -5.887,
#   1,
#   0.0568,
#   0.145,
#   0,
#   0.374,
#   0.19,
#   130.141,
#   267360,
#   4],
#  [0.531,
#   0.481,
#   4,
#   -11.709,
#   0,
#   0.06,
#   0.699,
#   0,
#   0.0842,
#   0.491,
#   138.45,
#   516893,
#   4],
#  [0.492,
#   0.81,
#   7,
#   -5.315,
#   1,
#   0.0847,
#   0.0416,
#   0.00379,
#   0.117,
#   0.245,
#   149.954,
#   251840,
#   4],
#  [0.747,
#   0.716,
#   11,
#   -2.457,
#   0,
#   0.075,
#   0.135,
#   0,
#   0.251,
#   0.751,
#   125.008,
#   210627,
#   4],
#  [0.569,
#   0.83,
#   9,
#   -4.106,
#   0,
#   0.14,
#   0.0807,
#   0,
#   0.114,
#   0.609,
#   170.094,
#   186635,
#   4],
#  [0.657,
#   0.56,
#   6,
#   -9.049,
#   0,
#   0.0467,
#   0.498,
#   0,
#   0.0794,
#   0.854,
#   161.993,
#   182947,
#   4],
#  [0.65,
#   0.715,
#   5,
#   -5.198,
#   0,
#   0.253,
#   0.0993,
#   0.000291,
#   0.126,
#   0.187,
#   106.672,
#   243717,
#   4],
#  [0.801,
#   0.475,
#   7,
#   -8.797,
#   0,
#   0.0516,
#   0.141,
#   1.73e-05,
#   0.0639,
#   0.234,
#   98.047,
#   213061,
#   4],
#  [0.647,
#   0.686,
#   3,
#   -5.745,
#   0,
#   0.0413,
#   0.08,
#   1.34e-06,
#   0.528,
#   0.268,
#   79.928,
#   258299,
#   4],
#  [0.804,
#   0.674,
#   5,
#   -5.453,
#   0,
#   0.0333,
#   0.294,
#   1.18e-06,
#   0.115,
#   0.292,
#   99.968,
#   245940,
#   4],
#  [0.634,
#   0.886,
#   2,
#   -3.466,
#   1,
#   0.0517,
#   0.0291,
#   0,
#   0.342,
#   0.922,
#   161.933,
#   168253,
#   4],
#  [0.55,
#   0.917,
#   0,
#   -3.159,
#   1,
#   0.0638,
#   0.00428,
#   0,
#   0.197,
#   0.601,
#   126.115,
#   177827,
#   4],
#  [0.44,
#   0.317,
#   8,
#   -9.258,
#   1,
#   0.0531,
#   0.891,
#   4.78e-06,
#   0.141,
#   0.268,
#   169.914,
#   233456,
#   3],
#  [0.729,
#   0.65,
#   5,
#   -3.539,
#   1,
#   0.0313,
#   0.0702,
#   6.69e-05,
#   0.0829,
#   0.347,
#   110.02,
#   209160,
#   4],
#  [0.504,
#   0.904,
#   6,
#   -6.863,
#   1,
#   0.179,
#   0.356,
#   0.121,
#   0.14,
#   0.772,
#   176.808,
#   183440,
#   4],
#  [0.554,
#   0.315,
#   3,
#   -11.028,
#   1,
#   0.0298,
#   0.828,
#   5.53e-06,
#   0.101,
#   0.325,
#   128.157,
#   241787,
#   4],
#  [0.414,
#   0.428,
#   0,
#   -11.097,
#   1,
#   0.0278,
#   0.382,
#   0.000243,
#   0.148,
#   0.282,
#   145.075,
#   377093,
#   4],
#  [0.749,
#   0.491,
#   10,
#   -9.655,
#   1,
#   0.0403,
#   0.02,
#   0.00899,
#   0.159,
#   0.536,
#   119.528,
#   292613,
#   4],
#  [0.561,
#   0.965,
#   7,
#   -3.673,
#   0,
#   0.0343,
#   0.00383,
#   7.07e-06,
#   0.371,
#   0.304,
#   128.04,
#   175238,
#   4],
#  [0.552,
#   0.608,
#   1,
#   -9.786,
#   0,
#   0.0345,
#   0.352,
#   0,
#   0.0533,
#   0.637,
#   112.367,
#   162373,
#   4],
#  [0.674,
#   0.789,
#   8,
#   -6.903,
#   1,
#   0.0676,
#   0.00178,
#   0.00708,
#   0.0753,
#   0.918,
#   129.802,
#   121160,
#   4]]

# %%
num_features = len(num_track_data[0])

# %%
reduced_genres = {}
for genre in total_genres:
    if ' ' not in genre or genre == "hip hop":
        reduced_genres[genre] = []

for genre in total_genres:
    base_genre = genre
    if ' ' in genre:
        for key in reduced_genres.keys():
            if key in genre:
                base_genre = key
    if base_genre not in reduced_genres:
        reduced_genres[base_genre] = []
    else:
        reduced_genres[base_genre].append(genre)

# %%
print(len(reduced_genres))
reduced_genres
# Out:
# 110
# {'eurodance': ['eurodance'],
#  'neo-psychedelic': ['neo-psychedelic'],
#  'r&b': ['r&b',
#   'indie r&b',
#   'alternative r&b',
#   'canadian contemporary r&b',
#   'chill r&b',
#   'contemporary r&b',
#   'uk contemporary r&b'],
#  'afropop': ['afropop'],
#  'edm': ['edm', 'dutch edm'],
#  'madchester': ['madchester'],
#  'metropopolis': ['metropopolis'],
#  'shoegaze': ['shoegaze', 'french shoegaze'],
#  'soul': ['soul', 'british soul', 'northern soul', 'neo soul', 'classic soul'],
#  'electro': ['electro', 'canadian electronic'],
#  'britpop': ['britpop'],
#  'hip hop': ['minnesota hip hop',
#   'canadian old school hip hop',
#   'seattle hip hop',
#   'mississippi hip hop',
#   'atl hip hop',
#   'hip hop',
#   'kentucky hip hop',
#   'oakland hip hop',
#   'dutch hip hop',
#   'portland hip hop',
#   'deep underground hip hop',
#   'nigerian hip hop',
#   'memphis hip hop',
#   'north carolina hip hop',
#   'virginia hip hop',
#   'tennessee hip hop',
#   'latin hip hop',
#   'argentine hip hop',
#   'underground hip hop',
#   'canadian hip hop',
#   'south carolina hip hop',
#   'detroit hip hop',
#   'old school atlanta hip hop',
#   'queens hip hop',
#   'east coast hip hop',
#   'alternative hip hop',
#   'miami hip hop',
#   'lgbtq+ hip hop',
#   'conscious hip hop',
#   'southern hip hop',
#   'australian hip hop'],
#  'indietronica': ['indietronica'],
#  'complextro': ['complextro'],
#  'azonto': ['azonto'],
#  'neo-synthpop': ['neo-synthpop'],
#  'post-grunge': ['post-grunge'],
#  'trap': ['trap'],
#  'melancholia': ['melancholia'],
#  'trance': ['trance'],
#  'lilith': ['lilith'],
#  'folk': ['folk', 'indie folk'],
#  'sophisti-pop': ['sophisti-pop'],
#  'metal': ['glam metal',
#   'metal',
#   'alternative metal',
#   'thrash metal',
#   'nu metal'],
#  'cubaton': ['cubaton'],
#  'moombahton': ['moombahton'],
#  'rock': ['modern rock',
#   'modern alternative rock',
#   'rock keyboard',
#   'piano rock',
#   'detroit rock',
#   'blues rock',
#   'french rock',
#   'garage rock',
#   'celtic rock',
#   'heartland rock',
#   'southern rock',
#   'dance rock',
#   'rock',
#   'classic rock',
#   'folk rock',
#   'yacht rock',
#   'indie rock italiano',
#   'modern blues rock',
#   'alternative rock',
#   'swamp rock',
#   'canadian rock',
#   'art rock',
#   'roots rock',
#   'soft rock',
#   'album rock',
#   'symphonic rock',
#   'psychedelic rock',
#   'glam rock',
#   'irish rock',
#   'hard rock',
#   'australian rock'],
#  'beatlesque': ['beatlesque'],
#  'aussietronica': ['aussietronica'],
#  'rap': ['canadian trap',
#   'sad rap',
#   'atl trap',
#   'new jersey rap',
#   'philly rap',
#   'dmv rap',
#   'florida rap',
#   'toronto rap',
#   'trap queen',
#   'new orleans rap',
#   'rap kreyol',
#   'gangster rap',
#   'rap',
#   'electronic trap',
#   'pittsburgh rap',
#   'dfw rap',
#   'rap latina',
#   'rhode island rap',
#   'viral trap',
#   'trap argentino',
#   'houston rap',
#   'rap rock',
#   'trap boricua',
#   'vapor trap',
#   'dirty south rap',
#   'viral rap',
#   'dark trap',
#   'trap soul',
#   'west coast rap',
#   'rap metal',
#   'trap latino',
#   'chicago rap',
#   'rap conscient',
#   'melodic rap',
#   'cali rap'],
#  'hollywood': ['hollywood'],
#  'disco': ['disco'],
#  'dancehall': ['afro dancehall', 'dancehall'],
#  'covertronica': ['covertronica'],
#  'neo-singer-songwriter': ['neo-singer-songwriter'],
#  'bboy': ['bboy'],
#  'crunk': ['crunk'],
#  'funk': ['modern funk',
#   'g funk',
#   'funk metal',
#   'jazz funk',
#   'uk funky',
#   'instrumental funk',
#   'funk',
#   'funk rock'],
#  'synthpop': ['synthpop'],
#  'cumbia': ['cumbia'],
#  'k-pop': ['k-pop'],
#  'folk-pop': ['folk-pop'],
#  'merseybeat': ['merseybeat'],
#  'etherpop': ['etherpop'],
#  'emo': ['emo rap', 'emo'],
#  'francoton': ['francoton'],
#  'bubblegrunge': ['bubblegrunge'],
#  'gqom': ['gqom'],
#  'speedrun': ['speedrun'],
#  'country': ['country rock',
#   'country road',
#   'modern country rock',
#   'contemporary country',
#   'texas country',
#   'country'],
#  'punk': ['punk blues', 'punk', 'skate punk'],
#  'grunge': ['grunge'],
#  'europop': ['europop'],
#  'pop': ['latin pop',
#   'uk alternative pop',
#   'pop rap',
#   'baroque pop',
#   'k-pop boy group',
#   'italian pop',
#   'sunshine pop',
#   'french pop',
#   'french synthpop',
#   'german pop',
#   'new wave pop',
#   'alternative pop rock',
#   'israeli pop',
#   'pop edm',
#   'pop electronico',
#   'swedish pop',
#   'french indie pop',
#   'pop dance',
#   'teen pop',
#   'socal pop punk',
#   'modern alternative pop',
#   'candy pop',
#   'pop punk',
#   'indie pop',
#   'pop rock',
#   'danish pop',
#   'indie pop rap',
#   'dark pop',
#   'norwegian pop',
#   'country pop',
#   'nigerian pop',
#   'gauze pop',
#   'shiver pop',
#   'viral pop',
#   'latin arena pop',
#   'bedroom pop',
#   'indie poptimism',
#   'dutch pop',
#   'shimmer pop',
#   'latin viral pop',
#   'dance pop',
#   'pop r&b',
#   'post-teen pop',
#   'pop soul',
#   'canadian pop',
#   'hip pop',
#   'stomp pop',
#   'australian pop',
#   'pop venezolano',
#   'nz pop',
#   'chill pop',
#   'pop',
#   'art pop',
#   'colombian pop',
#   'barbadian pop',
#   'deep dance pop',
#   'swedish synthpop',
#   'mexican pop',
#   'social media pop',
#   'bubblegum pop',
#   'uk pop',
#   'puerto rican pop',
#   'acoustic pop',
#   'modern power pop'],
#  'grime': ['birmingham grime', 'grime', 'instrumental grime'],
#  'pluggnb': ['pluggnb'],
#  'singer-songwriter': ['irish singer-songwriter', 'singer-songwriter'],
#  'house': ['vocal house',
#   'deep euro house',
#   'hip house',
#   'disco house',
#   'dutch house',
#   'electro house',
#   'pop house',
#   'deep groove house',
#   'deep house',
#   'filter house',
#   'tropical house',
#   'progressive electro house',
#   'progressive house',
#   'slap house',
#   'house'],
#  'reggaeton': ['reggaeton colombiano',
#   'reggaeton flow',
#   'pop reggaeton',
#   'reggaeton'],
#  'motown': ['motown'],
#  'electropop': ['australian electropop', 'swedish electropop', 'electropop'],
#  'protopunk': ['protopunk'],
#  'scandipop': ['scandipop'],
#  'afrofuturism': ['afrofuturism'],
#  'brostep': ['brostep'],
#  'melbourne bounce': [],
#  'italo dance': [],
#  'bergen indie': [],
#  'australian dance': [],
#  'urbano latino': [],
#  'sad lo-fi': [],
#  'big room': [],
#  'sheffield indie': [],
#  'girl group': ['k-pop girl group'],
#  'la indie': [],
#  'alt z': [],
#  'german dance': [],
#  'boy band': [],
#  'new wave': ['scottish new wave'],
#  'latin alternative': [],
#  'virgin islands reggae': [],
#  'alternative dance': [],
#  'nashville indie': [],
#  'quiet storm': [],
#  'permanent wave': [],
#  'talent show': ['deep talent show'],
#  'new french touch': [],
#  'oxford indie': [],
#  'athens indie': [],
#  'reggae fusion': [],
#  "women's music": [],
#  'adult standards': [],
#  'lo-fi chill': [],
#  'new romantic': [],
#  'mellow gold': [],
#  'brooklyn drill': [],
#  'uk dance': [],
#  'british invasion': [],
#  'double drumming': [],
#  'show tunes': [],
#  'urban contemporary': [],
#  'escape room': [],
#  'neo mellow': [],
#  'german techno': [],
#  'stomp and holler': [],
#  'old school thrash': [],
#  'australian psych': [],
#  'tropical alternativo': [],
#  'video game music': [],
#  'florida drill': []}

# %%
n = len(reduced_genres)
n
# Out:
# 110

# %%
#kmeans
km = KMeans(n_clusters=n, init='random', n_init='auto', 
    tol=1e-04, random_state=0)
y_km = km.fit_predict(num_track_data)
y_km
# Out:
# array([ 64,  80,  47,  83, 101,  40,  95,  91,   8,  38,  27,  63,  16,
#         20,  52,  53,  59,  76,  68, 106,  64,  95,   5,  85,  60,  23,
#         80,   9,  54,  90,   6,  59,  87, 100,  28,  15, 101,  29,  68,
#         47,  71, 107,  82,  35,  89,  79,   9,   8,  90,  64,   5,  51,
#        102,  82,  26,  71,  75,  90,  14,  37,  44,  11,  29,  47,   6,
#         99,  44,  14,  64,  37,   4, 102,  34,  30,  29,  61,   8,  38,
#        103,  80,  61, 106,  17,  49,   5, 102,  20, 106,  10, 102,  77,
#         36,   3, 105,  28,  84,  72,  36,  72,  83,  29, 105,  94,  94,
#         87,  66, 101,  47,  47,  98,  70,   7,  40,  79,  19,  71,  37,
#         71,  86,   8,  87,  23,  32,  54,  40,  44,   4,   6,   2,  56,
#         38,  10,  49,  93,  75,  16, 101,  42,  47,   8,  58,  16,  60,
#         86,  45,  16,  27,  18,  85,  89,  98,  10,  32,  19,  29,  48,
#         93,  39, 101,  93,  71,  29,  99,  29,   8,  98,  38,  26,  91,
#         37, 106,  87, 102,  99,  20,  88,  30,  77,  91,   0,  22,  93,
#         48,  12,  35,  58,  70,  81,  44,  31,  65,  15,  59,  75,  82,
#         36,  90,  48,  21,  71,  84,   8,  18,  91,  99,  12,  19,  24,
#         43,  92,  64,  20,  45,   1,  29,  46,  54,  88,  97,   4,  41,
#         15,   7,  96,  76,  56,  33,  98,  46,  29,   9,  69,  40,  21,
#         56,   7,  87, 109,  31,  36,  22,  90,  58,  60, 106,   9,  29,
#         24,  33,  83,  70, 101,  14, 102,  37,  79, 104,  11,   0,  58,
#          5,   7, 107,   8,  62,  26,  11,  46,  64,  47,  27,  91,  65,
#         78,  61,  59,  79,  63,  10,  22, 105,  29,  27,  29,  38,  34,
#         18,  76,  48,  91,  29,  59,  11, 105,   3,  86,  77,  34,  61,
#          7,   2,  84,  63,   6, 102,  16,  81,  43, 106, 105,  62,  99,
#         88,  58,  30,  70, 106,  88,  63,  46,  81,  48,  29,  36,   5,
#         58,  41, 106, 100,  24,   4,  73,  50,  56,   9,  75,  66, 108,
#          1,  42,  44,  13,  30,  64,   7,   9,  81,  47,  27,  50,   4,
#         28,  37,  86,  44,  58,  34,  20, 107,  27,  19,  17,  66,  28,
#          4,  72,   2,  36,  58,  15,  63,  63,  61,  37,  56,  64,  14,
#          8,  57,  31,  36,  64, 102,  18,   8,  14,  44,  90,  33,  28,
#          0,  86,  16, 103,  92,  86, 108,  27,  36,  96,  31,  46,  50,
#        109,  49,  36,  19,  72,  17,  46,   4,   4,  84,  14,  14,  46,
#          8,  13, 104,  96,  48,  71,  22,  29,   9, 101,  84, 109,  63,
#         63,  66,  64,  69, 104,  29,  58,  27,  49,  25,  66,  74,  65,
#         44,  50,  72,   1,  75,   5,  27,  22,  22,  28, 100,   8,  39,
#         91,  55,  64,  84,  80,  75,  89,  46,  97,   4,  13,   4, 108,
#         67,  64,  66,  20,  83,  94,  28,  14,  21,   4,  47,  99, 104,
#          1,   6,  95,  46,  86,  64,  30,   6,   3,  27,  26,  41,  20,
#         38,  42,   3,  52,  33,  37,  17,  38,  29,  38,  40,  74,  11,
#         33,   8,   8,  27,  25,  29,  67,  13,  35,  48,  59,  45,  11,
#         68, 100,   2, 107,  76,  40,  40,  69,  58,  60,  47, 109,  29,
#         96,  88,  92,   9,  85,  10,  84,  92,  90,  53,  58,  20,   0,
#          7,  69,   6,  66,  84,  66,  24,  83,  10, 105,  21,  80,  16,
#         67,  24,  93,   9, 108,  20,  71,  17,  37,  63,  59,  22,   4,
#         14, 103,  32,  47,  64,  47,  46,  51,  61, 101,   0,   0,   8,
#         40,  23, 101,  59,  56,  61,   8,  82,  83,  10,  39,  17,  58,
#         68,  83,  29,  89,  62,  88,  57,  88,   7,  27,  72,  74,  43,
#         40,  75,  85,  43,  65,  99,  75,  76,  42,  28,  57,  45,  66,
#         93,  99,  19,  10,  62,  25,  52,  63,   9,  32,  91,  70,  43,
#         16,  15,  40,   9,  36,  62,   2,  95,  64,  86,  17,  84,  46,
#         12,  75,  38,  33,  40,  68,  76,  38,  68,  29,  42,  50,  74,
#         98,  62,  87,  68,  28,  86,   5,  60,   9,  51,  21,  47,  68,
#         90,  55,  77,  34,  58,  15])

# %%
print("Number of tracks: " + str(len(y_km)) + "\n" +
    "Number of genres: " + str(len(set(y_km))))
# Out:
# Number of tracks: 682
# Number of genres: 110

# %%
for i in range(len(track_info)):
    track_info[i]["Category"] = y_km[i]

track_info
# Out:
# [{'danceability': 0.514,
#   'energy': 0.73,
#   'key': 1,
#   'loudness': -5.934,
#   'mode': 1,
#   'speechiness': 0.0598,
#   'acousticness': 0.00146,
#   'instrumentalness': 9.54e-05,
#   'liveness': 0.0897,
#   'valence': 0.334,
#   'tempo': 171.005,
#   'duration_ms': 200040,
#   'time_signature': 4,
#   'name': 'Blinding Lights',
#   'artist(s)': ['The Weeknd'],
#   'genres': [['canadian contemporary r&b', 'canadian pop', 'pop']],
#   'Category': 64},
#  {'danceability': 0.825,
#   'energy': 0.652,
#   'key': 1,
#   'loudness': -3.183,
#   'mode': 0,
#   'speechiness': 0.0802,
#   'acousticness': 0.581,
#   'instrumentalness': 0,
#   'liveness': 0.0931,
#   'valence': 0.931,
#   'tempo': 95.977,
#   'duration_ms': 233713,
#   'time_signature': 4,
#   'name': 'Shape of You',
#   'artist(s)': ['Ed Sheeran'],
#   'genres': [['pop', 'uk pop']],
#   'Category': 80},
#  {'danceability': 0.824,
#   'energy': 0.587,
#   'key': 6,
#   'loudness': -6.401,
#   'mode': 0,
#   'speechiness': 0.0937,
#   'acousticness': 0.69,
#   'instrumentalness': 0.000105,
#   'liveness': 0.149,
#   'valence': 0.514,
#   'tempo': 98.029,
#   'duration_ms': 209438,
#   'time_signature': 4,
#   'name': 'Dance Monkey',
#   'artist(s)': ['Tones And I'],
#   'genres': [['australian pop', 'pop']],
#   'Category': 47},
#  {'danceability': 0.501,
#   'energy': 0.405,
#   'key': 1,
#   'loudness': -5.679,
#   'mode': 1,
#   'speechiness': 0.0319,
#   'acousticness': 0.751,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.446,
#   'tempo': 109.891,
#   'duration_ms': 182161,
#   'time_signature': 4,
#   'name': 'Someone You Loved',
#   'artist(s)': ['Lewis Capaldi'],
#   'genres': [['pop', 'uk pop']],
#   'Category': 83},
#  {'danceability': 0.585,
#   'energy': 0.52,
#   'key': 5,
#   'loudness': -6.136,
#   'mode': 0,
#   'speechiness': 0.0712,
#   'acousticness': 0.124,
#   'instrumentalness': 7.01e-05,
#   'liveness': 0.131,
#   'valence': 0.129,
#   'tempo': 159.801,
#   'duration_ms': 218147,
#   'time_signature': 4,
#   'name': 'rockstar (feat. 21 Savage)',
#   'artist(s)': ['Post Malone', '21 Savage'],
#   'genres': [['dfw rap', 'melodic rap', 'rap'], ['atl hip hop', 'rap']],
#   'Category': 101},
#  {'danceability': 0.76,
#   'energy': 0.479,
#   'key': 2,
#   'loudness': -5.574,
#   'mode': 1,
#   'speechiness': 0.0466,
#   'acousticness': 0.556,
#   'instrumentalness': 0,
#   'liveness': 0.0703,
#   'valence': 0.913,
#   'tempo': 89.911,
#   'duration_ms': 158040,
#   'time_signature': 4,
#   'name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#   'artist(s)': ['Post Malone', 'Swae Lee'],
#   'genres': [['dfw rap', 'melodic rap', 'rap'], ['melodic rap', 'trap']],
#   'Category': 40},
#  {'danceability': 0.792,
#   'energy': 0.625,
#   'key': 1,
#   'loudness': -5.609,
#   'mode': 1,
#   'speechiness': 0.0536,
#   'acousticness': 0.00776,
#   'instrumentalness': 0.00188,
#   'liveness': 0.329,
#   'valence': 0.37,
#   'tempo': 103.967,
#   'duration_ms': 173987,
#   'time_signature': 4,
#   'name': 'One Dance',
#   'artist(s)': ['Drake', 'Wizkid', 'Kyla'],
#   'genres': [['canadian hip hop',
#     'canadian pop',
#     'hip hop',
#     'rap',
#     'toronto rap'],
#    ['afro dancehall', 'afropop', 'azonto', 'nigerian hip hop', 'nigerian pop'],
#    ['uk funky']],
#   'Category': 95},
#  {'danceability': 0.738,
#   'energy': 0.541,
#   'key': 8,
#   'loudness': -5.597,
#   'mode': 1,
#   'speechiness': 0.0303,
#   'acousticness': 0.415,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.657,
#   'tempo': 94.949,
#   'duration_ms': 245507,
#   'time_signature': 4,
#   'name': 'Closer',
#   'artist(s)': ['The Chainsmokers', 'Halsey'],
#   'genres': [['dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    ['dance pop', 'electropop', 'etherpop', 'indie poptimism', 'pop']],
#   'Category': 91},
#  {'danceability': 0.772,
#   'energy': 0.78,
#   'key': 10,
#   'loudness': -4.288,
#   'mode': 0,
#   'speechiness': 0.108,
#   'acousticness': 0.0512,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.719,
#   'tempo': 124.988,
#   'duration_ms': 204347,
#   'time_signature': 4,
#   'name': 'Believer',
#   'artist(s)': ['Imagine Dragons'],
#   'genres': [['modern rock', 'rock']],
#   'Category': 8},
#  {'danceability': 0.591,
#   'energy': 0.764,
#   'key': 1,
#   'loudness': -5.484,
#   'mode': 1,
#   'speechiness': 0.0483,
#   'acousticness': 0.0383,
#   'instrumentalness': 0,
#   'liveness': 0.103,
#   'valence': 0.478,
#   'tempo': 169.928,
#   'duration_ms': 141806,
#   'time_signature': 4,
#   'name': 'STAY (with Justin Bieber)',
#   'artist(s)': ['The Kid LAROI', 'Justin Bieber'],
#   'genres': [['australian hip hop', 'pop', 'rap'], ['canadian pop', 'pop']],
#   'Category': 38},
#  {'danceability': 0.759,
#   'energy': 0.548,
#   'key': 9,
#   'loudness': -6.049,
#   'mode': 0,
#   'speechiness': 0.029,
#   'acousticness': 0.0392,
#   'instrumentalness': 0,
#   'liveness': 0.0828,
#   'valence': 0.749,
#   'tempo': 116.967,
#   'duration_ms': 190800,
#   'time_signature': 4,
#   'name': 'Señorita',
#   'artist(s)': ['Shawn Mendes', 'Camila Cabello'],
#   'genres': [['canadian pop', 'dance pop', 'pop', 'viral pop'],
#    ['dance pop', 'pop', 'post-teen pop']],
#   'Category': 27},
#  {'danceability': 0.599,
#   'energy': 0.448,
#   'key': 8,
#   'loudness': -6.312,
#   'mode': 1,
#   'speechiness': 0.0232,
#   'acousticness': 0.163,
#   'instrumentalness': 0,
#   'liveness': 0.106,
#   'valence': 0.168,
#   'tempo': 95.05,
#   'duration_ms': 263400,
#   'time_signature': 3,
#   'name': 'Perfect',
#   'artist(s)': ['Ed Sheeran'],
#   'genres': [['pop', 'uk pop']],
#   'Category': 63},
#  {'danceability': 0.761,
#   'energy': 0.525,
#   'key': 11,
#   'loudness': -6.9,
#   'mode': 1,
#   'speechiness': 0.0944,
#   'acousticness': 0.44,
#   'instrumentalness': 6.7e-06,
#   'liveness': 0.0921,
#   'valence': 0.531,
#   'tempo': 80.87,
#   'duration_ms': 238805,
#   'time_signature': 4,
#   'name': 'Heat Waves',
#   'artist(s)': ['Glass Animals'],
#   'genres': [['gauze pop', 'indietronica', 'shiver pop']],
#   'Category': 16},
#  {'danceability': 0.358,
#   'energy': 0.557,
#   'key': 10,
#   'loudness': -7.398,
#   'mode': 1,
#   'speechiness': 0.059,
#   'acousticness': 0.695,
#   'instrumentalness': 0,
#   'liveness': 0.0902,
#   'valence': 0.494,
#   'tempo': 85.043,
#   'duration_ms': 211467,
#   'time_signature': 4,
#   'name': "Say You Won't Let Go",
#   'artist(s)': ['James Arthur'],
#   'genres': [['pop', 'talent show', 'uk pop']],
#   'Category': 20},
#  {'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'duration_ms': 194088,
#   'time_signature': 4,
#   'name': 'bad guy',
#   'artist(s)': ['Billie Eilish'],
#   'genres': [['art pop', 'electropop', 'pop']],
#   'Category': 52},
#  {'danceability': 0.781,
#   'energy': 0.445,
#   'key': 2,
#   'loudness': -6.061,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.474,
#   'instrumentalness': 0,
#   'liveness': 0.184,
#   'valence': 0.591,
#   'tempo': 78.998,
#   'duration_ms': 281560,
#   'time_signature': 4,
#   'name': 'Thinking out Loud',
#   'artist(s)': ['Ed Sheeran'],
#   'genres': [['pop', 'uk pop']],
#   'Category': 53},
#  {'danceability': 0.511,
#   'energy': 0.566,
#   'key': 6,
#   'loudness': -7.23,
#   'mode': 0,
#   'speechiness': 0.2,
#   'acousticness': 0.349,
#   'instrumentalness': 0,
#   'liveness': 0.34,
#   'valence': 0.218,
#   'tempo': 83.903,
#   'duration_ms': 239836,
#   'time_signature': 4,
#   'name': 'Lucid Dreams',
#   'artist(s)': ['Juice WRLD'],
#   'genres': [['chicago rap', 'melodic rap']],
#   'Category': 59},
#  {'danceability': 0.679,
#   'energy': 0.587,
#   'key': 7,
#   'loudness': -7.015,
#   'mode': 1,
#   'speechiness': 0.276,
#   'acousticness': 0.141,
#   'instrumentalness': 6.35e-06,
#   'liveness': 0.137,
#   'valence': 0.486,
#   'tempo': 186.003,
#   'duration_ms': 230453,
#   'time_signature': 4,
#   'name': 'Starboy',
#   'artist(s)': ['The Weeknd', 'Daft Punk'],
#   'genres': [['canadian contemporary r&b', 'canadian pop', 'pop'],
#    ['electro', 'filter house']],
#   'Category': 76},
#  {'danceability': 0.793,
#   'energy': 0.793,
#   'key': 11,
#   'loudness': -4.521,
#   'mode': 0,
#   'speechiness': 0.083,
#   'acousticness': 0.0123,
#   'instrumentalness': 0,
#   'liveness': 0.0951,
#   'valence': 0.679,
#   'tempo': 123.95,
#   'duration_ms': 183290,
#   'time_signature': 4,
#   'name': "Don't Start Now",
#   'artist(s)': ['Dua Lipa'],
#   'genres': [['dance pop', 'pop', 'uk pop']],
#   'Category': 68},
#  {'danceability': 0.754,
#   'energy': 0.449,
#   'key': 7,
#   'loudness': -9.211,
#   'mode': 1,
#   'speechiness': 0.109,
#   'acousticness': 0.0332,
#   'instrumentalness': 8.29e-05,
#   'liveness': 0.552,
#   'valence': 0.357,
#   'tempo': 77.169,
#   'duration_ms': 198973,
#   'time_signature': 4,
#   'name': "God's Plan",
#   'artist(s)': ['Drake'],
#   'genres': [['canadian hip hop',
#     'canadian pop',
#     'hip hop',
#     'rap',
#     'toronto rap']],
#   'Category': 106},
#  {'danceability': 0.351,
#   'energy': 0.296,
#   'key': 4,
#   'loudness': -10.109,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.934,
#   'instrumentalness': 0,
#   'liveness': 0.095,
#   'valence': 0.12,
#   'tempo': 115.284,
#   'duration_ms': 200186,
#   'time_signature': 4,
#   'name': 'lovely (with Khalid)',
#   'artist(s)': ['Billie Eilish', 'Khalid'],
#   'genres': [['art pop', 'electropop', 'pop'], ['pop', 'pop r&b']],
#   'Category': 64},
#  {'danceability': 0.548,
#   'energy': 0.816,
#   'key': 0,
#   'loudness': -4.209,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.122,
#   'instrumentalness': 0,
#   'liveness': 0.335,
#   'valence': 0.557,
#   'tempo': 95.39,
#   'duration_ms': 174000,
#   'time_signature': 4,
#   'name': 'Watermelon Sugar',
#   'artist(s)': ['Harry Styles'],
#   'genres': [['pop']],
#   'Category': 95},
#  {'danceability': 0.614,
#   'energy': 0.379,
#   'key': 4,
#   'loudness': -10.48,
#   'mode': 1,
#   'speechiness': 0.0476,
#   'acousticness': 0.607,
#   'instrumentalness': 0.000464,
#   'liveness': 0.0986,
#   'valence': 0.201,
#   'tempo': 107.989,
#   'duration_ms': 258987,
#   'time_signature': 4,
#   'name': 'Photograph',
#   'artist(s)': ['Ed Sheeran'],
#   'genres': [['pop', 'uk pop']],
#   'Category': 5},
#  {'danceability': 0.392,
#   'energy': 0.402,
#   'key': 0,
#   'loudness': -9.961,
#   'mode': 0,
#   'speechiness': 0.0536,
#   'acousticness': 0.288,
#   'instrumentalness': 0,
#   'liveness': 0.243,
#   'valence': 0.228,
#   'tempo': 143.883,
#   'duration_ms': 354320,
#   'time_signature': 4,
#   'name': 'Bohemian Rhapsody - Remastered 2011',
#   'artist(s)': ['Queen'],
#   'genres': [['classic rock', 'glam rock', 'rock']],
#   'Category': 85},
#  {'danceability': 0.617,
#   'energy': 0.635,
#   'key': 11,
#   'loudness': -6.769,
#   'mode': 0,
#   'speechiness': 0.0317,
#   'acousticness': 0.0498,
#   'instrumentalness': 1.44e-05,
#   'liveness': 0.164,
#   'valence': 0.446,
#   'tempo': 103.019,
#   'duration_ms': 247160,
#   'time_signature': 4,
#   'name': 'Something Just Like This',
#   'artist(s)': ['The Chainsmokers', 'Coldplay'],
#   'genres': [['dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    ['permanent wave', 'pop']],
#   'Category': 60},
#  {'danceability': 0.572,
#   'energy': 0.385,
#   'key': 7,
#   'loudness': -6.362,
#   'mode': 1,
#   'speechiness': 0.0308,
#   'acousticness': 0.371,
#   'instrumentalness': 0,
#   'liveness': 0.231,
#   'valence': 0.323,
#   'tempo': 95.799,
#   'duration_ms': 215733,
#   'time_signature': 4,
#   'name': 'Shallow',
#   'artist(s)': ['Lady Gaga', 'Bradley Cooper'],
#   'genres': [['art pop', 'dance pop', 'pop'], ['hollywood']],
#   'Category': 23},
#  {'danceability': 0.609,
#   'energy': 0.378,
#   'key': 4,
#   'loudness': -9.828,
#   'mode': 1,
#   'speechiness': 0.438,
#   'acousticness': 0.835,
#   'instrumentalness': 0,
#   'liveness': 0.28,
#   'valence': 0.515,
#   'tempo': 100.418,
#   'duration_ms': 233720,
#   'time_signature': 4,
#   'name': 'Love Yourself',
#   'artist(s)': ['Justin Bieber'],
#   'genres': [['canadian pop', 'pop']],
#   'Category': 80},
#  {'danceability': 0.74,
#   'energy': 0.613,
#   'key': 8,
#   'loudness': -4.88,
#   'mode': 1,
#   'speechiness': 0.145,
#   'acousticness': 0.258,
#   'instrumentalness': 0.00372,
#   'liveness': 0.123,
#   'valence': 0.473,
#   'tempo': 75.023,
#   'duration_ms': 166606,
#   'time_signature': 4,
#   'name': 'SAD!',
#   'artist(s)': ['XXXTENTACION'],
#   'genres': [['emo rap', 'miami hip hop']],
#   'Category': 9},
#  {'danceability': 0.695,
#   'energy': 0.762,
#   'key': 0,
#   'loudness': -3.497,
#   'mode': 1,
#   'speechiness': 0.0395,
#   'acousticness': 0.192,
#   'instrumentalness': 0.00244,
#   'liveness': 0.0863,
#   'valence': 0.553,
#   'tempo': 120.042,
#   'duration_ms': 215280,
#   'time_signature': 4,
#   'name': 'Circles',
#   'artist(s)': ['Post Malone'],
#   'genres': [['dfw rap', 'melodic rap', 'rap']],
#   'Category': 54},
#  {'danceability': 0.575,
#   'energy': 0.664,
#   'key': 4,
#   'loudness': -5.303,
#   'mode': 0,
#   'speechiness': 0.0481,
#   'acousticness': 0.637,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.437,
#   'tempo': 129.07,
#   'duration_ms': 241693,
#   'time_signature': 4,
#   'name': 'Take Me to Church',
#   'artist(s)': ['Hozier'],
#   'genres': [['irish singer-songwriter', 'pop']],
#   'Category': 90},
#  {'danceability': 0.422,
#   'energy': 0.264,
#   'key': 8,
#   'loudness': -7.064,
#   'mode': 1,
#   'speechiness': 0.0322,
#   'acousticness': 0.922,
#   'instrumentalness': 0,
#   'liveness': 0.132,
#   'valence': 0.331,
#   'tempo': 119.93,
#   'duration_ms': 269560,
#   'time_signature': 4,
#   'name': 'All of Me',
#   'artist(s)': ['John Legend'],
#   'genres': [['neo soul', 'pop', 'pop soul', 'r&b', 'urban contemporary']],
#   'Category': 6},
#  {'danceability': 0.612,
#   'energy': 0.807,
#   'key': 10,
#   'loudness': -2.81,
#   'mode': 1,
#   'speechiness': 0.0336,
#   'acousticness': 0.0495,
#   'instrumentalness': 0.0177,
#   'liveness': 0.101,
#   'valence': 0.398,
#   'tempo': 124.053,
#   'duration_ms': 240400,
#   'time_signature': 4,
#   'name': 'Sweater Weather',
#   'artist(s)': ['The Neighbourhood'],
#   'genres': [['modern alternative rock', 'modern rock', 'pop', 'shimmer pop']],
#   'Category': 59},
#  {'danceability': 0.604,
#   'energy': 0.826,
#   'key': 0,
#   'loudness': -4.804,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.00782,
#   'instrumentalness': 0.15,
#   'liveness': 0.154,
#   'valence': 0.241,
#   'tempo': 167.985,
#   'duration_ms': 187147,
#   'time_signature': 4,
#   'name': 'Thunder',
#   'artist(s)': ['Imagine Dragons'],
#   'genres': [['modern rock', 'rock']],
#   'Category': 87},
#  {'danceability': 0.778,
#   'energy': 0.317,
#   'key': 1,
#   'loudness': -10.732,
#   'mode': 0,
#   'speechiness': 0.334,
#   'acousticness': 0.592,
#   'instrumentalness': 0,
#   'liveness': 0.0881,
#   'valence': 0.327,
#   'tempo': 140.048,
#   'duration_ms': 178627,
#   'time_signature': 4,
#   'name': '7 rings',
#   'artist(s)': ['Ariana Grande'],
#   'genres': [['dance pop', 'pop']],
#   'Category': 100},
#  {'danceability': 0.841,
#   'energy': 0.728,
#   'key': 7,
#   'loudness': -3.37,
#   'mode': 1,
#   'speechiness': 0.0484,
#   'acousticness': 0.0847,
#   'instrumentalness': 0,
#   'liveness': 0.149,
#   'valence': 0.43,
#   'tempo': 130.049,
#   'duration_ms': 243837,
#   'time_signature': 4,
#   'name': 'goosebumps',
#   'artist(s)': ['Travis Scott'],
#   'genres': [['rap', 'slap house']],
#   'Category': 28},
#  {'danceability': 0.872,
#   'energy': 0.391,
#   'key': 0,
#   'loudness': -9.144,
#   'mode': 0,
#   'speechiness': 0.242,
#   'acousticness': 0.469,
#   'instrumentalness': 4.13e-06,
#   'liveness': 0.297,
#   'valence': 0.437,
#   'tempo': 134.021,
#   'duration_ms': 119133,
#   'time_signature': 4,
#   'name': 'Jocelyn Flores',
#   'artist(s)': ['XXXTENTACION'],
#   'genres': [['emo rap', 'miami hip hop']],
#   'Category': 15},
#  {'danceability': 0.765,
#   'energy': 0.523,
#   'key': 2,
#   'loudness': -4.333,
#   'mode': 1,
#   'speechiness': 0.03,
#   'acousticness': 0.184,
#   'instrumentalness': 3.56e-05,
#   'liveness': 0.132,
#   'valence': 0.394,
#   'tempo': 104.988,
#   'duration_ms': 217307,
#   'time_signature': 4,
#   'name': 'Havana (feat. Young Thug)',
#   'artist(s)': ['Camila Cabello', 'Young Thug'],
#   'genres': [['dance pop', 'pop', 'post-teen pop'],
#    ['atl hip hop',
#     'atl trap',
#     'gangster rap',
#     'hip hop',
#     'melodic rap',
#     'pop rap',
#     'rap',
#     'southern hip hop',
#     'trap']],
#   'Category': 101},
#  {'danceability': 0.734,
#   'energy': 0.637,
#   'key': 4,
#   'loudness': -5.677,
#   'mode': 0,
#   'speechiness': 0.141,
#   'acousticness': 0.0462,
#   'instrumentalness': 2.29e-05,
#   'liveness': 0.0602,
#   'valence': 0.648,
#   'tempo': 169.977,
#   'duration_ms': 202333,
#   'time_signature': 4,
#   'name': 'Stressed Out',
#   'artist(s)': ['Twenty One Pilots'],
#   'genres': [['modern rock', 'rock']],
#   'Category': 29},
#  {'danceability': 0.732,
#   'energy': 0.75,
#   'key': 11,
#   'loudness': -6.366,
#   'mode': 0,
#   'speechiness': 0.231,
#   'acousticness': 0.00264,
#   'instrumentalness': 0,
#   'liveness': 0.109,
#   'valence': 0.401,
#   'tempo': 155.096,
#   'duration_ms': 182707,
#   'time_signature': 4,
#   'name': 'XO Tour Llif3',
#   'artist(s)': ['Lil Uzi Vert'],
#   'genres': [['melodic rap', 'philly rap', 'rap', 'trap']],
#   'Category': 68},
#  {'danceability': 0.762,
#   'energy': 0.7,
#   'key': 9,
#   'loudness': -6.021,
#   'mode': 0,
#   'speechiness': 0.0694,
#   'acousticness': 0.00261,
#   'instrumentalness': 1.56e-05,
#   'liveness': 0.153,
#   'valence': 0.608,
#   'tempo': 116.073,
#   'duration_ms': 209320,
#   'time_signature': 4,
#   'name': 'New Rules',
#   'artist(s)': ['Dua Lipa'],
#   'genres': [['dance pop', 'pop', 'uk pop']],
#   'Category': 47},
#  {'danceability': 0.687,
#   'energy': 0.792,
#   'key': 5,
#   'loudness': -2.749,
#   'mode': 1,
#   'speechiness': 0.0452,
#   'acousticness': 0.191,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.671,
#   'tempo': 100.015,
#   'duration_ms': 214290,
#   'time_signature': 4,
#   'name': 'Happier',
#   'artist(s)': ['Marshmello', 'Bastille'],
#   'genres': [['brostep',
#     'dance pop',
#     'edm',
#     'pop',
#     'pop dance',
#     'progressive electro house'],
#    ['metropopolis', 'modern rock', 'pop', 'pop rock']],
#   'Category': 71},
#  {'danceability': 0.663,
#   'energy': 0.712,
#   'key': 1,
#   'loudness': -4.945,
#   'mode': 0,
#   'speechiness': 0.0381,
#   'acousticness': 0.0649,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.48,
#   'tempo': 122.014,
#   'duration_ms': 257280,
#   'time_signature': 4,
#   'name': 'Counting Stars',
#   'artist(s)': ['OneRepublic'],
#   'genres': [['piano rock', 'pop']],
#   'Category': 107},
#  {'danceability': 0.908,
#   'energy': 0.621,
#   'key': 1,
#   'loudness': -6.638,
#   'mode': 0,
#   'speechiness': 0.102,
#   'acousticness': 0.000282,
#   'instrumentalness': 5.39e-05,
#   'liveness': 0.0958,
#   'valence': 0.421,
#   'tempo': 150.011,
#   'duration_ms': 177000,
#   'time_signature': 4,
#   'name': 'HUMBLE.',
#   'artist(s)': ['Kendrick Lamar'],
#   'genres': [['conscious hip hop', 'hip hop', 'rap', 'west coast rap']],
#   'Category': 82},
#  {'danceability': 0.516,
#   'energy': 0.806,
#   'key': 2,
#   'loudness': -5.133,
#   'mode': 1,
#   'speechiness': 0.0538,
#   'acousticness': 0.00389,
#   'instrumentalness': 0.000674,
#   'liveness': 0.115,
#   'valence': 0.577,
#   'tempo': 124.118,
#   'duration_ms': 249693,
#   'time_signature': 4,
#   'name': 'Wake Me Up',
#   'artist(s)': ['Avicii'],
#   'genres': [['dance pop', 'edm', 'pop', 'pop dance', 'pop rap']],
#   'Category': 35},
#  {'danceability': 0.479,
#   'energy': 0.545,
#   'key': 7,
#   'loudness': -7.346,
#   'mode': 1,
#   'speechiness': 0.0688,
#   'acousticness': 0.365,
#   'instrumentalness': 0,
#   'liveness': 0.0963,
#   'valence': 0.244,
#   'tempo': 74.897,
#   'duration_ms': 252733,
#   'time_signature': 4,
#   'name': 'Let Her Go',
#   'artist(s)': ['Passenger'],
#   'genres': [['folk-pop', 'neo mellow']],
#   'Category': 89},
#  {'danceability': 0.834,
#   'energy': 0.73,
#   'key': 8,
#   'loudness': -3.714,
#   'mode': 1,
#   'speechiness': 0.222,
#   'acousticness': 0.00513,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.446,
#   'tempo': 155.008,
#   'duration_ms': 312820,
#   'time_signature': 4,
#   'name': 'SICKO MODE',
#   'artist(s)': ['Travis Scott'],
#   'genres': [['rap', 'slap house']],
#   'Category': 79},
#  {'danceability': 0.52,
#   'energy': 0.731,
#   'key': 6,
#   'loudness': -5.338,
#   'mode': 0,
#   'speechiness': 0.0557,
#   'acousticness': 0.342,
#   'instrumentalness': 0.00101,
#   'liveness': 0.311,
#   'valence': 0.662,
#   'tempo': 173.93,
#   'duration_ms': 167303,
#   'time_signature': 4,
#   'name': 'As It Was',
#   'artist(s)': ['Harry Styles'],
#   'genres': [['pop']],
#   'Category': 9},
#  {'danceability': 0.484,
#   'energy': 0.731,
#   'key': 1,
#   'loudness': -6.694,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.431,
#   'instrumentalness': 0,
#   'liveness': 0.151,
#   'valence': 0.51,
#   'tempo': 101.654,
#   'duration_ms': 204280,
#   'time_signature': 4,
#   'name': 'Riptide',
#   'artist(s)': ['Vance Joy'],
#   'genres': [['folk-pop', 'pop']],
#   'Category': 8},
#  {'danceability': 0.356,
#   'energy': 0.567,
#   'key': 0,
#   'loudness': -7.011,
#   'mode': 0,
#   'speechiness': 0.0798,
#   'acousticness': 0.0861,
#   'instrumentalness': 0,
#   'liveness': 0.137,
#   'valence': 0.109,
#   'tempo': 135.553,
#   'duration_ms': 242253,
#   'time_signature': 5,
#   'name': 'The Hills',
#   'artist(s)': ['The Weeknd'],
#   'genres': [['canadian contemporary r&b', 'canadian pop', 'pop']],
#   'Category': 90},
#  {'danceability': 0.654,
#   'energy': 0.76,
#   'key': 0,
#   'loudness': -3.669,
#   'mode': 0,
#   'speechiness': 0.045,
#   'acousticness': 0.0797,
#   'instrumentalness': 0,
#   'liveness': 0.299,
#   'valence': 0.41,
#   'tempo': 99.945,
#   'duration_ms': 200787,
#   'time_signature': 4,
#   'name': 'Sorry',
#   'artist(s)': ['Justin Bieber'],
#   'genres': [['canadian pop', 'pop']],
#   'Category': 64},
#  {'danceability': 0.641,
#   'energy': 0.922,
#   'key': 2,
#   'loudness': -4.457,
#   'mode': 1,
#   'speechiness': 0.0786,
#   'acousticness': 0.0291,
#   'instrumentalness': 0,
#   'liveness': 0.0862,
#   'valence': 0.847,
#   'tempo': 146.078,
#   'duration_ms': 258343,
#   'time_signature': 4,
#   'name': "Can't Hold Us (feat. Ray Dalton)",
#   'artist(s)': ['Macklemore & Ryan Lewis',
#    'Macklemore',
#    'Ryan Lewis',
#    'Ray Dalton'],
#   'genres': [['dance pop', 'pop', 'pop rap', 'seattle hip hop'],
#    ['pop rap', 'seattle hip hop'],
#    [],
#    []],
#   'Category': 5},
#  {'danceability': 0.563,
#   'energy': 0.664,
#   'key': 9,
#   'loudness': -5.044,
#   'mode': 1,
#   'speechiness': 0.154,
#   'acousticness': 0.335,
#   'instrumentalness': 0,
#   'liveness': 0.0849,
#   'valence': 0.688,
#   'tempo': 166.928,
#   'duration_ms': 178147,
#   'time_signature': 4,
#   'name': 'good 4 u',
#   'artist(s)': ['Olivia Rodrigo'],
#   'genres': [['pop']],
#   'Category': 51},
#  {'danceability': 0.649,
#   'energy': 0.716,
#   'key': 8,
#   'loudness': -5.371,
#   'mode': 1,
#   'speechiness': 0.0349,
#   'acousticness': 0.0863,
#   'instrumentalness': 2.63e-05,
#   'liveness': 0.135,
#   'valence': 0.163,
#   'tempo': 99.988,
#   'duration_ms': 205947,
#   'time_signature': 4,
#   'name': 'Let Me Love You',
#   'artist(s)': ['DJ Snake', 'Justin Bieber'],
#   'genres': [['dance pop',
#     'edm',
#     'electronic trap',
#     'pop',
#     'pop dance',
#     'pop rap'],
#    ['canadian pop', 'pop']],
#   'Category': 102},
#  {'danceability': 0.723,
#   'energy': 0.809,
#   'key': 7,
#   'loudness': -3.081,
#   'mode': 0,
#   'speechiness': 0.0625,
#   'acousticness': 0.00346,
#   'instrumentalness': 0.00123,
#   'liveness': 0.565,
#   'valence': 0.274,
#   'tempo': 98.007,
#   'duration_ms': 176561,
#   'time_signature': 4,
#   'name': 'Lean On (feat. MØ & DJ Snake)',
#   'artist(s)': ['Major Lazer', 'MØ', 'DJ Snake'],
#   'genres': [['dance pop',
#     'edm',
#     'electro house',
#     'moombahton',
#     'pop',
#     'pop dance',
#     'pop rap',
#     'tropical house'],
#    ['dance pop',
#     'danish pop',
#     'electropop',
#     'indie poptimism',
#     'pop',
#     'tropical house'],
#    ['dance pop', 'edm', 'electronic trap', 'pop', 'pop dance', 'pop rap']],
#   'Category': 82},
#  {'danceability': 0.785,
#   'energy': 0.721,
#   'key': 8,
#   'loudness': -5.457,
#   'mode': 1,
#   'speechiness': 0.0506,
#   'acousticness': 0.0149,
#   'instrumentalness': 0.00432,
#   'liveness': 0.285,
#   'valence': 0.894,
#   'tempo': 121.962,
#   'duration_ms': 176219,
#   'time_signature': 4,
#   'name': 'Roses - Imanbek Remix',
#   'artist(s)': ['SAINt JHN', 'Imanbek'],
#   'genres': [['melodic rap', 'rap', 'slap house'],
#    ['dance pop',
#     'edm',
#     'electro house',
#     'pop dance',
#     'slap house',
#     'tropical house']],
#   'Category': 26},
#  {'danceability': 0.791,
#   'energy': 0.862,
#   'key': 9,
#   'loudness': -3.24,
#   'mode': 0,
#   'speechiness': 0.11,
#   'acousticness': 0.037,
#   'instrumentalness': 2.19e-05,
#   'liveness': 0.0814,
#   'valence': 0.592,
#   'tempo': 123.994,
#   'duration_ms': 214847,
#   'time_signature': 4,
#   'name': 'One Kiss (with Dua Lipa)',
#   'artist(s)': ['Calvin Harris', 'Dua Lipa'],
#   'genres': [['dance pop',
#     'edm',
#     'electro house',
#     'house',
#     'pop',
#     'progressive house',
#     'uk dance'],
#    ['dance pop', 'pop', 'uk pop']],
#   'Category': 71},
#  {'danceability': 0.68,
#   'energy': 0.578,
#   'key': 10,
#   'loudness': -5.804,
#   'mode': 1,
#   'speechiness': 0.04,
#   'acousticness': 0.331,
#   'instrumentalness': 0,
#   'liveness': 0.135,
#   'valence': 0.341,
#   'tempo': 145.038,
#   'duration_ms': 231267,
#   'time_signature': 4,
#   'name': 'Better Now',
#   'artist(s)': ['Post Malone'],
#   'genres': [['dfw rap', 'melodic rap', 'rap']],
#   'Category': 75},
#  {'danceability': 0.561,
#   'energy': 0.431,
#   'key': 10,
#   'loudness': -8.81,
#   'mode': 1,
#   'speechiness': 0.0578,
#   'acousticness': 0.768,
#   'instrumentalness': 1.42e-05,
#   'liveness': 0.106,
#   'valence': 0.137,
#   'tempo': 143.875,
#   'duration_ms': 242013,
#   'time_signature': 4,
#   'name': 'drivers license',
#   'artist(s)': ['Olivia Rodrigo'],
#   'genres': [['pop']],
#   'Category': 90},
#  {'danceability': 0.455,
#   'energy': 0.797,
#   'key': 10,
#   'loudness': -4.133,
#   'mode': 0,
#   'speechiness': 0.36,
#   'acousticness': 0.132,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.757,
#   'tempo': 165.717,
#   'duration_ms': 187973,
#   'time_signature': 4,
#   'name': 'Treat You Better',
#   'artist(s)': ['Shawn Mendes'],
#   'genres': [['canadian pop', 'dance pop', 'pop', 'viral pop']],
#   'Category': 14},
#  {'danceability': 0.63,
#   'energy': 0.804,
#   'key': 6,
#   'loudness': -4.183,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.215,
#   'instrumentalness': 0,
#   'liveness': 0.253,
#   'valence': 0.492,
#   'tempo': 123.146,
#   'duration_ms': 220293,
#   'time_signature': 4,
#   'name': 'Congratulations',
#   'artist(s)': ['Post Malone', 'Quavo'],
#   'genres': [['dfw rap', 'melodic rap', 'rap'],
#    ['atl hip hop',
#     'hip hop',
#     'melodic rap',
#     'rap',
#     'southern hip hop',
#     'trap']],
#   'Category': 37},
#  {'danceability': 0.589,
#   'energy': 0.651,
#   'key': 6,
#   'loudness': -5.097,
#   'mode': 1,
#   'speechiness': 0.0306,
#   'acousticness': 0.0291,
#   'instrumentalness': 3.2e-06,
#   'liveness': 0.111,
#   'valence': 0.166,
#   'tempo': 90.011,
#   'duration_ms': 212627,
#   'time_signature': 4,
#   'name': 'Faded',
#   'artist(s)': ['Alan Walker'],
#   'genres': [['electro house']],
#   'Category': 44},
#  {'danceability': 0.418,
#   'energy': 0.42,
#   'key': 0,
#   'loudness': -6.444,
#   'mode': 1,
#   'speechiness': 0.0414,
#   'acousticness': 0.588,
#   'instrumentalness': 6.39e-05,
#   'liveness': 0.11,
#   'valence': 0.184,
#   'tempo': 84.094,
#   'duration_ms': 172724,
#   'time_signature': 4,
#   'name': 'Stay With Me',
#   'artist(s)': ['Sam Smith'],
#   'genres': [['pop', 'uk pop']],
#   'Category': 11},
#  {'danceability': 0.752,
#   'energy': 0.488,
#   'key': 6,
#   'loudness': -7.05,
#   'mode': 1,
#   'speechiness': 0.0705,
#   'acousticness': 0.297,
#   'instrumentalness': 9.11e-06,
#   'liveness': 0.0936,
#   'valence': 0.533,
#   'tempo': 136.041,
#   'duration_ms': 201661,
#   'time_signature': 4,
#   'name': 'Without Me',
#   'artist(s)': ['Halsey'],
#   'genres': [['dance pop',
#     'electropop',
#     'etherpop',
#     'indie poptimism',
#     'pop']],
#   'Category': 29},
#  {'danceability': 0.534,
#   'energy': 0.868,
#   'key': 11,
#   'loudness': -5.057,
#   'mode': 1,
#   'speechiness': 0.205,
#   'acousticness': 0.187,
#   'instrumentalness': 0.0032,
#   'liveness': 0.148,
#   'valence': 0.406,
#   'tempo': 159.763,
#   'duration_ms': 208667,
#   'time_signature': 4,
#   'name': "Don't Let Me Down",
#   'artist(s)': ['The Chainsmokers', 'Daya'],
#   'genres': [['dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'tropical house'],
#    ['alt z',
#     'dance pop',
#     'edm',
#     'electropop',
#     'pop',
#     'pop dance',
#     'post-teen pop',
#     'tropical house']],
#   'Category': 47},
#  {'danceability': 0.856,
#   'energy': 0.609,
#   'key': 0,
#   'loudness': -7.223,
#   'mode': 1,
#   'speechiness': 0.0824,
#   'acousticness': 0.00801,
#   'instrumentalness': 8.15e-05,
#   'liveness': 0.0344,
#   'valence': 0.928,
#   'tempo': 114.988,
#   'duration_ms': 269667,
#   'time_signature': 4,
#   'name': 'Uptown Funk (feat. Bruno Mars)',
#   'artist(s)': ['Mark Ronson', 'Bruno Mars'],
#   'genres': [['dance pop', 'pop'], ['dance pop', 'pop']],
#   'Category': 6},
#  {'danceability': 0.664,
#   'energy': 0.714,
#   'key': 7,
#   'loudness': -6.645,
#   'mode': 0,
#   'speechiness': 0.111,
#   'acousticness': 0.0353,
#   'instrumentalness': 8.42e-06,
#   'liveness': 0.0843,
#   'valence': 0.71,
#   'tempo': 101.969,
#   'duration_ms': 197933,
#   'time_signature': 4,
#   'name': 'I Took A Pill In Ibiza - Seeb Remix',
#   'artist(s)': ['Mike Posner', 'Seeb'],
#   'genres': [['dance pop', 'edm', 'pop', 'pop rap'],
#    ['dance pop',
#     'edm',
#     'electro house',
#     'norwegian pop',
#     'pop',
#     'pop dance',
#     'pop edm',
#     'tropical house']],
#   'Category': 99},
#  {'danceability': 0.741,
#   'energy': 0.691,
#   'key': 10,
#   'loudness': -7.395,
#   'mode': 0,
#   'speechiness': 0.0672,
#   'acousticness': 0.0221,
#   'instrumentalness': 0,
#   'liveness': 0.0476,
#   'valence': 0.892,
#   'tempo': 150.087,
#   'duration_ms': 212353,
#   'time_signature': 4,
#   'name': 'INDUSTRY BABY (feat. Jack Harlow)',
#   'artist(s)': ['Lil Nas X', 'Jack Harlow'],
#   'genres': [['lgbtq+ hip hop', 'pop'],
#    ['deep underground hip hop', 'kentucky hip hop', 'pop', 'rap']],
#   'Category': 44},
#  {'danceability': 0.775,
#   'energy': 0.327,
#   'key': 11,
#   'loudness': -7.241,
#   'mode': 1,
#   'speechiness': 0.0557,
#   'acousticness': 0.841,
#   'instrumentalness': 0,
#   'liveness': 0.0821,
#   'valence': 0.595,
#   'tempo': 91.05,
#   'duration_ms': 189486,
#   'time_signature': 4,
#   'name': 'Memories',
#   'artist(s)': ['Maroon 5'],
#   'genres': [['pop']],
#   'Category': 14},
#  {'danceability': 0.681,
#   'energy': 0.372,
#   'key': 5,
#   'loudness': -8.237,
#   'mode': 1,
#   'speechiness': 0.0432,
#   'acousticness': 0.64,
#   'instrumentalness': 0,
#   'liveness': 0.169,
#   'valence': 0.476,
#   'tempo': 91.873,
#   'duration_ms': 201000,
#   'time_signature': 4,
#   'name': 'Too Good At Goodbyes',
#   'artist(s)': ['Sam Smith'],
#   'genres': [['pop', 'uk pop']],
#   'Category': 64},
#  {'danceability': 0.798,
#   'energy': 0.676,
#   'key': 6,
#   'loudness': -5.041,
#   'mode': 1,
#   'speechiness': 0.0442,
#   'acousticness': 0.0902,
#   'instrumentalness': 0,
#   'liveness': 0.0894,
#   'valence': 0.843,
#   'tempo': 101.956,
#   'duration_ms': 219947,
#   'time_signature': 4,
#   'name': "I Don't Care (with Justin Bieber)",
#   'artist(s)': ['Ed Sheeran', 'Justin Bieber'],
#   'genres': [['pop', 'uk pop'], ['canadian pop', 'pop']],
#   'Category': 37},
#  {'danceability': 0.356,
#   'energy': 0.924,
#   'key': 1,
#   'loudness': -3.74,
#   'mode': 1,
#   'speechiness': 0.0808,
#   'acousticness': 0.00101,
#   'instrumentalness': 0,
#   'liveness': 0.0953,
#   'valence': 0.232,
#   'tempo': 148.017,
#   'duration_ms': 222587,
#   'time_signature': 4,
#   'name': 'Mr. Brightside',
#   'artist(s)': ['The Killers'],
#   'genres': [['alternative rock', 'dance rock', 'permanent wave', 'rock']],
#   'Category': 4},
#  {'danceability': 0.717,
#   'energy': 0.653,
#   'key': 1,
#   'loudness': -5.634,
#   'mode': 1,
#   'speechiness': 0.0658,
#   'acousticness': 0.229,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.412,
#   'tempo': 106.966,
#   'duration_ms': 207320,
#   'time_signature': 4,
#   'name': 'thank u, next',
#   'artist(s)': ['Ariana Grande'],
#   'genres': [['dance pop', 'pop']],
#   'Category': 102},
#  {'danceability': 0.505,
#   'energy': 0.71,
#   'key': 3,
#   'loudness': -3.015,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.19,
#   'instrumentalness': 0.00025,
#   'liveness': 0.329,
#   'valence': 0.428,
#   'tempo': 89.938,
#   'duration_ms': 175200,
#   'time_signature': 4,
#   'name': 'Demons',
#   'artist(s)': ['Imagine Dragons'],
#   'genres': [['modern rock', 'rock']],
#   'Category': 34},
#  {'danceability': 0.692,
#   'energy': 0.744,
#   'key': 2,
#   'loudness': -4.565,
#   'mode': 1,
#   'speechiness': 0.257,
#   'acousticness': 0.00868,
#   'instrumentalness': 0.000423,
#   'liveness': 0.359,
#   'valence': 0.0612,
#   'tempo': 171.374,
#   'duration_ms': 326467,
#   'time_signature': 4,
#   'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#   'artist(s)': ['Eminem'],
#   'genres': [['detroit hip hop', 'hip hop', 'rap']],
#   'Category': 30},
#  {'danceability': 0.702,
#   'energy': 0.825,
#   'key': 6,
#   'loudness': -3.787,
#   'mode': 0,
#   'speechiness': 0.0601,
#   'acousticness': 0.00883,
#   'instrumentalness': 0,
#   'liveness': 0.0674,
#   'valence': 0.915,
#   'tempo': 102.977,
#   'duration_ms': 203064,
#   'time_signature': 4,
#   'name': 'Levitating (feat. DaBaby)',
#   'artist(s)': ['Dua Lipa', 'DaBaby'],
#   'genres': [['dance pop', 'pop', 'uk pop'],
#    ['north carolina hip hop', 'rap', 'trap']],
#   'Category': 29},
#  {'danceability': 0.593,
#   'energy': 0.503,
#   'key': 8,
#   'loudness': -6.725,
#   'mode': 0,
#   'speechiness': 0.22,
#   'acousticness': 0.293,
#   'instrumentalness': 0,
#   'liveness': 0.405,
#   'valence': 0.71,
#   'tempo': 178.781,
#   'duration_ms': 137704,
#   'time_signature': 4,
#   'name': 'MONTERO (Call Me By Your Name)',
#   'artist(s)': ['Lil Nas X'],
#   'genres': [['lgbtq+ hip hop', 'pop']],
#   'Category': 61},
#  {'danceability': 0.731,
#   'energy': 0.573,
#   'key': 4,
#   'loudness': -10.059,
#   'mode': 0,
#   'speechiness': 0.0544,
#   'acousticness': 0.401,
#   'instrumentalness': 5.22e-05,
#   'liveness': 0.113,
#   'valence': 0.145,
#   'tempo': 109.928,
#   'duration_ms': 205090,
#   'time_signature': 4,
#   'name': 'DÁKITI',
#   'artist(s)': ['Bad Bunny', 'Jhayco'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino'],
#    ['reggaeton', 'trap latino', 'urbano latino']],
#   'Category': 8},
#  {'danceability': 0.701,
#   'energy': 0.716,
#   'key': 7,
#   'loudness': -3.671,
#   'mode': 0,
#   'speechiness': 0.0361,
#   'acousticness': 0.174,
#   'instrumentalness': 0,
#   'liveness': 0.324,
#   'valence': 0.732,
#   'tempo': 91.007,
#   'duration_ms': 140533,
#   'time_signature': 4,
#   'name': 'Mood (feat. iann dior)',
#   'artist(s)': ['24kGoldn', 'iann dior'],
#   'genres': [['cali rap', 'pop', 'pop rap', 'rap'],
#    ['melodic rap', 'pop', 'pop rap', 'rap']],
#   'Category': 38},
#  {'danceability': 0.653,
#   'energy': 0.816,
#   'key': 2,
#   'loudness': -4.353,
#   'mode': 1,
#   'speechiness': 0.167,
#   'acousticness': 0.228,
#   'instrumentalness': 0,
#   'liveness': 0.0967,
#   'valence': 0.816,
#   'tempo': 178.085,
#   'duration_ms': 228827,
#   'time_signature': 4,
#   'name': 'Despacito - Remix',
#   'artist(s)': ['Luis Fonsi', 'Daddy Yankee', 'Justin Bieber'],
#   'genres': [['latin pop', 'puerto rican pop'],
#    ['latin hip hop', 'reggaeton', 'urbano latino'],
#    ['canadian pop', 'pop']],
#   'Category': 103},
#  {'danceability': 0.726,
#   'energy': 0.769,
#   'key': 6,
#   'loudness': -5.043,
#   'mode': 1,
#   'speechiness': 0.123,
#   'acousticness': 0.0293,
#   'instrumentalness': 0.0101,
#   'liveness': 0.104,
#   'valence': 0.733,
#   'tempo': 97.985,
#   'duration_ms': 233902,
#   'time_signature': 4,
#   'name': 'Unforgettable',
#   'artist(s)': ['French Montana', 'Swae Lee'],
#   'genres': [['gangster rap',
#     'hip hop',
#     'pop rap',
#     'rap',
#     'southern hip hop',
#     'trap'],
#    ['melodic rap', 'trap']],
#   'Category': 80},
#  {'danceability': 0.921,
#   'energy': 0.537,
#   'key': 9,
#   'loudness': -5.723,
#   'mode': 0,
#   'speechiness': 0.0804,
#   'acousticness': 0.556,
#   'instrumentalness': 0.00404,
#   'liveness': 0.102,
#   'valence': 0.711,
#   'tempo': 128.009,
#   'duration_ms': 135090,
#   'time_signature': 4,
#   'name': 'Moonlight',
#   'artist(s)': ['XXXTENTACION'],
#   'genres': [['emo rap', 'miami hip hop']],
#   'Category': 61},
#  {'danceability': 0.746,
#   'energy': 0.765,
#   'key': 6,
#   'loudness': -4.41,
#   'mode': 0,
#   'speechiness': 0.0993,
#   'acousticness': 0.0112,
#   'instrumentalness': 0,
#   'liveness': 0.0936,
#   'valence': 0.737,
#   'tempo': 114.044,
#   'duration_ms': 199054,
#   'time_signature': 4,
#   'name': 'Dynamite',
#   'artist(s)': ['BTS'],
#   'genres': [['k-pop', 'k-pop boy group']],
#   'Category': 106},
#  {'danceability': 0.548,
#   'energy': 0.532,
#   'key': 5,
#   'loudness': -7.596,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.186,
#   'instrumentalness': 0.000263,
#   'liveness': 0.217,
#   'valence': 0.405,
#   'tempo': 85.03,
#   'duration_ms': 272394,
#   'time_signature': 4,
#   'name': 'Do I Wanna Know?',
#   'artist(s)': ['Arctic Monkeys'],
#   'genres': [['garage rock',
#     'modern rock',
#     'permanent wave',
#     'rock',
#     'sheffield indie']],
#   'Category': 17},
#  {'danceability': 0.896,
#   'energy': 0.586,
#   'key': 10,
#   'loudness': -6.687,
#   'mode': 0,
#   'speechiness': 0.0559,
#   'acousticness': 0.104,
#   'instrumentalness': 0,
#   'liveness': 0.79,
#   'valence': 0.642,
#   'tempo': 116.971,
#   'duration_ms': 196653,
#   'time_signature': 4,
#   'name': 'The Box',
#   'artist(s)': ['Roddy Ricch'],
#   'genres': [['melodic rap', 'rap', 'trap']],
#   'Category': 49},
#  {'danceability': 0.372,
#   'energy': 0.865,
#   'key': 2,
#   'loudness': -4.918,
#   'mode': 1,
#   'speechiness': 0.0381,
#   'acousticness': 0.000453,
#   'instrumentalness': 0,
#   'liveness': 0.234,
#   'valence': 0.478,
#   'tempo': 174.53,
#   'duration_ms': 258733,
#   'time_signature': 4,
#   'name': 'Wonderwall - Remastered',
#   'artist(s)': ['Oasis'],
#   'genres': [['beatlesque',
#     'britpop',
#     'madchester',
#     'permanent wave',
#     'pop rock',
#     'rock']],
#   'Category': 5},
#  {'danceability': 0.853,
#   'energy': 0.56,
#   'key': 1,
#   'loudness': -4.961,
#   'mode': 1,
#   'speechiness': 0.0406,
#   'acousticness': 0.013,
#   'instrumentalness': 0,
#   'liveness': 0.0944,
#   'valence': 0.86,
#   'tempo': 134.066,
#   'duration_ms': 206693,
#   'time_signature': 4,
#   'name': "That's What I Like",
#   'artist(s)': ['Bruno Mars'],
#   'genres': [['dance pop', 'pop']],
#   'Category': 102},
#  {'danceability': 0.628,
#   'energy': 0.698,
#   'key': 6,
#   'loudness': -5.608,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.0472,
#   'instrumentalness': 0.00143,
#   'liveness': 0.0907,
#   'valence': 0.732,
#   'tempo': 89.976,
#   'duration_ms': 211667,
#   'time_signature': 4,
#   'name': 'Cheap Thrills',
#   'artist(s)': ['Sia'],
#   'genres': [['australian dance', 'australian pop', 'pop']],
#   'Category': 20},
#  {'danceability': 0.866,
#   'energy': 0.813,
#   'key': 11,
#   'loudness': -4.063,
#   'mode': 0,
#   'speechiness': 0.0554,
#   'acousticness': 0.38,
#   'instrumentalness': 0,
#   'liveness': 0.0779,
#   'valence': 0.969,
#   'tempo': 121.998,
#   'duration_ms': 199440,
#   'time_signature': 4,
#   'name': "There's Nothing Holdin' Me Back",
#   'artist(s)': ['Shawn Mendes'],
#   'genres': [['canadian pop', 'dance pop', 'pop', 'viral pop']],
#   'Category': 106},
#  {'danceability': 0.548,
#   'energy': 0.847,
#   'key': 1,
#   'loudness': -3.237,
#   'mode': 1,
#   'speechiness': 0.186,
#   'acousticness': 0.0622,
#   'instrumentalness': 0,
#   'liveness': 0.0816,
#   'valence': 0.1,
#   'tempo': 171.447,
#   'duration_ms': 297787,
#   'time_signature': 4,
#   'name': 'Till I Collapse',
#   'artist(s)': ['Eminem', 'Nate Dogg'],
#   'genres': [['detroit hip hop', 'hip hop', 'rap'],
#    ['g funk', 'gangster rap', 'hip hop', 'pop rap', 'rap', 'west coast rap']],
#   'Category': 10},
#  {'danceability': 0.746,
#   'energy': 0.754,
#   'key': 1,
#   'loudness': -6.684,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'acousticness': 0.0152,
#   'instrumentalness': 0,
#   'liveness': 0.0486,
#   'valence': 0.746,
#   'tempo': 149.882,
#   'duration_ms': 206880,
#   'time_signature': 4,
#   'name': 'Stitches',
#   'artist(s)': ['Shawn Mendes'],
#   'genres': [['canadian pop', 'dance pop', 'pop', 'viral pop']],
#   'Category': 102},
#  {'danceability': 0.692,
#   'energy': 0.521,
#   'key': 10,
#   'loudness': -8.465,
#   'mode': 0,
#   'speechiness': 0.33,
#   'acousticness': 0.301,
#   'instrumentalness': 0,
#   'liveness': 0.0565,
#   'valence': 0.463,
#   'tempo': 100.45,
#   'duration_ms': 292987,
#   'time_signature': 4,
#   'name': 'No Role Modelz',
#   'artist(s)': ['J. Cole'],
#   'genres': [['conscious hip hop',
#     'hip hop',
#     'north carolina hip hop',
#     'rap']],
#   'Category': 77},
#  {'danceability': 0.689,
#   'energy': 0.481,
#   'key': 10,
#   'loudness': -7.503,
#   'mode': 1,
#   'speechiness': 0.0815,
#   'acousticness': 0.369,
#   'instrumentalness': 1.03e-06,
#   'liveness': 0.0649,
#   'valence': 0.283,
#   'tempo': 80.025,
#   'duration_ms': 229526,
#   'time_signature': 4,
#   'name': 'See You Again (feat. Charlie Puth)',
#   'artist(s)': ['Wiz Khalifa', 'Charlie Puth'],
#   'genres': [['dance pop',
#     'hip hop',
#     'pittsburgh rap',
#     'pop rap',
#     'rap',
#     'southern hip hop',
#     'trap'],
#    ['dance pop', 'pop', 'viral pop']],
#   'Category': 36},
#  {'danceability': 0.752,
#   'energy': 0.505,
#   'key': 9,
#   'loudness': -7.621,
#   'mode': 1,
#   'speechiness': 0.253,
#   'acousticness': 0.535,
#   'instrumentalness': 2.55e-06,
#   'liveness': 0.104,
#   'valence': 0.419,
#   'tempo': 91.97,
#   'duration_ms': 197437,
#   'time_signature': 4,
#   'name': 'I Like Me Better',
#   'artist(s)': ['Lauv'],
#   'genres': [['dance pop', 'electropop', 'pop']],
#   'Category': 3},
#  {'danceability': 0.765,
#   'energy': 0.473,
#   'key': 10,
#   'loudness': -5.829,
#   'mode': 1,
#   'speechiness': 0.0514,
#   'acousticness': 0.287,
#   'instrumentalness': 0,
#   'liveness': 0.391,
#   'valence': 0.34,
#   'tempo': 119.992,
#   'duration_ms': 237300,
#   'time_signature': 4,
#   'name': '7 Years',
#   'artist(s)': ['Lukas Graham'],
#   'genres': [['danish pop', 'pop', 'scandipop']],
#   'Category': 105},
#  {'danceability': 0.703,
#   'energy': 0.444,
#   'key': 11,
#   'loudness': -9.331,
#   'mode': 1,
#   'speechiness': 0.0417,
#   'acousticness': 0.559,
#   'instrumentalness': 0,
#   'liveness': 0.0973,
#   'valence': 0.712,
#   'tempo': 150.96,
#   'duration_ms': 242947,
#   'time_signature': 4,
#   'name': "I'm Yours",
#   'artist(s)': ['Jason Mraz'],
#   'genres': [['acoustic pop', 'neo mellow', 'pop', 'pop rock']],
#   'Category': 28},
#  {'danceability': 0.502,
#   'energy': 0.912,
#   'key': 1,
#   'loudness': -4.556,
#   'mode': 1,
#   'speechiness': 0.0564,
#   'acousticness': 2.55e-05,
#   'instrumentalness': 0.000173,
#   'liveness': 0.106,
#   'valence': 0.72,
#   'tempo': 116.761,
#   'duration_ms': 301920,
#   'time_signature': 4,
#   'name': 'Smells Like Teen Spirit',
#   'artist(s)': ['Nirvana'],
#   'genres': [['alternative rock', 'grunge', 'permanent wave', 'rock']],
#   'Category': 84},
#  {'danceability': 0.851,
#   'energy': 0.541,
#   'key': 0,
#   'loudness': -6.825,
#   'mode': 1,
#   'speechiness': 0.0505,
#   'acousticness': 0.568,
#   'instrumentalness': 0,
#   'liveness': 0.13,
#   'valence': 0.448,
#   'tempo': 124.959,
#   'duration_ms': 235545,
#   'time_signature': 4,
#   'name': 'Girls Like You (feat. Cardi B) - Cardi B Version',
#   'artist(s)': ['Maroon 5', 'Cardi B'],
#   'genres': [['pop'], ['dance pop', 'pop', 'rap']],
#   'Category': 72},
#  {'danceability': 0.655,
#   'energy': 0.797,
#   'key': 2,
#   'loudness': -4.787,
#   'mode': 1,
#   'speechiness': 0.153,
#   'acousticness': 0.198,
#   'instrumentalness': 0,
#   'liveness': 0.067,
#   'valence': 0.839,
#   'tempo': 177.928,
#   'duration_ms': 229360,
#   'time_signature': 4,
#   'name': 'Despacito',
#   'artist(s)': ['Luis Fonsi', 'Daddy Yankee'],
#   'genres': [['latin pop', 'puerto rican pop'],
#    ['latin hip hop', 'reggaeton', 'urbano latino']],
#   'Category': 36},
#  {'danceability': 0.748,
#   'energy': 0.788,
#   'key': 1,
#   'loudness': -7.055,
#   'mode': 1,
#   'speechiness': 0.0334,
#   'acousticness': 0.0591,
#   'instrumentalness': 0,
#   'liveness': 0.0863,
#   'valence': 0.884,
#   'tempo': 120.076,
#   'duration_ms': 235493,
#   'time_signature': 4,
#   'name': 'Sugar',
#   'artist(s)': ['Maroon 5'],
#   'genres': [['pop']],
#   'Category': 72},
#  {'danceability': 0.746,
#   'energy': 0.69,
#   'key': 11,
#   'loudness': -7.956,
#   'mode': 1,
#   'speechiness': 0.164,
#   'acousticness': 0.247,
#   'instrumentalness': 0,
#   'liveness': 0.101,
#   'valence': 0.497,
#   'tempo': 89.977,
#   'duration_ms': 181733,
#   'time_signature': 4,
#   'name': 'ROCKSTAR (feat. Roddy Ricch)',
#   'artist(s)': ['DaBaby', 'Roddy Ricch'],
#   'genres': [['north carolina hip hop', 'rap', 'trap'],
#    ['melodic rap', 'rap', 'trap']],
#   'Category': 83},
#  {'danceability': 0.596,
#   'energy': 0.854,
#   'key': 7,
#   'loudness': -5.114,
#   'mode': 0,
#   'speechiness': 0.463,
#   'acousticness': 0.0169,
#   'instrumentalness': 0,
#   'liveness': 0.124,
#   'valence': 0.152,
#   'tempo': 120.274,
#   'duration_ms': 203418,
#   'time_signature': 4,
#   'name': 'Youngblood',
#   'artist(s)': ['5 Seconds of Summer'],
#   'genres': [['boy band', 'dance pop', 'pop', 'post-teen pop']],
#   'Category': 29},
#  {'danceability': 0.669,
#   'energy': 0.832,
#   'key': 0,
#   'loudness': -5.721,
#   'mode': 1,
#   'speechiness': 0.0682,
#   'acousticness': 0.0106,
#   'instrumentalness': 0,
#   'liveness': 0.0968,
#   'valence': 0.7,
#   'tempo': 113.035,
#   'duration_ms': 237547,
#   'time_signature': 4,
#   'name': 'CAN\'T STOP THE FEELING! (from DreamWorks Animation\'s "TROLLS")',
#   'artist(s)': ['Justin Timberlake'],
#   'genres': [['dance pop', 'pop']],
#   'Category': 105},
#  {'danceability': 0.732,
#   'energy': 0.396,
#   'key': 4,
#   'loudness': -9.348,
#   'mode': 0,
#   'speechiness': 0.0286,
#   'acousticness': 0.0841,
#   'instrumentalness': 3.58e-05,
#   'liveness': 0.105,
#   'valence': 0.548,
#   'tempo': 90.024,
#   'duration_ms': 195920,
#   'time_signature': 4,
#   'name': 'Heathens',
#   'artist(s)': ['Twenty One Pilots'],
#   'genres': [['modern rock', 'rock']],
#   'Category': 94},
#  {'danceability': 0.367,
#   'energy': 0.111,
#   'key': 4,
#   'loudness': -14.084,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.978,
#   'instrumentalness': 3.97e-05,
#   'liveness': 0.0897,
#   'valence': 0.198,
#   'tempo': 82.642,
#   'duration_ms': 196077,
#   'time_signature': 4,
#   'name': "when the party's over",
#   'artist(s)': ['Billie Eilish'],
#   'genres': [['art pop', 'electropop', 'pop']],
#   'Category': 94},
#  {'danceability': 0.448,
#   'energy': 0.784,
#   'key': 9,
#   'loudness': -3.686,
#   'mode': 1,
#   'speechiness': 0.0627,
#   'acousticness': 0.106,
#   'instrumentalness': 0.000108,
#   'liveness': 0.668,
#   'valence': 0.236,
#   'tempo': 136.245,
#   'duration_ms': 186813,
#   'time_signature': 4,
#   'name': 'Radioactive',
#   'artist(s)': ['Imagine Dragons'],
#   'genres': [['modern rock', 'rock']],
#   'Category': 87},
#  {'danceability': 0.556,
#   'energy': 0.538,
#   'key': 8,
#   'loudness': -5.408,
#   'mode': 0,
#   'speechiness': 0.0382,
#   'acousticness': 0.0689,
#   'instrumentalness': 0,
#   'liveness': 0.196,
#   'valence': 0.291,
#   'tempo': 143.95,
#   'duration_ms': 223347,
#   'time_signature': 4,
#   'name': 'I Fall Apart',
#   'artist(s)': ['Post Malone'],
#   'genres': [['dfw rap', 'melodic rap', 'rap']],
#   'Category': 66},
#  {'danceability': 0.728,
#   'energy': 0.563,
#   'key': 1,
#   'loudness': -8.053,
#   'mode': 0,
#   'speechiness': 0.134,
#   'acousticness': 0.621,
#   'instrumentalness': 0,
#   'liveness': 0.179,
#   'valence': 0.352,
#   'tempo': 100.017,
#   'duration_ms': 217707,
#   'time_signature': 4,
#   'name': "We Don't Talk Anymore (feat. Selena Gomez)",
#   'artist(s)': ['Charlie Puth', 'Selena Gomez'],
#   'genres': [['dance pop', 'pop', 'viral pop'],
#    ['dance pop', 'pop', 'post-teen pop']],
#   'Category': 101},
#  {'danceability': 0.563,
#   'energy': 0.865,
#   'key': 5,
#   'loudness': -5.277,
#   'mode': 1,
#   'speechiness': 0.16,
#   'acousticness': 0.0472,
#   'instrumentalness': 0.000191,
#   'liveness': 0.77,
#   'valence': 0.601,
#   'tempo': 156.271,
#   'duration_ms': 209413,
#   'time_signature': 4,
#   'name': "Don't Stop Me Now - Remastered 2011",
#   'artist(s)': ['Queen'],
#   'genres': [['classic rock', 'glam rock', 'rock']],
#   'Category': 47},
#  {'danceability': 0.775,
#   'energy': 0.613,
#   'key': 3,
#   'loudness': -4.586,
#   'mode': 0,
#   'speechiness': 0.0542,
#   'acousticness': 0.109,
#   'instrumentalness': 2.33e-05,
#   'liveness': 0.134,
#   'valence': 0.797,
#   'tempo': 100.066,
#   'duration_ms': 208787,
#   'time_signature': 4,
#   'name': 'Attention',
#   'artist(s)': ['Charlie Puth'],
#   'genres': [['dance pop', 'pop', 'viral pop']],
#   'Category': 47},
#  {'danceability': 0.5,
#   'energy': 0.748,
#   'key': 4,
#   'loudness': -9.072,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.127,
#   'instrumentalness': 0,
#   'liveness': 0.447,
#   'valence': 0.514,
#   'tempo': 118.852,
#   'duration_ms': 250987,
#   'time_signature': 4,
# ...
#   'energy': 0.939,
#   'key': 8,
#   'loudness': -11.823,
#   'mode': 1,
#   'speechiness': 0.0376,
#   'acousticness': 0.115,
#   'instrumentalness': 3.79e-05,
#   'liveness': 0.108,
#   'valence': 0.914,
#   'tempo': 113.309,
#   'duration_ms': 213573,
#   'time_signature': 4,
#   'name': 'Never Gonna Give You Up',
#   'artist(s)': ['Rick Astley'],
#   'genres': [['europop',
#     'new romantic',
#     'new wave',
#     'new wave pop',
#     'soft rock',
#     'sophisti-pop',
#     'synthpop']],
#   'Category': 86},
#  {'danceability': 0.768,
#   'energy': 0.852,
#   'key': 4,
#   'loudness': -6.215,
#   'mode': 1,
#   'speechiness': 0.038,
#   'acousticness': 0.214,
#   'instrumentalness': 7.36e-05,
#   'liveness': 0.0723,
#   'valence': 0.867,
#   'tempo': 128.373,
#   'duration_ms': 271240,
#   'time_signature': 4,
#   'name': "I Was Made For Lovin' You",
#   'artist(s)': ['KISS'],
#   'genres': [['album rock', 'glam rock', 'hard rock', 'metal', 'rock']],
#   'Category': 17},
#  {'danceability': 0.574,
#   'energy': 0.628,
#   'key': 2,
#   'loudness': -8.815,
#   'mode': 0,
#   'speechiness': 0.036,
#   'acousticness': 0.13,
#   'instrumentalness': 0,
#   'liveness': 0.271,
#   'valence': 0.803,
#   'tempo': 153.119,
#   'duration_ms': 300107,
#   'time_signature': 4,
#   'name': 'Careless Whisper',
#   'artist(s)': ['George Michael'],
#   'genres': [['dance pop', 'new wave pop']],
#   'Category': 84},
#  {'danceability': 0.689,
#   'energy': 0.808,
#   'key': 0,
#   'loudness': -3.28,
#   'mode': 1,
#   'speechiness': 0.0572,
#   'acousticness': 0.0721,
#   'instrumentalness': 0,
#   'liveness': 0.241,
#   'valence': 0.674,
#   'tempo': 91.012,
#   'duration_ms': 207680,
#   'time_signature': 4,
#   'name': 'SUBEME LA RADIO (feat. Descemer Bueno & Zion & Lennox)',
#   'artist(s)': ['Enrique Iglesias', 'Descemer Bueno', 'Zion & Lennox'],
#   'genres': [['latin pop', 'mexican pop'],
#    [],
#    ['latin hip hop', 'reggaeton', 'urbano latino']],
#   'Category': 46},
#  {'danceability': 0.573,
#   'energy': 0.711,
#   'key': 1,
#   'loudness': -6.268,
#   'mode': 0,
#   'speechiness': 0.0406,
#   'acousticness': 0.0114,
#   'instrumentalness': 0,
#   'liveness': 0.328,
#   'valence': 0.47,
#   'tempo': 105.006,
#   'duration_ms': 226198,
#   'time_signature': 4,
#   'name': 'My Universe',
#   'artist(s)': ['Coldplay', 'BTS'],
#   'genres': [['permanent wave', 'pop'], ['k-pop', 'k-pop boy group']],
#   'Category': 12},
#  {'danceability': 0.652,
#   'energy': 0.812,
#   'key': 3,
#   'loudness': -3.797,
#   'mode': 0,
#   'speechiness': 0.0409,
#   'acousticness': 0.00125,
#   'instrumentalness': 3.01e-05,
#   'liveness': 0.667,
#   'valence': 0.72,
#   'tempo': 126.023,
#   'duration_ms': 230733,
#   'time_signature': 4,
#   'name': 'Last Friday Night (T.G.I.F.)',
#   'artist(s)': ['Katy Perry'],
#   'genres': [['dance pop', 'pop']],
#   'Category': 75},
#  {'danceability': 0.737,
#   'energy': 0.846,
#   'key': 1,
#   'loudness': -4.51,
#   'mode': 0,
#   'speechiness': 0.22,
#   'acousticness': 0.00614,
#   'instrumentalness': 0,
#   'liveness': 0.0486,
#   'valence': 0.546,
#   'tempo': 87.981,
#   'duration_ms': 143901,
#   'time_signature': 4,
#   'name': 'THATS WHAT I WANT',
#   'artist(s)': ['Lil Nas X'],
#   'genres': [['lgbtq+ hip hop', 'pop']],
#   'Category': 38},
#  {'danceability': 0.532,
#   'energy': 0.767,
#   'key': 7,
#   'loudness': -5.509,
#   'mode': 1,
#   'speechiness': 0.0574,
#   'acousticness': 0.00287,
#   'instrumentalness': 0.000513,
#   'liveness': 0.39,
#   'valence': 0.755,
#   'tempo': 127.361,
#   'duration_ms': 210173,
#   'time_signature': 4,
#   'name': 'You Shook Me All Night Long',
#   'artist(s)': ['AC/DC'],
#   'genres': [['australian rock', 'hard rock', 'rock']],
#   'Category': 33},
#  {'danceability': 0.653,
#   'energy': 0.524,
#   'key': 11,
#   'loudness': -9.016,
#   'mode': 0,
#   'speechiness': 0.0502,
#   'acousticness': 0.112,
#   'instrumentalness': 0,
#   'liveness': 0.203,
#   'valence': 0.553,
#   'tempo': 83.97,
#   'duration_ms': 160191,
#   'time_signature': 4,
#   'name': 'telepatía',
#   'artist(s)': ['Kali Uchis'],
#   'genres': [['colombian pop', 'pop']],
#   'Category': 40},
#  {'danceability': 0.812,
#   'energy': 0.761,
#   'key': 11,
#   'loudness': -5.222,
#   'mode': 1,
#   'speechiness': 0.0812,
#   'acousticness': 0.0465,
#   'instrumentalness': 0.000135,
#   'liveness': 0.0601,
#   'valence': 0.344,
#   'tempo': 130.032,
#   'duration_ms': 182956,
#   'time_signature': 4,
#   'name': 'How You Like That',
#   'artist(s)': ['BLACKPINK'],
#   'genres': [['k-pop', 'k-pop girl group']],
#   'Category': 68},
#  {'danceability': 0.688,
#   'energy': 0.835,
#   'key': 8,
#   'loudness': -4.162,
#   'mode': 1,
#   'speechiness': 0.0911,
#   'acousticness': 0.0583,
#   'instrumentalness': 2.87e-06,
#   'liveness': 0.0795,
#   'valence': 0.88,
#   'tempo': 84.858,
#   'duration_ms': 230493,
#   'time_signature': 4,
#   'name': 'Remember the Name (feat. Styles of Beyond)',
#   'artist(s)': ['Fort Minor', 'Styles Of Beyond'],
#   'genres': [['pop rap', 'rap rock'], ['cali rap', 'rap rock']],
#   'Category': 76},
#  {'danceability': 0.704,
#   'energy': 0.797,
#   'key': 0,
#   'loudness': -5.927,
#   'mode': 1,
#   'speechiness': 0.0475,
#   'acousticness': 0.0826,
#   'instrumentalness': 0.000745,
#   'liveness': 0.0546,
#   'valence': 0.825,
#   'tempo': 139.994,
#   'duration_ms': 148486,
#   'time_signature': 4,
#   'name': "I Ain't Worried",
#   'artist(s)': ['OneRepublic'],
#   'genres': [['piano rock', 'pop']],
#   'Category': 38},
#  {'danceability': 0.464,
#   'energy': 0.417,
#   'key': 0,
#   'loudness': -9.345,
#   'mode': 0,
#   'speechiness': 0.0256,
#   'acousticness': 0.136,
#   'instrumentalness': 0.022,
#   'liveness': 0.0974,
#   'valence': 0.479,
#   'tempo': 67.528,
#   'duration_ms': 183956,
#   'time_signature': 4,
#   'name': 'I Wanna Be Yours',
#   'artist(s)': ['Arctic Monkeys'],
#   'genres': [['garage rock',
#     'modern rock',
#     'permanent wave',
#     'rock',
#     'sheffield indie']],
#   'Category': 68},
#  {'danceability': 0.288,
#   'energy': 0.758,
#   'key': 6,
#   'loudness': -5.692,
#   'mode': 0,
#   'speechiness': 0.0371,
#   'acousticness': 0.00616,
#   'instrumentalness': 0,
#   'liveness': 0.303,
#   'valence': 0.619,
#   'tempo': 97.094,
#   'duration_ms': 201726,
#   'time_signature': 4,
#   'name': 'R U Mine?',
#   'artist(s)': ['Arctic Monkeys'],
#   'genres': [['garage rock',
#     'modern rock',
#     'permanent wave',
#     'rock',
#     'sheffield indie']],
#   'Category': 29},
#  {'danceability': 0.646,
#   'energy': 0.813,
#   'key': 6,
#   'loudness': -5.29,
#   'mode': 0,
#   'speechiness': 0.0288,
#   'acousticness': 0.00178,
#   'instrumentalness': 2.26e-05,
#   'liveness': 0.144,
#   'valence': 0.821,
#   'tempo': 112.115,
#   'duration_ms': 173493,
#   'time_signature': 4,
#   'name': 'Fluorescent Adolescent',
#   'artist(s)': ['Arctic Monkeys'],
#   'genres': [['garage rock',
#     'modern rock',
#     'permanent wave',
#     'rock',
#     'sheffield indie']],
#   'Category': 42},
#  {'danceability': 0.431,
#   'energy': 0.723,
#   'key': 8,
#   'loudness': -5.887,
#   'mode': 1,
#   'speechiness': 0.0568,
#   'acousticness': 0.145,
#   'instrumentalness': 0,
#   'liveness': 0.374,
#   'valence': 0.19,
#   'tempo': 130.141,
#   'duration_ms': 267360,
#   'time_signature': 4,
#   'name': 'Total Eclipse of the Heart',
#   'artist(s)': ['Bonnie Tyler'],
#   'genres': [['europop', 'new wave pop', 'soft rock']],
#   'Category': 50},
#  {'danceability': 0.531,
#   'energy': 0.481,
#   'key': 4,
#   'loudness': -11.709,
#   'mode': 0,
#   'speechiness': 0.06,
#   'acousticness': 0.699,
#   'instrumentalness': 0,
#   'liveness': 0.0842,
#   'valence': 0.491,
#   'tempo': 138.45,
#   'duration_ms': 516893,
#   'time_signature': 4,
#   'name': 'American Pie',
#   'artist(s)': ['Don McLean'],
#   'genres': [['adult standards',
#     'classic rock',
#     'folk',
#     'folk rock',
#     'mellow gold',
#     'singer-songwriter',
#     'soft rock']],
#   'Category': 74},
#  {'danceability': 0.492,
#   'energy': 0.81,
#   'key': 7,
#   'loudness': -5.315,
#   'mode': 1,
#   'speechiness': 0.0847,
#   'acousticness': 0.0416,
#   'instrumentalness': 0.00379,
#   'liveness': 0.117,
#   'valence': 0.245,
#   'tempo': 149.954,
#   'duration_ms': 251840,
#   'time_signature': 4,
#   'name': 'Dog Days Are Over',
#   'artist(s)': ['Florence + The Machine'],
#   'genres': [['baroque pop', 'pop', 'uk alternative pop']],
#   'Category': 98},
#  {'danceability': 0.747,
#   'energy': 0.716,
#   'key': 11,
#   'loudness': -2.457,
#   'mode': 0,
#   'speechiness': 0.075,
#   'acousticness': 0.135,
#   'instrumentalness': 0,
#   'liveness': 0.251,
#   'valence': 0.751,
#   'tempo': 125.008,
#   'duration_ms': 210627,
#   'time_signature': 4,
#   'name': 'Starships',
#   'artist(s)': ['Nicki Minaj'],
#   'genres': [['dance pop', 'hip pop', 'pop', 'queens hip hop', 'rap']],
#   'Category': 62},
#  {'danceability': 0.569,
#   'energy': 0.83,
#   'key': 9,
#   'loudness': -4.106,
#   'mode': 0,
#   'speechiness': 0.14,
#   'acousticness': 0.0807,
#   'instrumentalness': 0,
#   'liveness': 0.114,
#   'valence': 0.609,
#   'tempo': 170.094,
#   'duration_ms': 186635,
#   'time_signature': 4,
#   'name': 'I Write Sins Not Tragedies',
#   'artist(s)': ['Panic! At The Disco'],
#   'genres': [['modern rock']],
#   'Category': 87},
#  {'danceability': 0.657,
#   'energy': 0.56,
#   'key': 6,
#   'loudness': -9.049,
#   'mode': 0,
#   'speechiness': 0.0467,
#   'acousticness': 0.498,
#   'instrumentalness': 0,
#   'liveness': 0.0794,
#   'valence': 0.854,
#   'tempo': 161.993,
#   'duration_ms': 182947,
#   'time_signature': 4,
#   'name': 'Mistletoe',
#   'artist(s)': ['Justin Bieber'],
#   'genres': [['canadian pop', 'pop']],
#   'Category': 68},
#  {'danceability': 0.65,
#   'energy': 0.715,
#   'key': 5,
#   'loudness': -5.198,
#   'mode': 0,
#   'speechiness': 0.253,
#   'acousticness': 0.0993,
#   'instrumentalness': 0.000291,
#   'liveness': 0.126,
#   'valence': 0.187,
#   'tempo': 106.672,
#   'duration_ms': 243717,
#   'time_signature': 4,
#   'name': 'Tití Me Preguntó',
#   'artist(s)': ['Bad Bunny'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino']],
#   'Category': 28},
#  {'danceability': 0.801,
#   'energy': 0.475,
#   'key': 7,
#   'loudness': -8.797,
#   'mode': 0,
#   'speechiness': 0.0516,
#   'acousticness': 0.141,
#   'instrumentalness': 1.73e-05,
#   'liveness': 0.0639,
#   'valence': 0.234,
#   'tempo': 98.047,
#   'duration_ms': 213061,
#   'time_signature': 4,
#   'name': 'Efecto',
#   'artist(s)': ['Bad Bunny'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino']],
#   'Category': 86},
#  {'danceability': 0.647,
#   'energy': 0.686,
#   'key': 3,
#   'loudness': -5.745,
#   'mode': 0,
#   'speechiness': 0.0413,
#   'acousticness': 0.08,
#   'instrumentalness': 1.34e-06,
#   'liveness': 0.528,
#   'valence': 0.268,
#   'tempo': 79.928,
#   'duration_ms': 258299,
#   'time_signature': 4,
#   'name': 'Ojitos Lindos',
#   'artist(s)': ['Bad Bunny', 'Bomba Estéreo'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino'],
#    ['cumbia', 'latin alternative', 'pop electronico', 'tropical alternativo']],
#   'Category': 5},
#  {'danceability': 0.804,
#   'energy': 0.674,
#   'key': 5,
#   'loudness': -5.453,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'acousticness': 0.294,
#   'instrumentalness': 1.18e-06,
#   'liveness': 0.115,
#   'valence': 0.292,
#   'tempo': 99.968,
#   'duration_ms': 245940,
#   'time_signature': 4,
#   'name': 'Moscow Mule',
#   'artist(s)': ['Bad Bunny'],
#   'genres': [['reggaeton', 'trap latino', 'urbano latino']],
#   'Category': 60},
#  {'danceability': 0.634,
#   'energy': 0.886,
#   'key': 2,
#   'loudness': -3.466,
#   'mode': 1,
#   'speechiness': 0.0517,
#   'acousticness': 0.0291,
#   'instrumentalness': 0,
#   'liveness': 0.342,
#   'valence': 0.922,
#   'tempo': 161.933,
#   'duration_ms': 168253,
#   'time_signature': 4,
#   'name': 'The Middle',
#   'artist(s)': ['Jimmy Eat World'],
#   'genres': [['emo',
#     'modern power pop',
#     'modern rock',
#     'neo mellow',
#     'pop punk',
#     'pop rock',
#     'rock']],
#   'Category': 9},
#  {'danceability': 0.55,
#   'energy': 0.917,
#   'key': 0,
#   'loudness': -3.159,
#   'mode': 1,
#   'speechiness': 0.0638,
#   'acousticness': 0.00428,
#   'instrumentalness': 0,
#   'liveness': 0.197,
#   'valence': 0.601,
#   'tempo': 126.115,
#   'duration_ms': 177827,
#   'time_signature': 4,
#   'name': "You're Gonna Go Far, Kid",
#   'artist(s)': ['The Offspring'],
#   'genres': [['alternative metal',
#     'permanent wave',
#     'punk',
#     'rock',
#     'skate punk',
#     'socal pop punk']],
#   'Category': 51},
#  {'danceability': 0.44,
#   'energy': 0.317,
#   'key': 8,
#   'loudness': -9.258,
#   'mode': 1,
#   'speechiness': 0.0531,
#   'acousticness': 0.891,
#   'instrumentalness': 4.78e-06,
#   'liveness': 0.141,
#   'valence': 0.268,
#   'tempo': 169.914,
#   'duration_ms': 233456,
#   'time_signature': 3,
#   'name': 'Glimpse of Us',
#   'artist(s)': ['Joji'],
#   'genres': [['viral pop']],
#   'Category': 21},
#  {'danceability': 0.729,
#   'energy': 0.65,
#   'key': 5,
#   'loudness': -3.539,
#   'mode': 1,
#   'speechiness': 0.0313,
#   'acousticness': 0.0702,
#   'instrumentalness': 6.69e-05,
#   'liveness': 0.0829,
#   'valence': 0.347,
#   'tempo': 110.02,
#   'duration_ms': 209160,
#   'time_signature': 4,
#   'name': 'Habits (Stay High)',
#   'artist(s)': ['Tove Lo'],
#   'genres': [['dance pop',
#     'electropop',
#     'metropopolis',
#     'pop',
#     'swedish electropop',
#     'swedish pop',
#     'swedish synthpop']],
#   'Category': 47},
#  {'danceability': 0.504,
#   'energy': 0.904,
#   'key': 6,
#   'loudness': -6.863,
#   'mode': 1,
#   'speechiness': 0.179,
#   'acousticness': 0.356,
#   'instrumentalness': 0.121,
#   'liveness': 0.14,
#   'valence': 0.772,
#   'tempo': 176.808,
#   'duration_ms': 183440,
#   'time_signature': 4,
#   'name': "I'm Still Standing",
#   'artist(s)': ['Elton John'],
#   'genres': [['glam rock', 'mellow gold', 'piano rock']],
#   'Category': 68},
#  {'danceability': 0.554,
#   'energy': 0.315,
#   'key': 3,
#   'loudness': -11.028,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.828,
#   'instrumentalness': 5.53e-06,
#   'liveness': 0.101,
#   'valence': 0.325,
#   'tempo': 128.157,
#   'duration_ms': 241787,
#   'time_signature': 4,
#   'name': 'Your Song',
#   'artist(s)': ['Elton John'],
#   'genres': [['glam rock', 'mellow gold', 'piano rock']],
#   'Category': 90},
#  {'danceability': 0.414,
#   'energy': 0.428,
#   'key': 0,
#   'loudness': -11.097,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.382,
#   'instrumentalness': 0.000243,
#   'liveness': 0.148,
#   'valence': 0.282,
#   'tempo': 145.075,
#   'duration_ms': 377093,
#   'time_signature': 4,
#   'name': 'Tiny Dancer',
#   'artist(s)': ['Elton John'],
#   'genres': [['glam rock', 'mellow gold', 'piano rock']],
#   'Category': 55},
#  {'danceability': 0.749,
#   'energy': 0.491,
#   'key': 10,
#   'loudness': -9.655,
#   'mode': 1,
#   'speechiness': 0.0403,
#   'acousticness': 0.02,
#   'instrumentalness': 0.00899,
#   'liveness': 0.159,
#   'valence': 0.536,
#   'tempo': 119.528,
#   'duration_ms': 292613,
#   'time_signature': 4,
#   'name': 'Gimme! Gimme! Gimme! (A Man After Midnight)',
#   'artist(s)': ['ABBA'],
#   'genres': [['europop', 'swedish pop']],
#   'Category': 77},
#  {'danceability': 0.561,
#   'energy': 0.965,
#   'key': 7,
#   'loudness': -3.673,
#   'mode': 0,
#   'speechiness': 0.0343,
#   'acousticness': 0.00383,
#   'instrumentalness': 7.07e-06,
#   'liveness': 0.371,
#   'valence': 0.304,
#   'tempo': 128.04,
#   'duration_ms': 175238,
#   'time_signature': 4,
#   'name': "I'm Good (Blue)",
#   'artist(s)': ['David Guetta', 'Bebe Rexha'],
#   'genres': [['big room', 'dance pop', 'edm', 'pop', 'pop dance'],
#    ['dance pop', 'edm', 'pop', 'post-teen pop']],
#   'Category': 34},
#  {'danceability': 0.552,
#   'energy': 0.608,
#   'key': 1,
#   'loudness': -9.786,
#   'mode': 0,
#   'speechiness': 0.0345,
#   'acousticness': 0.352,
#   'instrumentalness': 0,
#   'liveness': 0.0533,
#   'valence': 0.637,
#   'tempo': 112.367,
#   'duration_ms': 162373,
#   'time_signature': 4,
#   'name': "California Dreamin' - Single Version",
#   'artist(s)': ['The Mamas & The Papas'],
#   'genres': [['bubblegum pop',
#     'classic rock',
#     'folk rock',
#     'mellow gold',
#     'psychedelic rock',
#     'rock',
#     'sunshine pop']],
#   'Category': 58},
#  {'danceability': 0.674,
#   'energy': 0.789,
#   'key': 8,
#   'loudness': -6.903,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'acousticness': 0.00178,
#   'instrumentalness': 0.00708,
#   'liveness': 0.0753,
#   'valence': 0.918,
#   'tempo': 129.802,
#   'duration_ms': 121160,
#   'time_signature': 4,
#   'name': 'Song 2 - 2012 Remaster',
#   'artist(s)': ['Blur'],
#   'genres': [['alternative rock',
#     'britpop',
#     'madchester',
#     'modern rock',
#     'permanent wave',
#     'pop rock',
#     'rock']],
#   'Category': 15}]

# %%
tracks_df = pd.DataFrame.from_dict(track_info)
tracks_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.514   0.730    1    -5.934     1       0.0598       0.00146
# 1           0.825   0.652    1    -3.183     0       0.0802       0.58100
# 2           0.824   0.587    6    -6.401     0       0.0937       0.69000
# 3           0.501   0.405    1    -5.679     1       0.0319       0.75100
# 4           0.585   0.520    5    -6.136     0       0.0712       0.12400
# ..            ...     ...  ...       ...   ...          ...           ...
# 677         0.414   0.428    0   -11.097     1       0.0278       0.38200
# 678         0.749   0.491   10    -9.655     1       0.0403       0.02000
# 679         0.561   0.965    7    -3.673     0       0.0343       0.00383
# 680         0.552   0.608    1    -9.786     0       0.0345       0.35200
# 681         0.674   0.789    8    -6.903     1       0.0676       0.00178
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 0            0.000095    0.0897    0.334  171.005       200040
# 1            0.000000    0.0931    0.931   95.977       233713
# 2            0.000105    0.1490    0.514   98.029       209438
# 3            0.000000    0.1050    0.446  109.891       182161
# 4            0.000070    0.1310    0.129  159.801       218147
# ..                ...       ...      ...      ...          ...
# 677          0.000243    0.1480    0.282  145.075       377093
# 678          0.008990    0.1590    0.536  119.528       292613
# 679          0.000007    0.3710    0.304  128.040       175238
# 680          0.000000    0.0533    0.637  112.367       162373
# 681          0.007080    0.0753    0.918  129.802       121160
#
#      time_signature                                         name  \
# 0                 4                              Blinding Lights
# 1                 4                                 Shape of You
# 2                 4                                 Dance Monkey
# 3                 4                            Someone You Loved
# 4                 4                   rockstar (feat. 21 Savage)
# ..              ...                                          ...
# 677               4                                  Tiny Dancer
# 678               4  Gimme! Gimme! Gimme! (A Man After Midnight)
# 679               4                              I'm Good (Blue)
# 680               4         California Dreamin' - Single Version
# 681               4                       Song 2 - 2012 Remaster
#
#                       artist(s)  \
# 0                  [The Weeknd]
# 1                  [Ed Sheeran]
# 2                 [Tones And I]
# 3               [Lewis Capaldi]
# 4      [Post Malone, 21 Savage]
# ..                          ...
# 677                [Elton John]
# 678                      [ABBA]
# 679  [David Guetta, Bebe Rexha]
# 680     [The Mamas & The Papas]
# 681                      [Blur]
#
#                                                 genres  Category
# 0     [[canadian contemporary r&b, canadian pop, pop]]        64
# 1                                      [[pop, uk pop]]        80
# 2                              [[australian pop, pop]]        47
# 3                                      [[pop, uk pop]]        83
# 4    [[dfw rap, melodic rap, rap], [atl hip hop, rap]]       101
# ..                                                 ...       ...
# 677             [[glam rock, mellow gold, piano rock]]        55
# 678                           [[europop, swedish pop]]        77
# 679  [[big room, dance pop, edm, pop, pop dance], [...        34
# 680  [[bubblegum pop, classic rock, folk rock, mell...        58
# 681  [[alternative rock, britpop, madchester, moder...        15
#
# [682 rows x 17 columns]

# %%
tracks_by_category = tracks_df.sort_values(by='Category')
tracks_by_category
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 545         0.597   0.450    8    -6.658     1       0.0418       0.22300
# 258         0.461   0.593    1    -4.954     1       0.0356       0.17000
# 582         0.693   0.678    8    -7.159     1       0.0324       0.01510
# 583         0.512   0.662    3    -6.797     1       0.0439       0.02750
# 390         0.393   0.858    4    -2.868     0       0.0729       0.00359
# ..            ...     ...  ...       ...   ...          ...           ...
# 396         0.783   0.584    7    -6.572     1       0.0409       0.01090
# 531         0.691   0.823    2    -4.197     1       0.0623       0.48700
# 403         0.688   0.702    7    -4.792     0       0.0499       0.02150
# 237         0.671   0.314    5    -8.091     0       0.2440       0.11000
# 427         0.723   0.711    0    -5.576     0       0.0378       0.09970
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 545          0.000000    0.3820    0.537  178.765       228482
# 258          0.000000    0.3070    0.175  134.170       228373
# 582          0.000006    0.1010    0.404  103.952       228267
# 583          0.000000    0.1180    0.472  180.114       228347
# 390          0.000000    0.1020    0.560  176.042       228360
# ..                ...       ...      ...      ...          ...
# 396          0.000003    0.1080    0.632  120.031       193467
# 531          0.000000    0.1340    0.870  123.935       191467
# 403          0.000000    0.1280    0.740   94.006       192191
# 237          0.000000    0.0825    0.296  110.898       191600
# 427          0.000000    0.0528    0.606  138.098       192107
#
#      time_signature                               name  \
# 545               3  Stuck with U (with Justin Bieber)
# 258               3                   Call Out My Name
# 582               4                        Higher Love
# 583               4                          Fireflies
# 390               4                          Centuries
# ..              ...                                ...
# 396               4                      Call Me Maybe
# 531               4                If I Can't Have You
# 403               4                           My House
# 237               4                          Needed Me
# 427               4                       Drag Me Down
#
#                           artist(s)  \
# 545  [Ariana Grande, Justin Bieber]
# 258                    [The Weeknd]
# 582         [Kygo, Whitney Houston]
# 583                      [Owl City]
# 390                  [Fall Out Boy]
# ..                              ...
# 396              [Carly Rae Jepsen]
# 531                  [Shawn Mendes]
# 403                      [Flo Rida]
# 237                       [Rihanna]
# 427                 [One Direction]
#
#                                                 genres  Category
# 545            [[dance pop, pop], [canadian pop, pop]]         0
# 258   [[canadian contemporary r&b, canadian pop, pop]]         0
# 582  [[edm, pop, pop dance, tropical house], [dance...         0
# 583                         [[indietronica, pop rock]]         0
# 390                               [[emo, modern rock]]         0
# ..                                                 ...       ...
# 396  [[canadian pop, dance pop, electropop, pop, po...       108
# 531        [[canadian pop, dance pop, pop, viral pop]]       109
# 403    [[dance pop, edm, miami hip hop, pop, pop rap]]       109
# 237  [[barbadian pop, dance pop, pop, urban contemp...       109
# 427      [[boy band, pop, post-teen pop, talent show]]       109
#
# [682 rows x 17 columns]
