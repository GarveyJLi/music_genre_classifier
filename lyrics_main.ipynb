# %%
import track_methods
import numpy as np
from client_info import SPOTIFY_CID, SPOTIFY_CS, GENIUS_TOKEN

# %%
liked_playlist = 'https://open.spotify.com/playlist/1AFOT0dPcIXxMhEGnseiWm?si=c69d95c8a9734310'
"""liked_classifier = track_methods.MusicClassifier(SPOTIFY_CID, SPOTIFY_CS, \
    None, None, GENIUS_TOKEN)"""
# Out:
# 'liked_classifier = track_methods.MusicClassifier(SPOTIFY_CID, SPOTIFY_CS,     None, None, GENIUS_TOKEN)'

# %%
"""liked_list = liked_classifier.get_track_list(liked_playlist)
liked_list"""
# Out:
# 'liked_list = liked_classifier.get_track_list(liked_playlist)\nliked_list'

# %%
#liked_data = liked_classifier.create_playlist_track_info(liked_list)

# %%
girlboss_url = 'https://open.spotify.com/playlist/0rEZ9N18lkrdTsnDTFS5ha?si=e9389b1900774a78'
girlboss_classifier = track_methods.MusicClassifier(SPOTIFY_CID, SPOTIFY_CS, \
    None, None, GENIUS_TOKEN)

# %%
girlboss_list = girlboss_classifier.get_track_list(girlboss_url)

# %%
girlboss_data = girlboss_classifier.create_playlist_track_info(girlboss_list)
# Out:
# Searching for "Kiss Me More (feat. SZA)" by Doja Cat...
# Done.
# Searching for "positions" by Ariana Grande...
# Done.
# Searching for "motive (with Doja Cat)" by Ariana Grande...
# Done.
# Searching for "Need to Know" by Doja Cat...
# Done.
# Searching for "Like That (feat. Gucci Mane)" by Doja Cat...
# Done.
# Searching for "Freak" by Doja Cat...
# Done.
# Searching for "Rules" by Doja Cat...
# Done.
# Searching for "Streets" by Doja Cat...
# Done.
# Searching for "Get Into It (Yuh)" by Doja Cat...
# Done.
# Searching for "You Right" by Doja Cat...
# Done.
# Searching for "I Don't Do Drugs (feat. Ariana Grande)" by Doja Cat...
# Done.
# Searching for "test drive" by Ariana Grande...
# Done.
# Searching for "boyfriend (with Social House)" by Ariana Grande...
# Done.
# Searching for "Woman" by Doja Cat...
# Done.
# Searching for "Wait a Minute!" by WILLOW...
# Done.
# Searching for "Time Machine" by WILLOW...
# Done.
# Searching for "Cyber Sex" by Doja Cat...
# Done.
# ...

# %%
girlboss_classifier.get_playlist_df()
# Out:
#                                                  name  \
# 0                            Kiss Me More (feat. SZA)
# 1                                           positions
# 2                              motive (with Doja Cat)
# 3                                        Need to Know
# 4                        Like That (feat. Gucci Mane)
# 5                                               Freak
# 6                                               Rules
# 7                                             Streets
# 8                                   Get Into It (Yuh)
# 9                                           You Right
# 10             I Don't Do Drugs (feat. Ariana Grande)
# 11                                         test drive
# 12                      boyfriend (with Social House)
# 13                                              Woman
# 14                                     Wait a Minute!
# 15                                       Time Machine
# ...
